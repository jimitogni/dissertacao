# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy 
import random
import shutil, sys
import pandas as pd

print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.5.0
# Torchvision Version:  0.6.0

# %%
# Top level data directory. Here we assume the format of the directory conforms
#   to the ImageFolder structure
data_dir = '/home/jimi/dissertacao/covid19/datasets/dataset_bal/'

# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet, inception]
model_name = "squeezenet"

# Number of classes in the dataset
num_classes = 3

# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Number of epochs to train for
num_epochs = 200

# Flag for feature extracting. When False, we finetune the whole model,
#   when True we only update the reshaped layer params
feature_extract = True

# %%
# Path to data
data_dir = '/home/jimi/dissertacao/covid19/datasets/dataset_bal/'
train_dir = data_dir+'train/'
test_dir = data_dir+'test/'
val_dir = data_dir+'val/'

normal_dir = data_dir+'normal/'
pneumonia_dir = data_dir+'pneumonia/'
covid_dir = data_dir+'covid/'

len_covid = len([iq for iq in os.scandir(normal_dir)])
len_normal = len([iq for iq in os.scandir(pneumonia_dir)])
len_pneumonia = len([iq for iq in os.scandir(covid_dir)])

len_train_dir = len([iq for iq in os.scandir(train_dir+'covid/')]) + len([iq for iq in os.scandir(train_dir+'normal/')]) + len([iq for iq in os.scandir(train_dir+'pneumonia/')])
len_test_dir = len([iq for iq in os.scandir(test_dir+'covid/')]) + len([iq for iq in os.scandir(test_dir+'normal/')]) + len([iq for iq in os.scandir(test_dir+'pneumonia/')])
len_val_dir = len([iq for iq in os.scandir(val_dir+'covid/')]) + len([iq for iq in os.scandir(val_dir+'normal/')]) + len([iq for iq in os.scandir(val_dir+'pneumonia/')])

print('Files per classes')
print("----"*10)
print("normal : ", len_covid)
print("pneumonia : ", len_normal)
print("covid : ", len_pneumonia)
print("-"*20)
print('Train, test, validation')
print("-"*20)
print("len_train_dir : ", len_train_dir)
print("len_test_dir : ", len_test_dir)
print("len_val_dir : ", len_val_dir)
# Out:
# Files per classes
# ----------------------------------------
# normal :  505
# pneumonia :  505
# covid :  505
# --------------------
# Train, test, validation
# --------------------
# len_train_dir :  969
# len_test_dir :  303
# len_val_dir :  243

# %%
# Data augmentation and normalization for training
# Just normalization for validation
#transforms.RandomRotation(degrees=(-5, 5)),
#transforms.ColorJitter(brightness=.02),
    
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.RandomRotation(degrees=(-10, 10)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Initializing Datasets and Dataloaders...

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders_dict['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25, is_inception=False):
    since = time.time()

    val_acc_history = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for inception because in training it has an auxiliary output. In train
                    #   mode we calculate the loss by summing the final output and the auxiliary output
                    #   but in testing we only consider the final output.
                    if is_inception and phase == 'train':
                        # From https://discuss.pytorch.org/t/how-to-optimize-inception-model-with-auxiliary-classifiers/7958
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + 0.4*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
def visualize_model(model, num_images=4):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders_dict['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 3, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet18
        """
        model_ft = models.resnet18(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "alexnet":
        """ Alexnet
        """
        model_ft = models.alexnet(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "vgg":
        """ VGG11_bn
        """
        model_ft = models.vgg11_bn(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "squeezenet":
        """ Squeezenet
        """
        model_ft = models.squeezenet1_0(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        model_ft.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model_ft.num_classes = num_classes
        input_size = 224

    elif model_name == "densenet":
        """ Densenet
        """
        model_ft = models.densenet121(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "inception":
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        """
        model_ft = models.inception_v3(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        # Handle the auxilary net
        num_ftrs = model_ft.AuxLogits.fc.in_features
        model_ft.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs,num_classes)
        input_size = 299

    else:
        print("Invalid model name, exiting...")
        exit()

    return model_ft, input_size

# Initialize the model for this run
model_ft, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)

# Print the model we just instantiated
print(model_ft)
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (6): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (9): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Conv2d(512, 3, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )

# %%
# Send the model to GPU
model_ft = model_ft.to(device)

# Gather the parameters to be optimized/updated in this run. If we are
#  finetuning we will be updating all parameters. However, if we are
#  doing feature extract method, we will only update the parameters
#  that we have just initialized, i.e. the parameters with requires_grad
#  is True.
params_to_update = model_ft.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(params_to_update, lr=0.001, momentum=0.9)
# Out:
# Params to learn:
# 	 classifier.1.weight
# 	 classifier.1.bias

# %% [markdown]
# # Squeezenet

# %%
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Train and evaluate
model_ft, hist = train_model(model_ft, dataloaders_dict, criterion, 
                             optimizer_ft, num_epochs=num_epochs, 
                             is_inception=(model_name=="inception"))
# Out:
# Epoch 0/199
# ----------
# train Loss: 0.8806 Acc: 0.6017
# val Loss: 0.5313 Acc: 0.8066
#
# Epoch 1/199
# ----------
# train Loss: 0.5889 Acc: 0.7585
# val Loss: 0.5488 Acc: 0.8148
#
# Epoch 2/199
# ----------
# train Loss: 0.4637 Acc: 0.8153
# val Loss: 0.2389 Acc: 0.9300
#
# Epoch 3/199
# ----------
# train Loss: 0.3817 Acc: 0.8524
# val Loss: 0.6271 Acc: 0.8107
#
# Epoch 4/199
# ----------
# train Loss: 0.3991 Acc: 0.8535
# val Loss: 0.3344 Acc: 0.9095
#
# Epoch 5/199
# ----------
# train Loss: 0.3845 Acc: 0.8576
# val Loss: 0.2053 Acc: 0.9383
#
# Epoch 6/199
# ----------
# train Loss: 0.3195 Acc: 0.8834
# val Loss: 0.2765 Acc: 0.9095
#
# Epoch 7/199
# ----------
# train Loss: 0.3673 Acc: 0.8638
# val Loss: 0.2870 Acc: 0.9012
#
# Epoch 8/199
# ----------
# train Loss: 0.3239 Acc: 0.8741
# val Loss: 0.2508 Acc: 0.9300
#
# Epoch 9/199
# ----------
# train Loss: 0.3055 Acc: 0.8720
# val Loss: 0.4456 Acc: 0.7901
#
# Epoch 10/199
# ----------
# train Loss: 0.3220 Acc: 0.8834
# val Loss: 0.3578 Acc: 0.9053
#
# Epoch 11/199
# ----------
# train Loss: 0.3903 Acc: 0.8452
# val Loss: 0.2906 Acc: 0.9300
#
# Epoch 12/199
# ----------
# train Loss: 0.3166 Acc: 0.8906
# val Loss: 0.2108 Acc: 0.9342
#
# Epoch 13/199
# ----------
# train Loss: 0.3267 Acc: 0.8885
# val Loss: 0.4112 Acc: 0.8601
#
# Epoch 14/199
# ----------
# train Loss: 0.3121 Acc: 0.8751
# val Loss: 0.2969 Acc: 0.9218
#
# Epoch 15/199
# ----------
# train Loss: 0.2869 Acc: 0.8875
# val Loss: 0.1836 Acc: 0.9465
#
# Epoch 16/199
# ----------
# train Loss: 0.3522 Acc: 0.8607
# val Loss: 0.2081 Acc: 0.9095
#
# Epoch 17/199
# ----------
# train Loss: 0.2839 Acc: 0.8906
# val Loss: 0.3216 Acc: 0.8971
#
# Epoch 18/199
# ----------
# train Loss: 0.3014 Acc: 0.8854
# val Loss: 0.2262 Acc: 0.9465
#
# Epoch 19/199
# ----------
# train Loss: 0.3109 Acc: 0.8824
# val Loss: 0.1954 Acc: 0.9383
#
# Epoch 20/199
# ----------
# train Loss: 0.3249 Acc: 0.8824
# val Loss: 0.2653 Acc: 0.9095
#
# Epoch 21/199
# ----------
# train Loss: 0.3343 Acc: 0.8782
# val Loss: 0.3143 Acc: 0.9095
#
# Epoch 22/199
# ----------
# train Loss: 0.2671 Acc: 0.9092
# val Loss: 0.2865 Acc: 0.9136
#
# Epoch 23/199
# ----------
# train Loss: 0.3016 Acc: 0.8824
# val Loss: 0.3602 Acc: 0.8807
#
# Epoch 24/199
# ----------
# train Loss: 0.2758 Acc: 0.8937
# val Loss: 0.4835 Acc: 0.8807
#
# Epoch 25/199
# ----------
# train Loss: 0.3091 Acc: 0.8762
# val Loss: 0.2155 Acc: 0.9177
#
# Epoch 26/199
# ----------
# train Loss: 0.2810 Acc: 0.8906
# val Loss: 0.2926 Acc: 0.9136
#
# Epoch 27/199
# ----------
# train Loss: 0.2721 Acc: 0.9051
# val Loss: 0.2463 Acc: 0.9136
#
# Epoch 28/199
# ----------
# train Loss: 0.3300 Acc: 0.8720
# val Loss: 0.3772 Acc: 0.9053
#
# Epoch 29/199
# ----------
# train Loss: 0.3076 Acc: 0.8834
# val Loss: 0.2736 Acc: 0.9259
#
# Epoch 30/199
# ----------
# train Loss: 0.3072 Acc: 0.8844
# val Loss: 0.2384 Acc: 0.9095
#
# Epoch 31/199
# ----------
# train Loss: 0.2941 Acc: 0.9030
# val Loss: 0.1836 Acc: 0.9424
#
# Epoch 32/199
# ----------
# train Loss: 0.2742 Acc: 0.8958
# val Loss: 0.2176 Acc: 0.9342
#
# Epoch 33/199
# ----------
# train Loss: 0.2698 Acc: 0.9051
# val Loss: 0.3206 Acc: 0.9012
#
# Epoch 34/199
# ----------
# train Loss: 0.2602 Acc: 0.9040
# val Loss: 0.4365 Acc: 0.8848
#
# Epoch 35/199
# ----------
# train Loss: 0.2864 Acc: 0.9009
# val Loss: 0.2900 Acc: 0.9053
#
# Epoch 36/199
# ----------
# train Loss: 0.3137 Acc: 0.8885
# val Loss: 0.1921 Acc: 0.9218
#
# Epoch 37/199
# ----------
# train Loss: 0.2740 Acc: 0.8865
# val Loss: 0.1891 Acc: 0.9218
#
# Epoch 38/199
# ----------
# train Loss: 0.2999 Acc: 0.8947
# val Loss: 0.2197 Acc: 0.9383
#
# Epoch 39/199
# ----------
# train Loss: 0.2486 Acc: 0.9143
# val Loss: 0.2078 Acc: 0.9300
#
# Epoch 40/199
# ----------
# train Loss: 0.2709 Acc: 0.8937
# val Loss: 0.2120 Acc: 0.9383
#
# Epoch 41/199
# ----------
# train Loss: 0.2405 Acc: 0.9092
# val Loss: 0.2415 Acc: 0.9012
#
# Epoch 42/199
# ----------
# train Loss: 0.2765 Acc: 0.8947
# val Loss: 0.1994 Acc: 0.9383
#
# Epoch 43/199
# ----------
# train Loss: 0.2866 Acc: 0.8927
# val Loss: 0.2398 Acc: 0.9259
#
# Epoch 44/199
# ----------
# train Loss: 0.3014 Acc: 0.8854
# val Loss: 0.2405 Acc: 0.9136
#
# Epoch 45/199
# ----------
# train Loss: 0.2421 Acc: 0.9102
# val Loss: 0.2277 Acc: 0.9218
#
# Epoch 46/199
# ----------
# train Loss: 0.2961 Acc: 0.8906
# val Loss: 0.2621 Acc: 0.9218
#
# Epoch 47/199
# ----------
# train Loss: 0.2784 Acc: 0.8916
# val Loss: 0.3177 Acc: 0.9012
#
# Epoch 48/199
# ----------
# train Loss: 0.2534 Acc: 0.9112
# val Loss: 0.3165 Acc: 0.9053
#
# Epoch 49/199
# ----------
# train Loss: 0.2685 Acc: 0.8896
# val Loss: 0.2210 Acc: 0.9259
#
# Epoch 50/199
# ----------
# train Loss: 0.2728 Acc: 0.9030
# val Loss: 0.2462 Acc: 0.9259
#
# Epoch 51/199
# ----------
# train Loss: 0.2846 Acc: 0.8885
# val Loss: 0.2445 Acc: 0.9095
#
# Epoch 52/199
# ----------
# train Loss: 0.2699 Acc: 0.8875
# val Loss: 0.3406 Acc: 0.8848
#
# Epoch 53/199
# ----------
# train Loss: 0.2733 Acc: 0.9051
# val Loss: 0.2315 Acc: 0.9177
#
# Epoch 54/199
# ----------
# train Loss: 0.3114 Acc: 0.8844
# val Loss: 0.3377 Acc: 0.9053
#
# Epoch 55/199
# ----------
# train Loss: 0.2456 Acc: 0.9051
# val Loss: 0.3348 Acc: 0.8807
#
# Epoch 56/199
# ----------
# train Loss: 0.2565 Acc: 0.9123
# val Loss: 0.2638 Acc: 0.9095
#
# Epoch 57/199
# ----------
# train Loss: 0.2662 Acc: 0.8937
# val Loss: 0.2010 Acc: 0.9506
#
# Epoch 58/199
# ----------
# train Loss: 0.2556 Acc: 0.9030
# val Loss: 0.4388 Acc: 0.8848
#
# Epoch 59/199
# ----------
# train Loss: 0.2765 Acc: 0.8968
# val Loss: 0.4052 Acc: 0.8848
#
# Epoch 60/199
# ----------
# train Loss: 0.2638 Acc: 0.8999
# val Loss: 0.2193 Acc: 0.9342
#
# Epoch 61/199
# ----------
# train Loss: 0.2439 Acc: 0.8999
# val Loss: 0.4507 Acc: 0.8930
#
# Epoch 62/199
# ----------
# train Loss: 0.2973 Acc: 0.8875
# val Loss: 0.2864 Acc: 0.9136
#
# Epoch 63/199
# ----------
# train Loss: 0.2889 Acc: 0.8999
# val Loss: 0.2818 Acc: 0.9177
#
# Epoch 64/199
# ----------
# train Loss: 0.2924 Acc: 0.8978
# val Loss: 0.2659 Acc: 0.9300
#
# Epoch 65/199
# ----------
# train Loss: 0.2586 Acc: 0.8978
# val Loss: 0.2831 Acc: 0.9218
#
# Epoch 66/199
# ----------
# train Loss: 0.2392 Acc: 0.9195
# val Loss: 0.3275 Acc: 0.9136
#
# Epoch 67/199
# ----------
# train Loss: 0.2755 Acc: 0.8937
# val Loss: 0.3127 Acc: 0.9136
#
# Epoch 68/199
# ----------
# train Loss: 0.2522 Acc: 0.9102
# val Loss: 0.2157 Acc: 0.9177
#
# Epoch 69/199
# ----------
# train Loss: 0.2690 Acc: 0.8978
# val Loss: 0.3064 Acc: 0.9095
#
# Epoch 70/199
# ----------
# train Loss: 0.2956 Acc: 0.8762
# val Loss: 0.3339 Acc: 0.9095
#
# Epoch 71/199
# ----------
# train Loss: 0.2893 Acc: 0.8731
# val Loss: 0.3221 Acc: 0.9095
#
# Epoch 72/199
# ----------
# train Loss: 0.2764 Acc: 0.8958
# val Loss: 0.2739 Acc: 0.9300
#
# Epoch 73/199
# ----------
# train Loss: 0.2894 Acc: 0.8989
# val Loss: 0.3273 Acc: 0.9053
#
# Epoch 74/199
# ----------
# train Loss: 0.2570 Acc: 0.9020
# val Loss: 0.3134 Acc: 0.9218
#
# Epoch 75/199
# ----------
# train Loss: 0.2506 Acc: 0.9123
# val Loss: 0.1989 Acc: 0.9465
#
# Epoch 76/199
# ----------
# train Loss: 0.2461 Acc: 0.9092
# val Loss: 0.2831 Acc: 0.9053
#
# Epoch 77/199
# ----------
# train Loss: 0.2422 Acc: 0.9061
# val Loss: 0.2690 Acc: 0.9136
#
# Epoch 78/199
# ----------
# train Loss: 0.2770 Acc: 0.8958
# val Loss: 0.3118 Acc: 0.9012
#
# Epoch 79/199
# ----------
# train Loss: 0.2284 Acc: 0.9185
# val Loss: 0.2504 Acc: 0.9300
#
# Epoch 80/199
# ----------
# train Loss: 0.2580 Acc: 0.9082
# val Loss: 0.2418 Acc: 0.9300
#
# Epoch 81/199
# ----------
# train Loss: 0.2459 Acc: 0.9112
# val Loss: 0.2078 Acc: 0.9424
#
# Epoch 82/199
# ----------
# train Loss: 0.2585 Acc: 0.9164
# val Loss: 0.1725 Acc: 0.9342
#
# Epoch 83/199
# ----------
# train Loss: 0.2483 Acc: 0.9071
# val Loss: 0.2637 Acc: 0.9177
#
# Epoch 84/199
# ----------
# train Loss: 0.2309 Acc: 0.9154
# val Loss: 0.2318 Acc: 0.9259
#
# Epoch 85/199
# ----------
# train Loss: 0.3209 Acc: 0.8885
# val Loss: 0.2588 Acc: 0.9342
#
# Epoch 86/199
# ----------
# train Loss: 0.2411 Acc: 0.9133
# val Loss: 0.3312 Acc: 0.9053
#
# Epoch 87/199
# ----------
# train Loss: 0.2502 Acc: 0.9051
# val Loss: 0.2676 Acc: 0.9218
#
# Epoch 88/199
# ----------
# train Loss: 0.2385 Acc: 0.9040
# val Loss: 0.2608 Acc: 0.9342
#
# Epoch 89/199
# ----------
# train Loss: 0.2163 Acc: 0.9319
# val Loss: 0.1875 Acc: 0.9424
#
# Epoch 90/199
# ----------
# train Loss: 0.2460 Acc: 0.9071
# val Loss: 0.1912 Acc: 0.9383
#
# Epoch 91/199
# ----------
# train Loss: 0.2846 Acc: 0.8999
# val Loss: 0.2530 Acc: 0.9383
#
# Epoch 92/199
# ----------
# train Loss: 0.2538 Acc: 0.9061
# val Loss: 0.2917 Acc: 0.9342
#
# Epoch 93/199
# ----------
# train Loss: 0.2466 Acc: 0.9051
# val Loss: 0.2029 Acc: 0.9218
#
# Epoch 94/199
# ----------
# train Loss: 0.2383 Acc: 0.9133
# val Loss: 0.1679 Acc: 0.9465
#
# Epoch 95/199
# ----------
# train Loss: 0.2522 Acc: 0.9009
# val Loss: 0.2302 Acc: 0.9465
#
# Epoch 96/199
# ----------
# train Loss: 0.2665 Acc: 0.8978
# val Loss: 0.2253 Acc: 0.9383
#
# Epoch 97/199
# ----------
# train Loss: 0.2584 Acc: 0.9040
# val Loss: 0.3519 Acc: 0.8971
#
# Epoch 98/199
# ----------
# train Loss: 0.2496 Acc: 0.9009
# val Loss: 0.2549 Acc: 0.9136
#
# Epoch 99/199
# ----------
# train Loss: 0.3486 Acc: 0.8762
# val Loss: 0.2698 Acc: 0.9342
#
# Epoch 100/199
# ----------
# train Loss: 0.2430 Acc: 0.9164
# val Loss: 0.2328 Acc: 0.9342
#
# Epoch 101/199
# ----------
# train Loss: 0.2363 Acc: 0.9185
# val Loss: 0.2764 Acc: 0.9259
#
# Epoch 102/199
# ----------
# train Loss: 0.2580 Acc: 0.8947
# val Loss: 0.1951 Acc: 0.9424
#
# Epoch 103/199
# ----------
# train Loss: 0.2302 Acc: 0.9092
# val Loss: 0.3155 Acc: 0.9095
#
# Epoch 104/199
# ----------
# train Loss: 0.2560 Acc: 0.9051
# val Loss: 0.3128 Acc: 0.9218
#
# Epoch 105/199
# ----------
# train Loss: 0.2522 Acc: 0.9164
# val Loss: 0.2874 Acc: 0.9177
#
# Epoch 106/199
# ----------
# train Loss: 0.2465 Acc: 0.9112
# val Loss: 0.2656 Acc: 0.9342
#
# Epoch 107/199
# ----------
# train Loss: 0.2694 Acc: 0.8927
# val Loss: 0.2688 Acc: 0.9012
#
# Epoch 108/199
# ----------
# train Loss: 0.2732 Acc: 0.8916
# val Loss: 0.2484 Acc: 0.9300
#
# Epoch 109/199
# ----------
# train Loss: 0.2472 Acc: 0.9082
# val Loss: 0.2520 Acc: 0.9300
#
# Epoch 110/199
# ----------
# train Loss: 0.2790 Acc: 0.9020
# val Loss: 0.2270 Acc: 0.9424
#
# Epoch 111/199
# ----------
# train Loss: 0.2344 Acc: 0.9133
# val Loss: 0.2439 Acc: 0.9342
#
# Epoch 112/199
# ----------
# train Loss: 0.2216 Acc: 0.9133
# val Loss: 0.2474 Acc: 0.9053
#
# Epoch 113/199
# ----------
# train Loss: 0.2500 Acc: 0.9112
# val Loss: 0.2125 Acc: 0.9383
#
# Epoch 114/199
# ----------
# train Loss: 0.2431 Acc: 0.9061
# val Loss: 0.2655 Acc: 0.9259
#
# Epoch 115/199
# ----------
# train Loss: 0.2354 Acc: 0.9195
# val Loss: 0.2711 Acc: 0.9136
#
# Epoch 116/199
# ----------
# train Loss: 0.2634 Acc: 0.8927
# val Loss: 0.2575 Acc: 0.9300
#
# Epoch 117/199
# ----------
# train Loss: 0.2496 Acc: 0.9071
# val Loss: 0.3852 Acc: 0.9012
#
# Epoch 118/199
# ----------
# train Loss: 0.2399 Acc: 0.9216
# val Loss: 0.2447 Acc: 0.9300
#
# Epoch 119/199
# ----------
# train Loss: 0.2497 Acc: 0.9040
# val Loss: 0.2645 Acc: 0.9259
#
# Epoch 120/199
# ----------
# train Loss: 0.2287 Acc: 0.9216
# val Loss: 0.1649 Acc: 0.9383
#
# Epoch 121/199
# ----------
# train Loss: 0.2105 Acc: 0.9123
# val Loss: 0.2119 Acc: 0.9342
#
# Epoch 122/199
# ----------
# train Loss: 0.2424 Acc: 0.9061
# val Loss: 0.2797 Acc: 0.9218
#
# Epoch 123/199
# ----------
# train Loss: 0.2215 Acc: 0.9185
# val Loss: 0.1844 Acc: 0.9465
#
# Epoch 124/199
# ----------
# train Loss: 0.2253 Acc: 0.9061
# val Loss: 0.3729 Acc: 0.9053
#
# Epoch 125/199
# ----------
# train Loss: 0.2338 Acc: 0.9185
# val Loss: 0.2421 Acc: 0.9342
#
# Epoch 126/199
# ----------
# train Loss: 0.2984 Acc: 0.8916
# val Loss: 0.2146 Acc: 0.9342
#
# Epoch 127/199
# ----------
# train Loss: 0.2741 Acc: 0.8958
# val Loss: 0.3340 Acc: 0.9177
#
# Epoch 128/199
# ----------
# train Loss: 0.2460 Acc: 0.9040
# val Loss: 0.2181 Acc: 0.9424
#
# Epoch 129/199
# ----------
# train Loss: 0.2341 Acc: 0.9216
# val Loss: 0.2241 Acc: 0.9342
#
# Epoch 130/199
# ----------
# train Loss: 0.2541 Acc: 0.9009
# val Loss: 0.2580 Acc: 0.9342
#
# Epoch 131/199
# ----------
# train Loss: 0.2318 Acc: 0.9133
# val Loss: 0.2758 Acc: 0.9300
#
# Epoch 132/199
# ----------
# train Loss: 0.2360 Acc: 0.9185
# val Loss: 0.2411 Acc: 0.9342
#
# Epoch 133/199
# ----------
# train Loss: 0.2273 Acc: 0.9257
# val Loss: 0.2274 Acc: 0.9424
#
# Epoch 134/199
# ----------
# train Loss: 0.2196 Acc: 0.9216
# val Loss: 0.2013 Acc: 0.9300
#
# Epoch 135/199
# ----------
# train Loss: 0.2360 Acc: 0.9216
# val Loss: 0.2382 Acc: 0.9383
#
# Epoch 136/199
# ----------
# train Loss: 0.2464 Acc: 0.8989
# val Loss: 0.2731 Acc: 0.9177
#
# Epoch 137/199
# ----------
# train Loss: 0.2782 Acc: 0.8978
# val Loss: 0.2729 Acc: 0.9300
#
# Epoch 138/199
# ----------
# train Loss: 0.2316 Acc: 0.9112
# val Loss: 0.3800 Acc: 0.8848
#
# Epoch 139/199
# ----------
# train Loss: 0.2149 Acc: 0.9205
# val Loss: 0.2686 Acc: 0.9383
#
# Epoch 140/199
# ----------
# train Loss: 0.2151 Acc: 0.9236
# val Loss: 0.2737 Acc: 0.9177
#
# Epoch 141/199
# ----------
# train Loss: 0.2406 Acc: 0.9164
# val Loss: 0.3394 Acc: 0.9136
#
# Epoch 142/199
# ----------
# train Loss: 0.2558 Acc: 0.9112
# val Loss: 0.1628 Acc: 0.9342
#
# Epoch 143/199
# ----------
# train Loss: 0.2312 Acc: 0.9143
# val Loss: 0.1951 Acc: 0.9300
#
# Epoch 144/199
# ----------
# train Loss: 0.2360 Acc: 0.9236
# val Loss: 0.1574 Acc: 0.9424
#
# Epoch 145/199
# ----------
# train Loss: 0.2098 Acc: 0.9143
# val Loss: 0.2728 Acc: 0.9177
#
# Epoch 146/199
# ----------
# train Loss: 0.2760 Acc: 0.8937
# val Loss: 0.1802 Acc: 0.9588
#
# Epoch 147/199
# ----------
# train Loss: 0.2570 Acc: 0.9071
# val Loss: 0.2269 Acc: 0.9218
#
# Epoch 148/199
# ----------
# train Loss: 0.2375 Acc: 0.9123
# val Loss: 0.2198 Acc: 0.9259
#
# Epoch 149/199
# ----------
# train Loss: 0.2389 Acc: 0.9123
# val Loss: 0.3053 Acc: 0.9300
#
# Epoch 150/199
# ----------
# train Loss: 0.2516 Acc: 0.9071
# val Loss: 0.3097 Acc: 0.9259
#
# Epoch 151/199
# ----------
# train Loss: 0.2693 Acc: 0.8896
# val Loss: 0.2642 Acc: 0.9424
#
# Epoch 152/199
# ----------
# train Loss: 0.2090 Acc: 0.9236
# val Loss: 0.2316 Acc: 0.9259
#
# Epoch 153/199
# ----------
# train Loss: 0.2494 Acc: 0.9040
# val Loss: 0.2287 Acc: 0.9218
#
# Epoch 154/199
# ----------
# train Loss: 0.2128 Acc: 0.9112
# val Loss: 0.2307 Acc: 0.9424
#
# Epoch 155/199
# ----------
# train Loss: 0.2898 Acc: 0.8906
# val Loss: 0.2076 Acc: 0.9506
#
# Epoch 156/199
# ----------
# train Loss: 0.2175 Acc: 0.9185
# val Loss: 0.2390 Acc: 0.9342
#
# Epoch 157/199
# ----------
# train Loss: 0.2311 Acc: 0.9133
# val Loss: 0.2881 Acc: 0.9259
#
# Epoch 158/199
# ----------
# train Loss: 0.2364 Acc: 0.9071
# val Loss: 0.2226 Acc: 0.9342
#
# Epoch 159/199
# ----------
# train Loss: 0.2667 Acc: 0.9061
# val Loss: 0.2599 Acc: 0.9300
#
# Epoch 160/199
# ----------
# train Loss: 0.2129 Acc: 0.9267
# val Loss: 0.3297 Acc: 0.9136
#
# Epoch 161/199
# ----------
# train Loss: 0.2562 Acc: 0.9092
# val Loss: 0.3107 Acc: 0.9218
#
# Epoch 162/199
# ----------
# train Loss: 0.2168 Acc: 0.9174
# val Loss: 0.2767 Acc: 0.9259
#
# Epoch 163/199
# ----------
# train Loss: 0.2500 Acc: 0.9040
# val Loss: 0.2706 Acc: 0.9342
#
# Epoch 164/199
# ----------
# train Loss: 0.2492 Acc: 0.9102
# val Loss: 0.2825 Acc: 0.9342
#
# Epoch 165/199
# ----------
# train Loss: 0.2085 Acc: 0.9195
# val Loss: 0.2858 Acc: 0.9300
#
# Epoch 166/199
# ----------
# train Loss: 0.1932 Acc: 0.9329
# val Loss: 0.1978 Acc: 0.9465
#
# Epoch 167/199
# ----------
# train Loss: 0.2001 Acc: 0.9195
# val Loss: 0.1469 Acc: 0.9383
#
# Epoch 168/199
# ----------
# train Loss: 0.2735 Acc: 0.9061
# val Loss: 0.2157 Acc: 0.9136
#
# Epoch 169/199
# ----------
# train Loss: 0.2548 Acc: 0.9009
# val Loss: 0.1861 Acc: 0.9342
#
# Epoch 170/199
# ----------
# train Loss: 0.2529 Acc: 0.9082
# val Loss: 0.1983 Acc: 0.9342
#
# Epoch 171/199
# ----------
# train Loss: 0.2387 Acc: 0.9040
# val Loss: 0.1836 Acc: 0.9300
#
# Epoch 172/199
# ----------
# train Loss: 0.2306 Acc: 0.9082
# val Loss: 0.2131 Acc: 0.9259
#
# Epoch 173/199
# ----------
# train Loss: 0.2401 Acc: 0.9143
# val Loss: 0.2405 Acc: 0.9342
#
# Epoch 174/199
# ----------
# train Loss: 0.2370 Acc: 0.9123
# val Loss: 0.2096 Acc: 0.9342
#
# Epoch 175/199
# ----------
# train Loss: 0.2155 Acc: 0.9195
# val Loss: 0.2346 Acc: 0.9383
#
# Epoch 176/199
# ----------
# train Loss: 0.2384 Acc: 0.9082
# val Loss: 0.2510 Acc: 0.8971
#
# Epoch 177/199
# ----------
# train Loss: 0.2577 Acc: 0.8989
# val Loss: 0.1989 Acc: 0.9383
#
# Epoch 178/199
# ----------
# train Loss: 0.2158 Acc: 0.9247
# val Loss: 0.2318 Acc: 0.9095
#
# Epoch 179/199
# ----------
# train Loss: 0.2856 Acc: 0.8865
# val Loss: 0.2226 Acc: 0.9465
#
# Epoch 180/199
# ----------
# train Loss: 0.2175 Acc: 0.9143
# val Loss: 0.2390 Acc: 0.9465
#
# Epoch 181/199
# ----------
# train Loss: 0.2139 Acc: 0.9195
# val Loss: 0.2421 Acc: 0.9383
#
# Epoch 182/199
# ----------
# train Loss: 0.2620 Acc: 0.9020
# val Loss: 0.2027 Acc: 0.9342
#
# Epoch 183/199
# ----------
# train Loss: 0.2213 Acc: 0.9082
# val Loss: 0.2799 Acc: 0.9342
#
# Epoch 184/199
# ----------
# train Loss: 0.2362 Acc: 0.9164
# val Loss: 0.2351 Acc: 0.9300
#
# Epoch 185/199
# ----------
# train Loss: 0.2178 Acc: 0.9154
# val Loss: 0.4645 Acc: 0.8560
#
# Epoch 186/199
# ----------
# train Loss: 0.2360 Acc: 0.9133
# val Loss: 0.2032 Acc: 0.9424
#
# Epoch 187/199
# ----------
# train Loss: 0.2065 Acc: 0.9164
# val Loss: 0.2538 Acc: 0.9383
#
# Epoch 188/199
# ----------
# train Loss: 0.2195 Acc: 0.9205
# val Loss: 0.2641 Acc: 0.9342
#
# Epoch 189/199
# ----------
# train Loss: 0.2542 Acc: 0.9071
# val Loss: 0.2269 Acc: 0.9424
#
# Epoch 190/199
# ----------
# train Loss: 0.2037 Acc: 0.9288
# val Loss: 0.2103 Acc: 0.9300
#
# Epoch 191/199
# ----------
# train Loss: 0.2083 Acc: 0.9205
# val Loss: 0.2456 Acc: 0.9465
#
# Epoch 192/199
# ----------
# train Loss: 0.2374 Acc: 0.9051
# val Loss: 0.3546 Acc: 0.9177
#
# Epoch 193/199
# ----------
# train Loss: 0.2488 Acc: 0.9092
# val Loss: 0.1794 Acc: 0.9259
#
# Epoch 194/199
# ----------
# train Loss: 0.2490 Acc: 0.9082
# val Loss: 0.2501 Acc: 0.9383
#
# Epoch 195/199
# ----------
# train Loss: 0.2346 Acc: 0.9133
# val Loss: 0.2117 Acc: 0.9259
#
# Epoch 196/199
# ----------
# train Loss: 0.2485 Acc: 0.8999
# val Loss: 0.2588 Acc: 0.9383
#
# Epoch 197/199
# ----------
# train Loss: 0.2351 Acc: 0.9154
# val Loss: 0.2340 Acc: 0.9053
#
# Epoch 198/199
# ----------
# train Loss: 0.2137 Acc: 0.9236
# val Loss: 0.2178 Acc: 0.9259
#
# Epoch 199/199
# ----------
# train Loss: 0.2327 Acc: 0.9143
# val Loss: 0.2582 Acc: 0.9424
#
# Training complete in 98m 44s
# Best val Acc: 0.958848

# %%
visualize_model(model_ft)
