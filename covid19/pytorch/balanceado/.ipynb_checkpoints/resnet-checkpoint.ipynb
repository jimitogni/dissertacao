# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy 
import random
import shutil, sys
import pandas as pd

print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.5.0
# Torchvision Version:  0.6.0

# %%
# Top level data directory. Here we assume the format of the directory conforms
#   to the ImageFolder structure
data_dir = '/home/jimi/dissertacao/covid19/datasets/dataset_bal/'

# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet, inception]
model_name = "vgg"

# Number of classes in the dataset
num_classes = 3

# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Number of epochs to train for
num_epochs = 200

# Flag for feature extracting. When False, we finetune the whole model,
#   when True we only update the reshaped layer params
feature_extract = True

# %%
# Path to data
data_dir = '/home/jimi/dissertacao/covid19/datasets/dataset_bal/'
train_dir = data_dir+'train/'
test_dir = data_dir+'test/'
val_dir = data_dir+'val/'

normal_dir = data_dir+'normal/'
pneumonia_dir = data_dir+'pneumonia/'
covid_dir = data_dir+'covid/'

len_covid = len([iq for iq in os.scandir(normal_dir)])
len_normal = len([iq for iq in os.scandir(pneumonia_dir)])
len_pneumonia = len([iq for iq in os.scandir(covid_dir)])

len_train_dir = len([iq for iq in os.scandir(train_dir+'covid/')]) + len([iq for iq in os.scandir(train_dir+'normal/')]) + len([iq for iq in os.scandir(train_dir+'pneumonia/')])
len_test_dir = len([iq for iq in os.scandir(test_dir+'covid/')]) + len([iq for iq in os.scandir(test_dir+'normal/')]) + len([iq for iq in os.scandir(test_dir+'pneumonia/')])
len_val_dir = len([iq for iq in os.scandir(val_dir+'covid/')]) + len([iq for iq in os.scandir(val_dir+'normal/')]) + len([iq for iq in os.scandir(val_dir+'pneumonia/')])

print('Files per classes')
print("----"*10)
print("normal : ", len_covid)
print("pneumonia : ", len_normal)
print("covid : ", len_pneumonia)
print("-"*20)
print('Train, test, validation')
print("-"*20)
print("len_train_dir : ", len_train_dir)
print("len_test_dir : ", len_test_dir)
print("len_val_dir : ", len_val_dir)
# Out:
# Files per classes
# ----------------------------------------
# normal :  505
# pneumonia :  505
# covid :  505
# --------------------
# Train, test, validation
# --------------------
# len_train_dir :  969
# len_test_dir :  303
# len_val_dir :  243

# %%
# Data augmentation and normalization for training
# Just normalization for validation
#transforms.RandomRotation(degrees=(-5, 5)),
#transforms.ColorJitter(brightness=.02),
    
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

class_names = image_datasets['train'].classes

# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Initializing Datasets and Dataloaders...

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders_dict['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs, padding=10, nrow=4)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25, is_inception=False):
    since = time.time()

    val_acc_history = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for inception because in training it has an auxiliary output. In train
                    #   mode we calculate the loss by summing the final output and the auxiliary output
                    #   but in testing we only consider the final output.
                    if is_inception and phase == 'train':
                        # From https://discuss.pytorch.org/t/how-to-optimize-inception-model-with-auxiliary-classifiers/7958
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + 0.4*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
def visualize_model(model, num_images=4):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders_dict['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 3, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet18
        """
        model_ft = models.resnet18(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "alexnet":
        """ Alexnet
        """
        model_ft = models.alexnet(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "vgg":
        """ VGG11_bn
        """
        model_ft = models.vgg11_bn(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "squeezenet":
        """ Squeezenet
        """
        model_ft = models.squeezenet1_0(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        model_ft.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model_ft.num_classes = num_classes
        input_size = 224

    elif model_name == "densenet":
        """ Densenet
        """
        model_ft = models.densenet121(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "inception":
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        """
        model_ft = models.inception_v3(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        # Handle the auxilary net
        num_ftrs = model_ft.AuxLogits.fc.in_features
        model_ft.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs,num_classes)
        input_size = 299

    else:
        print("Invalid model name, exiting...")
        exit()

    return model_ft, input_size

# Initialize the model for this run
model_ft, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)

# Print the model we just instantiated
print(model_ft)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU(inplace=True)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): ReLU(inplace=True)
#     (21): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (22): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (27): ReLU(inplace=True)
#     (28): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=3, bias=True)
#   )
# )

# %%
# Send the model to GPU
model_ft = model_ft.to(device)

# Gather the parameters to be optimized/updated in this run. If we are
#  finetuning we will be updating all parameters. However, if we are
#  doing feature extract method, we will only update the parameters
#  that we have just initialized, i.e. the parameters with requires_grad
#  is True.
params_to_update = model_ft.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(params_to_update, lr=0.001, momentum=0.9)
# Out:
# Params to learn:
# 	 classifier.6.weight
# 	 classifier.6.bias

# %% [markdown]
# # Squeezenet

# %%
# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Train and evaluate
model_ft, hist = train_model(model_ft, dataloaders_dict, criterion, 
                             optimizer_ft, num_epochs=num_epochs, 
                             is_inception=(model_name=="inception"))
# Out:
# Epoch 0/199
# ----------
# train Loss: 0.6506 Acc: 0.7110
# val Loss: 0.4635 Acc: 0.7819
#
# Epoch 1/199
# ----------
# train Loss: 0.4970 Acc: 0.8039
# val Loss: 0.2927 Acc: 0.8930
#
# Epoch 2/199
# ----------
# train Loss: 0.4149 Acc: 0.8400
# val Loss: 0.2249 Acc: 0.9300
#
# Epoch 3/199
# ----------
# train Loss: 0.4356 Acc: 0.8277
# val Loss: 0.2469 Acc: 0.9342
#
# Epoch 4/199
# ----------
# train Loss: 0.4452 Acc: 0.8184
# val Loss: 0.3400 Acc: 0.8848
#
# Epoch 5/199
# ----------
# train Loss: 0.4134 Acc: 0.8369
# val Loss: 0.2107 Acc: 0.9383
#
# Epoch 6/199
# ----------
# train Loss: 0.4039 Acc: 0.8555
# val Loss: 0.2583 Acc: 0.9218
#
# Epoch 7/199
# ----------
# train Loss: 0.4289 Acc: 0.8277
# val Loss: 0.3130 Acc: 0.8848
#
# Epoch 8/199
# ----------
# train Loss: 0.4394 Acc: 0.8246
# val Loss: 0.2569 Acc: 0.9136
#
# Epoch 9/199
# ----------
# train Loss: 0.4144 Acc: 0.8493
# val Loss: 0.2158 Acc: 0.9300
#
# Epoch 10/199
# ----------
# train Loss: 0.3719 Acc: 0.8514
# val Loss: 0.2096 Acc: 0.9218
#
# Epoch 11/199
# ----------
# train Loss: 0.4118 Acc: 0.8359
# val Loss: 0.1839 Acc: 0.9259
#
# Epoch 12/199
# ----------
# train Loss: 0.4033 Acc: 0.8442
# val Loss: 0.2154 Acc: 0.9300
#
# Epoch 13/199
# ----------
# train Loss: 0.4307 Acc: 0.8338
# val Loss: 0.2970 Acc: 0.9136
#
# Epoch 14/199
# ----------
# train Loss: 0.3400 Acc: 0.8689
# val Loss: 0.2434 Acc: 0.9259
#
# Epoch 15/199
# ----------
# train Loss: 0.3614 Acc: 0.8566
# val Loss: 0.1881 Acc: 0.9424
#
# Epoch 16/199
# ----------
# train Loss: 0.4742 Acc: 0.8225
# val Loss: 0.2784 Acc: 0.9053
#
# Epoch 17/199
# ----------
# train Loss: 0.3600 Acc: 0.8586
# val Loss: 0.1800 Acc: 0.9424
#
# Epoch 18/199
# ----------
# train Loss: 0.3750 Acc: 0.8689
# val Loss: 0.1703 Acc: 0.9465
#
# Epoch 19/199
# ----------
# train Loss: 0.4237 Acc: 0.8318
# val Loss: 0.2269 Acc: 0.9300
#
# Epoch 20/199
# ----------
# train Loss: 0.4035 Acc: 0.8452
# val Loss: 0.2522 Acc: 0.9300
#
# Epoch 21/199
# ----------
# train Loss: 0.3925 Acc: 0.8596
# val Loss: 0.3664 Acc: 0.8930
#
# Epoch 22/199
# ----------
# train Loss: 0.4096 Acc: 0.8452
# val Loss: 0.1724 Acc: 0.9259
#
# Epoch 23/199
# ----------
# train Loss: 0.3704 Acc: 0.8535
# val Loss: 0.2272 Acc: 0.9342
#
# Epoch 24/199
# ----------
# train Loss: 0.4159 Acc: 0.8338
# val Loss: 0.2514 Acc: 0.9177
#
# Epoch 25/199
# ----------
# train Loss: 0.3734 Acc: 0.8720
# val Loss: 0.1783 Acc: 0.9424
#
# Epoch 26/199
# ----------
# train Loss: 0.4031 Acc: 0.8493
# val Loss: 0.2872 Acc: 0.8971
#
# Epoch 27/199
# ----------
# train Loss: 0.3378 Acc: 0.8617
# val Loss: 0.2300 Acc: 0.9300
#
# Epoch 28/199
# ----------
# train Loss: 0.4082 Acc: 0.8380
# val Loss: 0.2615 Acc: 0.9218
#
# Epoch 29/199
# ----------
# train Loss: 0.4107 Acc: 0.8431
# val Loss: 0.2256 Acc: 0.9342
#
# Epoch 30/199
# ----------
# train Loss: 0.3678 Acc: 0.8576
# val Loss: 0.3242 Acc: 0.9012
#
# Epoch 31/199
# ----------
# train Loss: 0.3404 Acc: 0.8586
# val Loss: 0.2915 Acc: 0.9095
#
# Epoch 32/199
# ----------
# train Loss: 0.3603 Acc: 0.8607
# val Loss: 0.2106 Acc: 0.9342
#
# Epoch 33/199
# ----------
# train Loss: 0.3657 Acc: 0.8483
# val Loss: 0.2495 Acc: 0.9300
#
# Epoch 34/199
# ----------
# train Loss: 0.4252 Acc: 0.8473
# val Loss: 0.2738 Acc: 0.9053
#
# Epoch 35/199
# ----------
# train Loss: 0.3437 Acc: 0.8700
# val Loss: 0.2950 Acc: 0.9259
#
# Epoch 36/199
# ----------
# train Loss: 0.4447 Acc: 0.8411
# val Loss: 0.2104 Acc: 0.9383
#
# Epoch 37/199
# ----------
# train Loss: 0.3699 Acc: 0.8452
# val Loss: 0.1840 Acc: 0.9342
#
# Epoch 38/199
# ----------
# train Loss: 0.3603 Acc: 0.8607
# val Loss: 0.1697 Acc: 0.9424
#
# Epoch 39/199
# ----------
# train Loss: 0.3230 Acc: 0.8803
# val Loss: 0.1816 Acc: 0.9342
#
# Epoch 40/199
# ----------
# train Loss: 0.3885 Acc: 0.8535
# val Loss: 0.1896 Acc: 0.9383
#
# Epoch 41/199
# ----------
# train Loss: 0.3933 Acc: 0.8555
# val Loss: 0.1586 Acc: 0.9342
#
# Epoch 42/199
# ----------
# train Loss: 0.3886 Acc: 0.8431
# val Loss: 0.2509 Acc: 0.9053
#
# Epoch 43/199
# ----------
# train Loss: 0.4209 Acc: 0.8431
# val Loss: 0.2133 Acc: 0.9259
#
# Epoch 44/199
# ----------
# train Loss: 0.4007 Acc: 0.8524
# val Loss: 0.2312 Acc: 0.9342
#
# Epoch 45/199
# ----------
# train Loss: 0.3816 Acc: 0.8431
# val Loss: 0.1621 Acc: 0.9342
#
# Epoch 46/199
# ----------
# train Loss: 0.3722 Acc: 0.8576
# val Loss: 0.1962 Acc: 0.9300
#
# Epoch 47/199
# ----------
# train Loss: 0.3946 Acc: 0.8524
# val Loss: 0.1955 Acc: 0.9383
#
# Epoch 48/199
# ----------
# train Loss: 0.4026 Acc: 0.8390
# val Loss: 0.1987 Acc: 0.9383
#
# Epoch 49/199
# ----------
# train Loss: 0.3902 Acc: 0.8535
# val Loss: 0.2251 Acc: 0.9259
#
# Epoch 50/199
# ----------
# train Loss: 0.3992 Acc: 0.8483
# val Loss: 0.1940 Acc: 0.9218
#
# Epoch 51/199
# ----------
# train Loss: 0.4327 Acc: 0.8369
# val Loss: 0.1832 Acc: 0.9342
#
# Epoch 52/199
# ----------
# train Loss: 0.4043 Acc: 0.8473
# val Loss: 0.1949 Acc: 0.9383
#
# Epoch 53/199
# ----------
# train Loss: 0.3630 Acc: 0.8824
# val Loss: 0.1695 Acc: 0.9465
#
# Epoch 54/199
# ----------
# train Loss: 0.3904 Acc: 0.8462
# val Loss: 0.2340 Acc: 0.9300
#
# Epoch 55/199
# ----------
# train Loss: 0.4267 Acc: 0.8442
# val Loss: 0.2663 Acc: 0.9342
#
# Epoch 56/199
# ----------
# train Loss: 0.3782 Acc: 0.8669
# val Loss: 0.1990 Acc: 0.9342
#
# Epoch 57/199
# ----------
# train Loss: 0.3581 Acc: 0.8555
# val Loss: 0.2065 Acc: 0.9300
#
# Epoch 58/199
# ----------
# train Loss: 0.3431 Acc: 0.8720
# val Loss: 0.1621 Acc: 0.9383
#
# Epoch 59/199
# ----------
# train Loss: 0.3503 Acc: 0.8689
# val Loss: 0.2337 Acc: 0.9342
#
# Epoch 60/199
# ----------
# train Loss: 0.3785 Acc: 0.8658
# val Loss: 0.1871 Acc: 0.9383
#
# Epoch 61/199
# ----------
# train Loss: 0.3817 Acc: 0.8545
# val Loss: 0.2098 Acc: 0.9218
#
# Epoch 62/199
# ----------
# train Loss: 0.4153 Acc: 0.8421
# val Loss: 0.2048 Acc: 0.9342
#
# Epoch 63/199
# ----------
# train Loss: 0.3665 Acc: 0.8473
# val Loss: 0.2674 Acc: 0.9218
#
# Epoch 64/199
# ----------
# train Loss: 0.4421 Acc: 0.8246
# val Loss: 0.2326 Acc: 0.9300
#
# Epoch 65/199
# ----------
# train Loss: 0.3892 Acc: 0.8669
# val Loss: 0.2247 Acc: 0.9300
#
# Epoch 66/199
# ----------
# train Loss: 0.3591 Acc: 0.8576
# val Loss: 0.2664 Acc: 0.9177
#
# Epoch 67/199
# ----------
# train Loss: 0.3366 Acc: 0.8710
# val Loss: 0.2429 Acc: 0.9259
#
# Epoch 68/199
# ----------
# train Loss: 0.3997 Acc: 0.8535
# val Loss: 0.1850 Acc: 0.9342
#
# Epoch 69/199
# ----------
# train Loss: 0.3799 Acc: 0.8638
# val Loss: 0.1631 Acc: 0.9424
#
# Epoch 70/199
# ----------
# train Loss: 0.3871 Acc: 0.8504
# val Loss: 0.2460 Acc: 0.9218
#
# Epoch 71/199
# ----------
# train Loss: 0.3196 Acc: 0.8772
# val Loss: 0.1583 Acc: 0.9342
#
# Epoch 72/199
# ----------
# train Loss: 0.3907 Acc: 0.8596
# val Loss: 0.3157 Acc: 0.9053
#
# Epoch 73/199
# ----------
# train Loss: 0.3758 Acc: 0.8607
# val Loss: 0.1669 Acc: 0.9342
#
# Epoch 74/199
# ----------
# train Loss: 0.3827 Acc: 0.8473
# val Loss: 0.2317 Acc: 0.9259
#
# Epoch 75/199
# ----------
# train Loss: 0.3667 Acc: 0.8700
# val Loss: 0.2681 Acc: 0.9218
#
# Epoch 76/199
# ----------
# train Loss: 0.3906 Acc: 0.8627
# val Loss: 0.2989 Acc: 0.9095
#
# Epoch 77/199
# ----------
# train Loss: 0.3106 Acc: 0.8854
# val Loss: 0.1583 Acc: 0.9465
#
# Epoch 78/199
# ----------
# train Loss: 0.3543 Acc: 0.8741
# val Loss: 0.2152 Acc: 0.9383
#
# Epoch 79/199
# ----------
# train Loss: 0.4115 Acc: 0.8596
# val Loss: 0.1569 Acc: 0.9506
#
# Epoch 80/199
# ----------
# train Loss: 0.3881 Acc: 0.8545
# val Loss: 0.2269 Acc: 0.9259
#
# Epoch 81/199
# ----------
# train Loss: 0.3811 Acc: 0.8555
# val Loss: 0.2217 Acc: 0.9012
#
# Epoch 82/199
# ----------
# train Loss: 0.3636 Acc: 0.8617
# val Loss: 0.1724 Acc: 0.9465
#
# Epoch 83/199
# ----------
# train Loss: 0.3501 Acc: 0.8648
# val Loss: 0.1875 Acc: 0.9465
#
# Epoch 84/199
# ----------
# train Loss: 0.3429 Acc: 0.8720
# val Loss: 0.2225 Acc: 0.9383
#
# Epoch 85/199
# ----------
# train Loss: 0.3556 Acc: 0.8679
# val Loss: 0.2025 Acc: 0.9342
#
# Epoch 86/199
# ----------
# train Loss: 0.4395 Acc: 0.8493
# val Loss: 0.2161 Acc: 0.9424
#
# Epoch 87/199
# ----------
# train Loss: 0.3795 Acc: 0.8473
# val Loss: 0.3170 Acc: 0.9177
#
# Epoch 88/199
# ----------
# train Loss: 0.3979 Acc: 0.8462
# val Loss: 0.2264 Acc: 0.9300
#
# Epoch 89/199
# ----------
# train Loss: 0.3777 Acc: 0.8813
# val Loss: 0.1831 Acc: 0.9506
#
# Epoch 90/199
# ----------
# train Loss: 0.3481 Acc: 0.8762
# val Loss: 0.1611 Acc: 0.9506
#
# Epoch 91/199
# ----------
# train Loss: 0.3919 Acc: 0.8514
# val Loss: 0.1972 Acc: 0.9383
#
# Epoch 92/199
# ----------
# train Loss: 0.4170 Acc: 0.8411
# val Loss: 0.1779 Acc: 0.9342
#
# Epoch 93/199
# ----------
# train Loss: 0.4099 Acc: 0.8607
# val Loss: 0.1509 Acc: 0.9424
#
# Epoch 94/199
# ----------
# train Loss: 0.4105 Acc: 0.8493
# val Loss: 0.1749 Acc: 0.9424
#
# Epoch 95/199
# ----------
# train Loss: 0.3948 Acc: 0.8421
# val Loss: 0.1481 Acc: 0.9465
#
# Epoch 96/199
# ----------
# train Loss: 0.3925 Acc: 0.8555
# val Loss: 0.2377 Acc: 0.9218
#
# Epoch 97/199
# ----------
# train Loss: 0.3429 Acc: 0.8700
# val Loss: 0.2110 Acc: 0.9383
#
# Epoch 98/199
# ----------
# train Loss: 0.3578 Acc: 0.8658
# val Loss: 0.1817 Acc: 0.9342
#
# Epoch 99/199
# ----------
# train Loss: 0.3861 Acc: 0.8576
# val Loss: 0.1740 Acc: 0.9465
#
# Epoch 100/199
# ----------
# train Loss: 0.4407 Acc: 0.8308
# val Loss: 0.1705 Acc: 0.9424
#
# Epoch 101/199
# ----------
# train Loss: 0.3699 Acc: 0.8596
# val Loss: 0.3487 Acc: 0.9053
#
# Epoch 102/199
# ----------
# train Loss: 0.3539 Acc: 0.8576
# val Loss: 0.2672 Acc: 0.9300
#
# Epoch 103/199
# ----------
# train Loss: 0.3694 Acc: 0.8483
# val Loss: 0.2446 Acc: 0.9259
#
# Epoch 104/199
# ----------
# train Loss: 0.4171 Acc: 0.8442
# val Loss: 0.2267 Acc: 0.9218
#
# Epoch 105/199
# ----------
# train Loss: 0.3748 Acc: 0.8545
# val Loss: 0.2227 Acc: 0.9342
#
# Epoch 106/199
# ----------
# train Loss: 0.3550 Acc: 0.8700
# val Loss: 0.1699 Acc: 0.9424
#
# Epoch 107/199
# ----------
# train Loss: 0.3468 Acc: 0.8782
# val Loss: 0.1711 Acc: 0.9424
#
# Epoch 108/199
# ----------
# train Loss: 0.3187 Acc: 0.8669
# val Loss: 0.2244 Acc: 0.9342
#
# Epoch 109/199
# ----------
# train Loss: 0.3871 Acc: 0.8473
# val Loss: 0.2051 Acc: 0.9424
#
# Epoch 110/199
# ----------
# train Loss: 0.3349 Acc: 0.8803
# val Loss: 0.2381 Acc: 0.9259
#
# Epoch 111/199
# ----------
# train Loss: 0.4756 Acc: 0.8442
# val Loss: 0.2978 Acc: 0.9095
#
# Epoch 112/199
# ----------
# train Loss: 0.4256 Acc: 0.8338
# val Loss: 0.3011 Acc: 0.9136
#
# Epoch 113/199
# ----------
# train Loss: 0.4153 Acc: 0.8566
# val Loss: 0.3055 Acc: 0.9177
#
# Epoch 114/199
# ----------
# train Loss: 0.3580 Acc: 0.8566
# val Loss: 0.1744 Acc: 0.9506
#
# Epoch 115/199
# ----------
# train Loss: 0.4089 Acc: 0.8596
# val Loss: 0.2480 Acc: 0.9259
#
# Epoch 116/199
# ----------
# train Loss: 0.3764 Acc: 0.8627
# val Loss: 0.2350 Acc: 0.9342
#
# Epoch 117/199
# ----------
# train Loss: 0.3499 Acc: 0.8576
# val Loss: 0.2254 Acc: 0.9259
#
# Epoch 118/199
# ----------
# train Loss: 0.3600 Acc: 0.8586
# val Loss: 0.1969 Acc: 0.9342
#
# Epoch 119/199
# ----------
# train Loss: 0.3320 Acc: 0.8844
# val Loss: 0.1954 Acc: 0.9506
#
# Epoch 120/199
# ----------
# train Loss: 0.3909 Acc: 0.8535
# val Loss: 0.2860 Acc: 0.9177
#
# Epoch 121/199
# ----------
# train Loss: 0.4498 Acc: 0.8504
# val Loss: 0.1888 Acc: 0.9300
#
# Epoch 122/199
# ----------
# train Loss: 0.3773 Acc: 0.8545
# val Loss: 0.1841 Acc: 0.9300
#
# Epoch 123/199
# ----------
# train Loss: 0.3910 Acc: 0.8617
# val Loss: 0.2052 Acc: 0.9424
#
# Epoch 124/199
# ----------
# train Loss: 0.3805 Acc: 0.8669
# val Loss: 0.1919 Acc: 0.9424
#
# Epoch 125/199
# ----------
# train Loss: 0.3631 Acc: 0.8648
# val Loss: 0.2784 Acc: 0.9136
#
# Epoch 126/199
# ----------
# train Loss: 0.3850 Acc: 0.8658
# val Loss: 0.1684 Acc: 0.9424
#
# Epoch 127/199
# ----------
# train Loss: 0.4191 Acc: 0.8514
# val Loss: 0.2875 Acc: 0.9218
#
# Epoch 128/199
# ----------
# train Loss: 0.3345 Acc: 0.8772
# val Loss: 0.3487 Acc: 0.9177
#
# Epoch 129/199
# ----------
# train Loss: 0.3802 Acc: 0.8576
# val Loss: 0.1800 Acc: 0.9424
#
# Epoch 130/199
# ----------
# train Loss: 0.3765 Acc: 0.8648
# val Loss: 0.1755 Acc: 0.9506
#
# Epoch 131/199
# ----------
# train Loss: 0.3695 Acc: 0.8793
# val Loss: 0.3135 Acc: 0.9177
#
# Epoch 132/199
# ----------
# train Loss: 0.3739 Acc: 0.8545
# val Loss: 0.2266 Acc: 0.9342
#
# Epoch 133/199
# ----------
# train Loss: 0.4436 Acc: 0.8318
# val Loss: 0.2112 Acc: 0.9300
#
# Epoch 134/199
# ----------
# train Loss: 0.3405 Acc: 0.8638
# val Loss: 0.2063 Acc: 0.9218
#
# Epoch 135/199
# ----------
# train Loss: 0.3875 Acc: 0.8679
# val Loss: 0.1695 Acc: 0.9424
#
# Epoch 136/199
# ----------
# train Loss: 0.4356 Acc: 0.8369
# val Loss: 0.1524 Acc: 0.9547
#
# Epoch 137/199
# ----------
# train Loss: 0.4103 Acc: 0.8545
# val Loss: 0.1867 Acc: 0.9383
#
# Epoch 138/199
# ----------
# train Loss: 0.4018 Acc: 0.8648
# val Loss: 0.1729 Acc: 0.9465
#
# Epoch 139/199
# ----------
# train Loss: 0.3905 Acc: 0.8586
# val Loss: 0.2742 Acc: 0.9259
#
# Epoch 140/199
# ----------
# train Loss: 0.3589 Acc: 0.8566
# val Loss: 0.1926 Acc: 0.9465
#
# Epoch 141/199
# ----------
# train Loss: 0.3461 Acc: 0.8731
# val Loss: 0.2095 Acc: 0.9424
#
# Epoch 142/199
# ----------
# train Loss: 0.3810 Acc: 0.8679
# val Loss: 0.1945 Acc: 0.9383
#
# Epoch 143/199
# ----------
# train Loss: 0.3473 Acc: 0.8762
# val Loss: 0.2206 Acc: 0.9383
#
# Epoch 144/199
# ----------
# train Loss: 0.3594 Acc: 0.8669
# val Loss: 0.1906 Acc: 0.9342
#
# Epoch 145/199
# ----------
# train Loss: 0.3563 Acc: 0.8555
# val Loss: 0.1640 Acc: 0.9465
#
# Epoch 146/199
# ----------
# train Loss: 0.3533 Acc: 0.8607
# val Loss: 0.2471 Acc: 0.9218
#
# Epoch 147/199
# ----------
# train Loss: 0.3482 Acc: 0.8751
# val Loss: 0.1860 Acc: 0.9424
#
# Epoch 148/199
# ----------
# train Loss: 0.3756 Acc: 0.8627
# val Loss: 0.1809 Acc: 0.9506
#
# Epoch 149/199
# ----------
# train Loss: 0.3334 Acc: 0.8772
# val Loss: 0.1559 Acc: 0.9588
#
# Epoch 150/199
# ----------
# train Loss: 0.3664 Acc: 0.8669
# val Loss: 0.1934 Acc: 0.9424
#
# Epoch 151/199
# ----------
# train Loss: 0.3857 Acc: 0.8638
# val Loss: 0.1991 Acc: 0.9424
#
# Epoch 152/199
# ----------
# train Loss: 0.4453 Acc: 0.8576
# val Loss: 0.1806 Acc: 0.9383
#
# Epoch 153/199
# ----------
# train Loss: 0.3813 Acc: 0.8638
# val Loss: 0.1592 Acc: 0.9300
#
# Epoch 154/199
# ----------
# train Loss: 0.3889 Acc: 0.8596
# val Loss: 0.2073 Acc: 0.9383
#
# Epoch 155/199
# ----------
# train Loss: 0.3552 Acc: 0.8658
# val Loss: 0.1458 Acc: 0.9465
#
# Epoch 156/199
# ----------
# train Loss: 0.3942 Acc: 0.8524
# val Loss: 0.1587 Acc: 0.9383
#
# Epoch 157/199
# ----------
# train Loss: 0.3605 Acc: 0.8638
# val Loss: 0.2122 Acc: 0.9342
#
# Epoch 158/199
# ----------
# train Loss: 0.3734 Acc: 0.8638
# val Loss: 0.2141 Acc: 0.9300
#
# Epoch 159/199
# ----------
# train Loss: 0.3745 Acc: 0.8535
# val Loss: 0.3178 Acc: 0.9218
#
# Epoch 160/199
# ----------
# train Loss: 0.3986 Acc: 0.8596
# val Loss: 0.3047 Acc: 0.9177
#
# Epoch 161/199
# ----------
# train Loss: 0.3866 Acc: 0.8648
# val Loss: 0.2253 Acc: 0.9218
#
# Epoch 162/199
# ----------
# train Loss: 0.3461 Acc: 0.8762
# val Loss: 0.2486 Acc: 0.9342
#
# Epoch 163/199
# ----------
# train Loss: 0.3761 Acc: 0.8782
# val Loss: 0.1932 Acc: 0.9424
#
# Epoch 164/199
# ----------
# train Loss: 0.3874 Acc: 0.8607
# val Loss: 0.1525 Acc: 0.9465
#
# Epoch 165/199
# ----------
# train Loss: 0.3668 Acc: 0.8627
# val Loss: 0.1894 Acc: 0.9342
#
# Epoch 166/199
# ----------
# train Loss: 0.4056 Acc: 0.8596
# val Loss: 0.1704 Acc: 0.9383
#
# Epoch 167/199
# ----------
# train Loss: 0.3816 Acc: 0.8700
# val Loss: 0.1820 Acc: 0.9383
#
# Epoch 168/199
# ----------
# train Loss: 0.3573 Acc: 0.8700
# val Loss: 0.2065 Acc: 0.9424
#
# Epoch 169/199
# ----------
# train Loss: 0.4190 Acc: 0.8514
# val Loss: 0.2386 Acc: 0.9300
#
# Epoch 170/199
# ----------
# train Loss: 0.4052 Acc: 0.8390
# val Loss: 0.1461 Acc: 0.9506
#
# Epoch 171/199
# ----------
# train Loss: 0.3664 Acc: 0.8658
# val Loss: 0.2419 Acc: 0.9259
#
# Epoch 172/199
# ----------
# train Loss: 0.3984 Acc: 0.8524
# val Loss: 0.2458 Acc: 0.9300
#
# Epoch 173/199
# ----------
# train Loss: 0.4263 Acc: 0.8545
# val Loss: 0.2113 Acc: 0.9383
#
# Epoch 174/199
# ----------
# train Loss: 0.3434 Acc: 0.8731
# val Loss: 0.1624 Acc: 0.9506
#
# Epoch 175/199
# ----------
# train Loss: 0.3388 Acc: 0.8793
# val Loss: 0.2259 Acc: 0.9383
#
# Epoch 176/199
# ----------
# train Loss: 0.4166 Acc: 0.8473
# val Loss: 0.1729 Acc: 0.9424
#
# Epoch 177/199
# ----------
# train Loss: 0.4004 Acc: 0.8535
# val Loss: 0.3603 Acc: 0.9053
#
# Epoch 178/199
# ----------
# train Loss: 0.3760 Acc: 0.8535
# val Loss: 0.2376 Acc: 0.9259
#
# Epoch 179/199
# ----------
# train Loss: 0.3517 Acc: 0.8627
# val Loss: 0.1505 Acc: 0.9506
#
# Epoch 180/199
# ----------
# train Loss: 0.3133 Acc: 0.8854
# val Loss: 0.1703 Acc: 0.9547
#
# Epoch 181/199
# ----------
# train Loss: 0.3852 Acc: 0.8442
# val Loss: 0.2832 Acc: 0.9136
#
# Epoch 182/199
# ----------
# train Loss: 0.3349 Acc: 0.8638
# val Loss: 0.2250 Acc: 0.9383
#
# Epoch 183/199
# ----------
# train Loss: 0.3736 Acc: 0.8658
# val Loss: 0.1637 Acc: 0.9506
#
# Epoch 184/199
# ----------
# train Loss: 0.4166 Acc: 0.8524
# val Loss: 0.1866 Acc: 0.9424
#
# Epoch 185/199
# ----------
# train Loss: 0.3599 Acc: 0.8679
# val Loss: 0.1682 Acc: 0.9465
#
# Epoch 186/199
# ----------
# train Loss: 0.3916 Acc: 0.8411
# val Loss: 0.1860 Acc: 0.9547
#
# Epoch 187/199
# ----------
# train Loss: 0.4010 Acc: 0.8679
# val Loss: 0.1660 Acc: 0.9465
#
# Epoch 188/199
# ----------
# train Loss: 0.3566 Acc: 0.8658
# val Loss: 0.1805 Acc: 0.9506
#
# Epoch 189/199
# ----------
# train Loss: 0.3648 Acc: 0.8638
# val Loss: 0.2204 Acc: 0.9383
#
# Epoch 190/199
# ----------
# train Loss: 0.3496 Acc: 0.8617
# val Loss: 0.2036 Acc: 0.9300
#
# Epoch 191/199
# ----------
# train Loss: 0.3532 Acc: 0.8762
# val Loss: 0.1627 Acc: 0.9465
#
# Epoch 192/199
# ----------
# train Loss: 0.4160 Acc: 0.8380
# val Loss: 0.2473 Acc: 0.9300
#
# Epoch 193/199
# ----------
# train Loss: 0.3841 Acc: 0.8586
# val Loss: 0.2051 Acc: 0.9342
#
# Epoch 194/199
# ----------
# train Loss: 0.3382 Acc: 0.8720
# val Loss: 0.1523 Acc: 0.9465
#
# Epoch 195/199
# ----------
# train Loss: 0.3965 Acc: 0.8596
# val Loss: 0.1861 Acc: 0.9300
#
# Epoch 196/199
# ----------
# train Loss: 0.3862 Acc: 0.8596
# val Loss: 0.1763 Acc: 0.9506
#
# Epoch 197/199
# ----------
# train Loss: 0.3980 Acc: 0.8535
# val Loss: 0.2556 Acc: 0.9136
#
# Epoch 198/199
# ----------
# train Loss: 0.3902 Acc: 0.8400
# val Loss: 0.1741 Acc: 0.9300
#
# Epoch 199/199
# ----------
# train Loss: 0.3495 Acc: 0.8741
# val Loss: 0.1648 Acc: 0.9547
#
# Training complete in 98m 58s
# Best val Acc: 0.958848

# %%
visualize_model(model_ft)
