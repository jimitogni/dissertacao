# %% [markdown]
# - Hatmap
# - Melhorar o plot de imagens
# - Propor algo novo

# %%
from __future__ import print_function
from __future__ import division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy 
import cv2
from torch.autograd import Variable
import random
import shutil, sys
import pandas as pd
from PIL import Image
from PIL import ImageFile
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# Top level data directory. Here we assume the format of the directory conforms
#   to the ImageFolder structure
data_dir = '/home/jimi/dissertacao/covid19/datasets/80-20/'

# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet, inception]
#model_name = "densenet"

# Number of classes in the dataset
#num_classes = 3

# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Number of epochs to train for


# Flag for feature extracting. When False, we finetune the whole model,
#   when True we only update the reshaped layer params
feature_extract = True

#num_epochs = 500

# %%
# Data augmentation and normalization for training
# Just normalization for validation
#transforms.RandomRotation(degrees=(-5, 5)),
#transforms.ColorJitter(brightness=.02),
    
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor()
    ]),
    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor()
    ]),
    'test': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor()
    ])
}

print("Initializing Datasets and Dataloaders...")

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x]) for x in ['train', 'val', 'test']}

# Create training and validation dataloaders
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], 
                    batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val', 'test']}

class_names = image_datasets['train'].classes

# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Initializing Datasets and Dataloaders...

# %%
# Path to data
data_dir = '/home/jimi/dissertacao/covid19/datasets/80-20/'
train_dir = data_dir+'train/'
test_dir = data_dir+'test/'
val_dir = data_dir+'val/'

normal_dir = data_dir+'normal/'
pneumonia_dir = data_dir+'pneumonia/'
covid_dir = data_dir+'covid/'

len_covid = len([iq for iq in os.scandir(normal_dir)])
len_normal = len([iq for iq in os.scandir(pneumonia_dir)])
len_pneumonia = len([iq for iq in os.scandir(covid_dir)])

len_train_dir = len([iq for iq in os.scandir(train_dir+'covid/')]) + len([iq for iq in os.scandir(train_dir+'normal/')]) + len([iq for iq in os.scandir(train_dir+'pneumonia/')])
len_test_dir = len([iq for iq in os.scandir(test_dir+'covid/')]) + len([iq for iq in os.scandir(test_dir+'normal/')]) + len([iq for iq in os.scandir(test_dir+'pneumonia/')])
len_val_dir = len([iq for iq in os.scandir(val_dir+'covid/')]) + len([iq for iq in os.scandir(val_dir+'normal/')]) + len([iq for iq in os.scandir(val_dir+'pneumonia/')])

print('Files per classes')
print("----"*10)
print("normal : ", len_covid)

print("pneumonia : ", len_normal)

print("covid : ", len_pneumonia)

print("-"*20)

print('Train, test, validation')

print("-"*20)

print("len_train_dir : ", len_train_dir)

print("len_test_dir : ", len_test_dir)

print("len_val_dir : ", len_val_dir)
# Out:
# Files per classes
# ----------------------------------------
# normal :  4023
# pneumonia :  4035
# covid :  4105
# --------------------
# Train, test, validation
# --------------------
# len_train_dir :  9632
# len_test_dir :  31
# len_val_dir :  2409

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs, model_name, lr, batch_size):
    since = time.time()
    is_inception = False
    
    #tensorboard
    writer = SummaryWriter(f'runs/dg_{model_name}_lr={lr}_epoch={num_epochs}_batch_size={batch_size}')
    step = 0

    val_acc_history = []
    val_loss_history = []

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        
        print('-' * 10)
        

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()
                
                # wrap them in Variable
                #inputs, labels = Variable(inputs), Variable(labels)

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    # Special case for inception because in training it has an auxiliary output. In train
                    #   mode we calculate the loss by summing the final output and the auxiliary output
                    #   but in testing we only consider the final output.
                    if is_inception and phase == 'train':
                        # From https://discuss.pytorch.org/t/how-to-optimize-inception-model-with-auxiliary-classifiers/7958
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + 0.4*loss2
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                
                if epoch % 1000 == 999:    # every 1000 mini-batches...
                    # ...log a Matplotlib Figure showing the model's predictions on a
                    # random mini-batch
                    writer.add_figure('predictions vs. actuals',
                                    plot_classes_preds(net, inputs, labels),
                                    global_step=epoch * len(trainloader) + i)
                    

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            writer.add_scalar('training loss', loss, global_step=step)
            writer.add_scalar('training accuracy', epoch_acc, global_step=step)
            step += 1
            
            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()
        
        
    time_elapsed = time.time() - since
    print()
    print('#'*30)
    print('------ Summary ------')
    print(f'model -> {_model}')
    print(f'epochs -> {_epochs}')
    print(f'lr -> {_lrs}')
    print(f'batch size -> {_batch}')
    print()
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))
    print('#'*30)
    print()
    print('==== END ====')
    

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
def visualize_model(model, num_images=4):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 3, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet18
        """
        model_ft = models.resnet18(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "alexnet":
        """ Alexnet
        """
        model_ft = models.alexnet(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "vgg":
        """ VGG11_bn
        """
        model_ft = models.vgg11_bn(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "squeezenet":
        """ Squeezenet
        """
        model_ft = models.squeezenet1_0(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        model_ft.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        
        model_ft.num_classes = num_classes
        input_size = 224

    elif model_name == "densenet":
        """ Densenet
        """
        model_ft = models.densenet121(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "inception":
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        """
        model_ft = models.inception_v3(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        # Handle the auxilary net
        num_ftrs = model_ft.AuxLogits.fc.in_features
        model_ft.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs,num_classes)
        input_size = 299

    else:
        print("Invalid model name, exiting...")
        exit()

    return model_ft, input_size

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__() 
        #img = images
        self.fc=nn.Linear(512,3)

    
    def forward(self,x):     
        x=x.view(512,7*7).mean(1).view(1,-1)
        x=self.fc(x)
        return  F.softmax(x,dim=1)

# %%
trainable_parameters = []
for name, p in model_ft.named_parameters():
    if "fc" in name:
        trainable_parameters.append(p)

# %%
params = list(Net().parameters())
weight = np.squeeze(params[-1].data.numpy())

# %%
# Models to choose from [resnet, alexnet, vgg, squeezenet, densenet, inception]
num_classes = 3

_models = ['squeezenet']
lrs = [1e-4]
_epoch = [500]
batch_sizes = [16]

for _model in _models:
    for _epochs in _epoch:
        for _lrs in lrs:
            for _batch in batch_sizes:
                               
                print()
                print()
                print()
                print('='*60)
                print('==== INITIALIZING WITH PARAMETERS: ====')
                print()
                print(f'model -> {_model}')
                print(f'epochs -> {_epochs}')
                print(f'lr -> {_lrs}')
                print(f'batch size -> {_batch}')
                print()
                
                feature_extract = True
                
                #teste heat map
                mod = nn.Sequential(*list(model_ft.children())[:-1])
                
                model_ft=nn.Sequential(mod,Net())
                
                model_ft, input_size = initialize_model(_model, num_classes, 
                                                        feature_extract, use_pretrained=True)
                
                # Send the model to GPU
                model_ft = model_ft.to(device)

                print('-'*20)
                params_to_update = model_ft.parameters()
                print("Params to learn:")
                if feature_extract:
                    params_to_update = []
                    for name,param in model_ft.named_parameters():
                        if param.requires_grad == True:
                            params_to_update.append(param)
                            print("\t",name)
                else:
                    for name,param in model_ft.named_parameters():
                        if param.requires_grad == True:
                            print("\t",name)

                print()
                
                print('-'*20)
                
                print()
                print('== Epochs ==')
                
                optimizer_ft = optim.SGD(params_to_update, _lrs, momentum=0.9)
                exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=10, gamma=0.1)

                criterion = nn.CrossEntropyLoss()

                model_ft, hist = train_model(model_ft, dataloaders, criterion, optimizer_ft,
                                             num_epochs=_epochs, model_name=_model, lr=_lrs, batch_size=_batch)
# Out:
# ============================================================
# ==== INITIALIZING WITH PARAMETERS: ====
#
# model -> squeezenet
# epochs -> 500
# lr -> 0.0001
# batch size -> 16
#
# --------------------
# Params to learn:
# 	 classifier.1.weight
# 	 classifier.1.bias
#
# --------------------
#
# == Epochs ==
# Epoch 0/499
# ----------
# train Loss: 0.4416 Acc: 0.8411
# val Loss: 0.3257 Acc: 0.8804
#
# Epoch 1/499
# ----------
# train Loss: 0.2505 Acc: 0.9177
# val Loss: 0.2059 Acc: 0.9377
#
# Epoch 2/499
# ----------
# train Loss: 0.2168 Acc: 0.9281
# val Loss: 0.1874 Acc: 0.9435
#
# Epoch 3/499
# ----------
# train Loss: 0.1996 Acc: 0.9332
# val Loss: 0.1648 Acc: 0.9469
#
# Epoch 4/499
# ----------
# train Loss: 0.1859 Acc: 0.9377
# val Loss: 0.1453 Acc: 0.9568
#
# Epoch 5/499
# ----------
# train Loss: 0.1792 Acc: 0.9394
# val Loss: 0.1403 Acc: 0.9589
#
# Epoch 6/499
# ----------
# train Loss: 0.1721 Acc: 0.9418
# val Loss: 0.1404 Acc: 0.9539
#
# Epoch 7/499
# ----------
# train Loss: 0.1683 Acc: 0.9425
# val Loss: 0.1286 Acc: 0.9610
#
# Epoch 8/499
# ----------
# train Loss: 0.1614 Acc: 0.9436
# val Loss: 0.1325 Acc: 0.9597
#
# Epoch 9/499
# ----------
# train Loss: 0.1590 Acc: 0.9445
# val Loss: 0.1490 Acc: 0.9506
#
# Epoch 10/499
# ----------
# train Loss: 0.1539 Acc: 0.9480
# val Loss: 0.1259 Acc: 0.9601
#
# Epoch 11/499
# ----------
# train Loss: 0.1511 Acc: 0.9487
# val Loss: 0.1211 Acc: 0.9639
#
# Epoch 12/499
# ----------
# train Loss: 0.1526 Acc: 0.9486
# val Loss: 0.1146 Acc: 0.9635
#
# Epoch 13/499
# ----------
# train Loss: 0.1498 Acc: 0.9454
# val Loss: 0.1137 Acc: 0.9647
#
# Epoch 14/499
# ----------
# train Loss: 0.1452 Acc: 0.9494
# val Loss: 0.1363 Acc: 0.9539
#
# Epoch 15/499
# ----------
# train Loss: 0.1394 Acc: 0.9526
# val Loss: 0.1111 Acc: 0.9660
#
# Epoch 16/499
# ----------
# train Loss: 0.1398 Acc: 0.9512
# val Loss: 0.1104 Acc: 0.9660
#
# Epoch 17/499
# ----------
# train Loss: 0.1421 Acc: 0.9504
# val Loss: 0.1181 Acc: 0.9618
#
# Epoch 18/499
# ----------
# train Loss: 0.1353 Acc: 0.9553
# val Loss: 0.1072 Acc: 0.9660
#
# Epoch 19/499
# ----------
# train Loss: 0.1353 Acc: 0.9537
# val Loss: 0.1057 Acc: 0.9647
#
# Epoch 20/499
# ----------
# train Loss: 0.1326 Acc: 0.9533
# val Loss: 0.1116 Acc: 0.9631
#
# Epoch 21/499
# ----------
# train Loss: 0.1337 Acc: 0.9525
# val Loss: 0.1090 Acc: 0.9651
#
# Epoch 22/499
# ----------
# train Loss: 0.1351 Acc: 0.9529
# val Loss: 0.1055 Acc: 0.9655
#
# Epoch 23/499
# ----------
# train Loss: 0.1334 Acc: 0.9521
# val Loss: 0.1337 Acc: 0.9535
#
# Epoch 24/499
# ----------
# train Loss: 0.1317 Acc: 0.9541
# val Loss: 0.1006 Acc: 0.9672
#
# Epoch 25/499
# ----------
# train Loss: 0.1281 Acc: 0.9555
# val Loss: 0.0996 Acc: 0.9697
#
# Epoch 26/499
# ----------
# train Loss: 0.1265 Acc: 0.9564
# val Loss: 0.1130 Acc: 0.9626
#
# Epoch 27/499
# ----------
# train Loss: 0.1323 Acc: 0.9536
# val Loss: 0.1019 Acc: 0.9647
#
# Epoch 28/499
# ----------
# train Loss: 0.1281 Acc: 0.9548
# val Loss: 0.1051 Acc: 0.9660
#
# Epoch 29/499
# ----------
# train Loss: 0.1296 Acc: 0.9537
# val Loss: 0.1043 Acc: 0.9639
#
# Epoch 30/499
# ----------
# train Loss: 0.1262 Acc: 0.9576
# val Loss: 0.1099 Acc: 0.9643
#
# Epoch 31/499
# ----------
# train Loss: 0.1225 Acc: 0.9584
# val Loss: 0.1166 Acc: 0.9606
#
# Epoch 32/499
# ----------
# train Loss: 0.1249 Acc: 0.9554
# val Loss: 0.0951 Acc: 0.9693
#
# Epoch 33/499
# ----------
# train Loss: 0.1252 Acc: 0.9551
# val Loss: 0.1005 Acc: 0.9672
#
# Epoch 34/499
# ----------
# train Loss: 0.1226 Acc: 0.9569
# val Loss: 0.0977 Acc: 0.9672
#
# Epoch 35/499
# ----------
# train Loss: 0.1184 Acc: 0.9590
# val Loss: 0.0938 Acc: 0.9705
#
# Epoch 36/499
# ----------
# train Loss: 0.1207 Acc: 0.9575
# val Loss: 0.1036 Acc: 0.9668
#
# Epoch 37/499
# ----------
# train Loss: 0.1204 Acc: 0.9588
# val Loss: 0.0940 Acc: 0.9676
#
# Epoch 38/499
# ----------
# train Loss: 0.1225 Acc: 0.9573
# val Loss: 0.0940 Acc: 0.9705
#
# Epoch 39/499
# ----------
# train Loss: 0.1186 Acc: 0.9592
# val Loss: 0.1015 Acc: 0.9672
#
# Epoch 40/499
# ----------
# train Loss: 0.1205 Acc: 0.9578
# val Loss: 0.1111 Acc: 0.9626
#
# Epoch 41/499
# ----------
# train Loss: 0.1175 Acc: 0.9590
# val Loss: 0.0994 Acc: 0.9664
#
# Epoch 42/499
# ----------
# train Loss: 0.1224 Acc: 0.9590
# val Loss: 0.0920 Acc: 0.9705
#
# Epoch 43/499
# ----------
# train Loss: 0.1186 Acc: 0.9588
# val Loss: 0.0910 Acc: 0.9718
#
# Epoch 44/499
# ----------
# train Loss: 0.1186 Acc: 0.9593
# val Loss: 0.0903 Acc: 0.9714
#
# Epoch 45/499
# ----------
# train Loss: 0.1175 Acc: 0.9577
# val Loss: 0.0923 Acc: 0.9664
#
# Epoch 46/499
# ----------
# train Loss: 0.1143 Acc: 0.9597
# val Loss: 0.1055 Acc: 0.9635
#
# Epoch 47/499
# ----------
# train Loss: 0.1149 Acc: 0.9610
# val Loss: 0.0897 Acc: 0.9714
#
# Epoch 48/499
# ----------
# train Loss: 0.1143 Acc: 0.9615
# val Loss: 0.0907 Acc: 0.9722
#
# Epoch 49/499
# ----------
# train Loss: 0.1140 Acc: 0.9584
# val Loss: 0.1008 Acc: 0.9664
#
# Epoch 50/499
# ----------
# train Loss: 0.1166 Acc: 0.9596
# val Loss: 0.0930 Acc: 0.9676
#
# Epoch 51/499
# ----------
# train Loss: 0.1111 Acc: 0.9601
# val Loss: 0.0912 Acc: 0.9676
#
# Epoch 52/499
# ----------
# train Loss: 0.1126 Acc: 0.9591
# val Loss: 0.0891 Acc: 0.9705
#
# Epoch 53/499
# ----------
# train Loss: 0.1142 Acc: 0.9587
# val Loss: 0.0987 Acc: 0.9668
#
# Epoch 54/499
# ----------
# train Loss: 0.1143 Acc: 0.9597
# val Loss: 0.0888 Acc: 0.9709
#
# Epoch 55/499
# ----------
# train Loss: 0.1156 Acc: 0.9604
# val Loss: 0.0889 Acc: 0.9722
#
# Epoch 56/499
# ----------
# train Loss: 0.1142 Acc: 0.9594
# val Loss: 0.0913 Acc: 0.9680
#
# Epoch 57/499
# ----------
# train Loss: 0.1125 Acc: 0.9602
# val Loss: 0.0878 Acc: 0.9747
#
# Epoch 58/499
# ----------
# train Loss: 0.1105 Acc: 0.9613
# val Loss: 0.0859 Acc: 0.9722
#
# Epoch 59/499
# ----------
# train Loss: 0.1117 Acc: 0.9611
# val Loss: 0.0865 Acc: 0.9714
#
# Epoch 60/499
# ----------
# train Loss: 0.1116 Acc: 0.9597
# val Loss: 0.0858 Acc: 0.9726
#
# Epoch 61/499
# ----------
# train Loss: 0.1118 Acc: 0.9615
# val Loss: 0.0858 Acc: 0.9709
#
# Epoch 62/499
# ----------
# train Loss: 0.1131 Acc: 0.9610
# val Loss: 0.0941 Acc: 0.9680
#
# Epoch 63/499
# ----------
# train Loss: 0.1138 Acc: 0.9593
# val Loss: 0.0844 Acc: 0.9726
#
# Epoch 64/499
# ----------
# train Loss: 0.1128 Acc: 0.9615
# val Loss: 0.0909 Acc: 0.9693
#
# Epoch 65/499
# ----------
# train Loss: 0.1082 Acc: 0.9619
# val Loss: 0.0889 Acc: 0.9693
#
# Epoch 66/499
# ----------
# train Loss: 0.1099 Acc: 0.9626
# val Loss: 0.0855 Acc: 0.9743
#
# Epoch 67/499
# ----------
# train Loss: 0.1125 Acc: 0.9602
# val Loss: 0.0845 Acc: 0.9718
#
# Epoch 68/499
# ----------
# train Loss: 0.1094 Acc: 0.9617
# val Loss: 0.0840 Acc: 0.9730
#
# Epoch 69/499
# ----------
# train Loss: 0.1108 Acc: 0.9612
# val Loss: 0.0843 Acc: 0.9730
#
# Epoch 70/499
# ----------
# train Loss: 0.1097 Acc: 0.9607
# val Loss: 0.0884 Acc: 0.9722
#
# Epoch 71/499
# ----------
# train Loss: 0.1097 Acc: 0.9595
# val Loss: 0.0826 Acc: 0.9738
#
# Epoch 72/499
# ----------
# train Loss: 0.1074 Acc: 0.9618
# val Loss: 0.0830 Acc: 0.9738
#
# Epoch 73/499
# ----------
# train Loss: 0.1073 Acc: 0.9624
# val Loss: 0.0842 Acc: 0.9722
#
# Epoch 74/499
# ----------
# train Loss: 0.1087 Acc: 0.9608
# val Loss: 0.0839 Acc: 0.9730
#
# Epoch 75/499
# ----------
# train Loss: 0.1060 Acc: 0.9632
# val Loss: 0.0830 Acc: 0.9734
#
# Epoch 76/499
# ----------
# train Loss: 0.1089 Acc: 0.9621
# val Loss: 0.0837 Acc: 0.9714
#
# Epoch 77/499
# ----------
# train Loss: 0.1064 Acc: 0.9635
# val Loss: 0.0907 Acc: 0.9685
#
# Epoch 78/499
# ----------
# train Loss: 0.1077 Acc: 0.9635
# val Loss: 0.0823 Acc: 0.9730
#
# Epoch 79/499
# ----------
# train Loss: 0.1045 Acc: 0.9619
# val Loss: 0.0936 Acc: 0.9685
#
# Epoch 80/499
# ----------
# train Loss: 0.1078 Acc: 0.9621
# val Loss: 0.0832 Acc: 0.9730
#
# Epoch 81/499
# ----------
# train Loss: 0.1054 Acc: 0.9641
# val Loss: 0.0869 Acc: 0.9676
#
# Epoch 82/499
# ----------
# train Loss: 0.1048 Acc: 0.9618
# val Loss: 0.0835 Acc: 0.9743
#
# Epoch 83/499
# ----------
# train Loss: 0.1057 Acc: 0.9624
# val Loss: 0.0947 Acc: 0.9664
#
# Epoch 84/499
# ----------
# train Loss: 0.1090 Acc: 0.9627
# val Loss: 0.0891 Acc: 0.9714
#
# Epoch 85/499
# ----------
# train Loss: 0.1076 Acc: 0.9629
# val Loss: 0.0809 Acc: 0.9743
#
# Epoch 86/499
# ----------
# train Loss: 0.1058 Acc: 0.9623
# val Loss: 0.0867 Acc: 0.9697
#
# Epoch 87/499
# ----------
# train Loss: 0.1083 Acc: 0.9616
# val Loss: 0.0804 Acc: 0.9730
#
# Epoch 88/499
# ----------
# train Loss: 0.1038 Acc: 0.9638
# val Loss: 0.0873 Acc: 0.9697
#
# Epoch 89/499
# ----------
# train Loss: 0.1060 Acc: 0.9640
# val Loss: 0.0811 Acc: 0.9734
#
# Epoch 90/499
# ----------
# train Loss: 0.1035 Acc: 0.9639
# val Loss: 0.0826 Acc: 0.9709
#
# Epoch 91/499
# ----------
# train Loss: 0.1015 Acc: 0.9619
# val Loss: 0.0918 Acc: 0.9701
#
# Epoch 92/499
# ----------
# train Loss: 0.1061 Acc: 0.9622
# val Loss: 0.0802 Acc: 0.9743
#
# Epoch 93/499
# ----------
# train Loss: 0.1037 Acc: 0.9640
# val Loss: 0.0804 Acc: 0.9751
#
# Epoch 94/499
# ----------
# train Loss: 0.1056 Acc: 0.9630
# val Loss: 0.0810 Acc: 0.9714
#
# Epoch 95/499
# ----------
# train Loss: 0.1037 Acc: 0.9637
# val Loss: 0.0816 Acc: 0.9747
#
# Epoch 96/499
# ----------
# train Loss: 0.1039 Acc: 0.9612
# val Loss: 0.0801 Acc: 0.9743
#
# Epoch 97/499
# ----------
# train Loss: 0.1087 Acc: 0.9612
# val Loss: 0.0826 Acc: 0.9726
#
# Epoch 98/499
# ----------
# train Loss: 0.1060 Acc: 0.9634
# val Loss: 0.0790 Acc: 0.9755
#
# Epoch 99/499
# ----------
# train Loss: 0.1033 Acc: 0.9650
# val Loss: 0.0812 Acc: 0.9738
#
# Epoch 100/499
# ----------
# train Loss: 0.1060 Acc: 0.9617
# val Loss: 0.0850 Acc: 0.9701
#
# Epoch 101/499
# ----------
# train Loss: 0.1009 Acc: 0.9655
# val Loss: 0.1138 Acc: 0.9585
#
# Epoch 102/499
# ----------
# train Loss: 0.1044 Acc: 0.9632
# val Loss: 0.0912 Acc: 0.9705
#
# Epoch 103/499
# ----------
# train Loss: 0.1024 Acc: 0.9646
# val Loss: 0.1096 Acc: 0.9601
#
# Epoch 104/499
# ----------
# train Loss: 0.1017 Acc: 0.9643
# val Loss: 0.1038 Acc: 0.9626
#
# Epoch 105/499
# ----------
# train Loss: 0.1038 Acc: 0.9640
# val Loss: 0.0798 Acc: 0.9730
#
# Epoch 106/499
# ----------
# train Loss: 0.1017 Acc: 0.9642
# val Loss: 0.0802 Acc: 0.9734
#
# Epoch 107/499
# ----------
# train Loss: 0.1058 Acc: 0.9641
# val Loss: 0.0805 Acc: 0.9718
#
# Epoch 108/499
# ----------
# train Loss: 0.1019 Acc: 0.9617
# val Loss: 0.0852 Acc: 0.9697
#
# Epoch 109/499
# ----------
# train Loss: 0.1040 Acc: 0.9628
# val Loss: 0.0790 Acc: 0.9738
#
# Epoch 110/499
# ----------
# train Loss: 0.1035 Acc: 0.9630
# val Loss: 0.0801 Acc: 0.9730
#
# Epoch 111/499
# ----------
# train Loss: 0.1015 Acc: 0.9634
# val Loss: 0.0807 Acc: 0.9718
#
# Epoch 112/499
# ----------
# train Loss: 0.1027 Acc: 0.9634
# val Loss: 0.1013 Acc: 0.9631
#
# Epoch 113/499
# ----------
# train Loss: 0.1032 Acc: 0.9645
# val Loss: 0.0947 Acc: 0.9680
#
# Epoch 114/499
# ----------
# train Loss: 0.1024 Acc: 0.9635
# val Loss: 0.0781 Acc: 0.9751
#
# Epoch 115/499
# ----------
# train Loss: 0.1003 Acc: 0.9638
# val Loss: 0.0912 Acc: 0.9709
#
# Epoch 116/499
# ----------
# train Loss: 0.1019 Acc: 0.9636
# val Loss: 0.1198 Acc: 0.9572
#
# Epoch 117/499
# ----------
# train Loss: 0.1008 Acc: 0.9626
# val Loss: 0.0818 Acc: 0.9709
#
# Epoch 118/499
# ----------
# train Loss: 0.1008 Acc: 0.9648
# val Loss: 0.0813 Acc: 0.9734
#
# Epoch 119/499
# ----------
# train Loss: 0.1015 Acc: 0.9615
# val Loss: 0.0826 Acc: 0.9693
#
# Epoch 120/499
# ----------
# train Loss: 0.1012 Acc: 0.9650
# val Loss: 0.0811 Acc: 0.9730
#
# Epoch 121/499
# ----------
# train Loss: 0.1028 Acc: 0.9627
# val Loss: 0.0801 Acc: 0.9718
#
# Epoch 122/499
# ----------
# train Loss: 0.1000 Acc: 0.9647
# val Loss: 0.0787 Acc: 0.9747
#
# Epoch 123/499
# ----------
# train Loss: 0.0976 Acc: 0.9639
# val Loss: 0.0787 Acc: 0.9738
#
# Epoch 124/499
# ----------
# train Loss: 0.1024 Acc: 0.9646
# val Loss: 0.0778 Acc: 0.9751
#
# Epoch 125/499
# ----------
# train Loss: 0.1006 Acc: 0.9634
# val Loss: 0.0773 Acc: 0.9759
#
# Epoch 126/499
# ----------
# train Loss: 0.1036 Acc: 0.9628
# val Loss: 0.0803 Acc: 0.9747
#
# Epoch 127/499
# ----------
# train Loss: 0.0984 Acc: 0.9668
# val Loss: 0.0770 Acc: 0.9763
#
# Epoch 128/499
# ----------
# train Loss: 0.0985 Acc: 0.9641
# val Loss: 0.0787 Acc: 0.9730
#
# Epoch 129/499
# ----------
# train Loss: 0.0997 Acc: 0.9646
# val Loss: 0.0840 Acc: 0.9738
#
# Epoch 130/499
# ----------
# train Loss: 0.0995 Acc: 0.9647
# val Loss: 0.0857 Acc: 0.9693
#
# Epoch 131/499
# ----------
# train Loss: 0.0992 Acc: 0.9645
# val Loss: 0.0830 Acc: 0.9738
#
# Epoch 132/499
# ----------
# train Loss: 0.0996 Acc: 0.9638
# val Loss: 0.0777 Acc: 0.9751
#
# Epoch 133/499
# ----------
# train Loss: 0.0994 Acc: 0.9663
# val Loss: 0.0769 Acc: 0.9738
#
# Epoch 134/499
# ----------
# train Loss: 0.1004 Acc: 0.9648
# val Loss: 0.0769 Acc: 0.9772
#
# Epoch 135/499
# ----------
# train Loss: 0.1017 Acc: 0.9631
# val Loss: 0.0773 Acc: 0.9747
#
# Epoch 136/499
# ----------
# train Loss: 0.0990 Acc: 0.9656
# val Loss: 0.0839 Acc: 0.9714
#
# Epoch 137/499
# ----------
# train Loss: 0.0964 Acc: 0.9642
# val Loss: 0.0818 Acc: 0.9705
#
# Epoch 138/499
# ----------
# train Loss: 0.1009 Acc: 0.9624
# val Loss: 0.0767 Acc: 0.9759
#
# Epoch 139/499
# ----------
# train Loss: 0.1002 Acc: 0.9642
# val Loss: 0.0814 Acc: 0.9709
#
# Epoch 140/499
# ----------
# train Loss: 0.0983 Acc: 0.9629
# val Loss: 0.0779 Acc: 0.9726
#
# Epoch 141/499
# ----------
# train Loss: 0.1001 Acc: 0.9647
# val Loss: 0.0768 Acc: 0.9768
#
# Epoch 142/499
# ----------
# train Loss: 0.0984 Acc: 0.9657
# val Loss: 0.0810 Acc: 0.9709
#
# Epoch 143/499
# ----------
# train Loss: 0.0999 Acc: 0.9647
# val Loss: 0.0764 Acc: 0.9772
#
# Epoch 144/499
# ----------
# train Loss: 0.0983 Acc: 0.9645
# val Loss: 0.0755 Acc: 0.9772
#
# Epoch 145/499
# ----------
# train Loss: 0.1013 Acc: 0.9646
# val Loss: 0.0763 Acc: 0.9759
#
# Epoch 146/499
# ----------
# train Loss: 0.1006 Acc: 0.9668
# val Loss: 0.0762 Acc: 0.9772
#
# Epoch 147/499
# ----------
# train Loss: 0.0962 Acc: 0.9654
# val Loss: 0.0757 Acc: 0.9751
#
# Epoch 148/499
# ----------
# train Loss: 0.0958 Acc: 0.9653
# val Loss: 0.0818 Acc: 0.9726
#
# Epoch 149/499
# ----------
# train Loss: 0.0967 Acc: 0.9663
# val Loss: 0.0787 Acc: 0.9751
#
# Epoch 150/499
# ----------
# train Loss: 0.0962 Acc: 0.9659
# val Loss: 0.0766 Acc: 0.9751
#
# Epoch 151/499
# ----------
# train Loss: 0.0994 Acc: 0.9643
# val Loss: 0.0757 Acc: 0.9747
#
# Epoch 152/499
# ----------
# train Loss: 0.0952 Acc: 0.9651
# val Loss: 0.0760 Acc: 0.9759
#
# Epoch 153/499
# ----------
# train Loss: 0.0971 Acc: 0.9672
# val Loss: 0.0856 Acc: 0.9705
#
# Epoch 154/499
# ----------
# train Loss: 0.0950 Acc: 0.9677
# val Loss: 0.0804 Acc: 0.9755
#
# Epoch 155/499
# ----------
# train Loss: 0.0995 Acc: 0.9635
# val Loss: 0.0773 Acc: 0.9738
#
# Epoch 156/499
# ----------
# train Loss: 0.0978 Acc: 0.9659
# val Loss: 0.0796 Acc: 0.9747
#
# Epoch 157/499
# ----------
# train Loss: 0.0982 Acc: 0.9642
# val Loss: 0.0758 Acc: 0.9772
#
# Epoch 158/499
# ----------
# train Loss: 0.0973 Acc: 0.9648
# val Loss: 0.0849 Acc: 0.9676
#
# Epoch 159/499
# ----------
# train Loss: 0.0937 Acc: 0.9683
# val Loss: 0.0833 Acc: 0.9701
#
# Epoch 160/499
# ----------
# train Loss: 0.1009 Acc: 0.9642
# val Loss: 0.0773 Acc: 0.9763
#
# Epoch 161/499
# ----------
# train Loss: 0.0965 Acc: 0.9658
# val Loss: 0.0759 Acc: 0.9755
#
# Epoch 162/499
# ----------
# train Loss: 0.1003 Acc: 0.9656
# val Loss: 0.0795 Acc: 0.9743
#
# Epoch 163/499
# ----------
# train Loss: 0.0972 Acc: 0.9649
# val Loss: 0.0752 Acc: 0.9768
#
# Epoch 164/499
# ----------
# train Loss: 0.0942 Acc: 0.9657
# val Loss: 0.0848 Acc: 0.9705
#
# Epoch 165/499
# ----------
# train Loss: 0.0945 Acc: 0.9663
# val Loss: 0.0772 Acc: 0.9722
#
# Epoch 166/499
# ----------
# train Loss: 0.0986 Acc: 0.9647
# val Loss: 0.0744 Acc: 0.9759
#
# Epoch 167/499
# ----------
# train Loss: 0.0967 Acc: 0.9645
# val Loss: 0.0747 Acc: 0.9768
#
# Epoch 168/499
# ----------
# train Loss: 0.0977 Acc: 0.9659
# val Loss: 0.0772 Acc: 0.9755
#
# Epoch 169/499
# ----------
# train Loss: 0.0968 Acc: 0.9631
# val Loss: 0.0834 Acc: 0.9726
#
# Epoch 170/499
# ----------
# train Loss: 0.0937 Acc: 0.9682
# val Loss: 0.0737 Acc: 0.9751
#
# Epoch 171/499
# ----------
# train Loss: 0.0968 Acc: 0.9641
# val Loss: 0.0758 Acc: 0.9747
#
# Epoch 172/499
# ----------
# train Loss: 0.0979 Acc: 0.9646
# val Loss: 0.0787 Acc: 0.9772
#
# Epoch 173/499
# ----------
# train Loss: 0.0982 Acc: 0.9657
# val Loss: 0.0856 Acc: 0.9680
#
# Epoch 174/499
# ----------
# train Loss: 0.0945 Acc: 0.9664
# val Loss: 0.1076 Acc: 0.9606
#
# Epoch 175/499
# ----------
# train Loss: 0.0949 Acc: 0.9656
# val Loss: 0.0849 Acc: 0.9701
#
# Epoch 176/499
# ----------
# train Loss: 0.0960 Acc: 0.9668
# val Loss: 0.0747 Acc: 0.9751
#
# Epoch 177/499
# ----------
# train Loss: 0.0972 Acc: 0.9662
# val Loss: 0.0747 Acc: 0.9743
#
# Epoch 178/499
# ----------
# train Loss: 0.0934 Acc: 0.9664
# val Loss: 0.0756 Acc: 0.9780
#
# Epoch 179/499
# ----------
# train Loss: 0.0967 Acc: 0.9653
# val Loss: 0.0763 Acc: 0.9726
#
# Epoch 180/499
# ----------
# train Loss: 0.0967 Acc: 0.9647
# val Loss: 0.0799 Acc: 0.9714
#
# Epoch 181/499
# ----------
# train Loss: 0.0965 Acc: 0.9653
# val Loss: 0.0873 Acc: 0.9714
#
# Epoch 182/499
# ----------
# train Loss: 0.0940 Acc: 0.9664
# val Loss: 0.0742 Acc: 0.9743
#
# Epoch 183/499
# ----------
# train Loss: 0.0946 Acc: 0.9673
# val Loss: 0.0750 Acc: 0.9755
#
# Epoch 184/499
# ----------
# train Loss: 0.0971 Acc: 0.9658
# val Loss: 0.0839 Acc: 0.9685
#
# Epoch 185/499
# ----------
# train Loss: 0.0940 Acc: 0.9677
# val Loss: 0.0791 Acc: 0.9755
#
# Epoch 186/499
# ----------
# train Loss: 0.0960 Acc: 0.9653
# val Loss: 0.0828 Acc: 0.9743
#
# Epoch 187/499
# ----------
# train Loss: 0.0958 Acc: 0.9670
# val Loss: 0.0733 Acc: 0.9772
#
# Epoch 188/499
# ----------
# train Loss: 0.0948 Acc: 0.9649
# val Loss: 0.0858 Acc: 0.9714
#
# Epoch 189/499
# ----------
# train Loss: 0.0995 Acc: 0.9655
# val Loss: 0.0768 Acc: 0.9768
#
# Epoch 190/499
# ----------
# train Loss: 0.0995 Acc: 0.9631
# val Loss: 0.0731 Acc: 0.9763
#
# Epoch 191/499
# ----------
# train Loss: 0.0928 Acc: 0.9668
# val Loss: 0.0762 Acc: 0.9776
#
# Epoch 192/499
# ----------
# train Loss: 0.0987 Acc: 0.9644
# val Loss: 0.0794 Acc: 0.9751
#
# Epoch 193/499
# ----------
# train Loss: 0.0941 Acc: 0.9664
# val Loss: 0.0757 Acc: 0.9763
#
# Epoch 194/499
# ----------
# train Loss: 0.0964 Acc: 0.9658
# val Loss: 0.0725 Acc: 0.9776
#
# Epoch 195/499
# ----------
# train Loss: 0.0977 Acc: 0.9630
# val Loss: 0.0802 Acc: 0.9701
#
# Epoch 196/499
# ----------
# train Loss: 0.0947 Acc: 0.9637
# val Loss: 0.0762 Acc: 0.9738
#
# Epoch 197/499
# ----------
# train Loss: 0.0977 Acc: 0.9657
# val Loss: 0.0746 Acc: 0.9743
#
# Epoch 198/499
# ----------
# train Loss: 0.0948 Acc: 0.9672
# val Loss: 0.0835 Acc: 0.9730
#
# Epoch 199/499
# ----------
# train Loss: 0.0914 Acc: 0.9691
# val Loss: 0.0816 Acc: 0.9685
#
# Epoch 200/499
# ----------
# train Loss: 0.0932 Acc: 0.9685
# val Loss: 0.0727 Acc: 0.9768
#
# Epoch 201/499
# ----------
# train Loss: 0.0939 Acc: 0.9649
# val Loss: 0.0975 Acc: 0.9639
#
# Epoch 202/499
# ----------
# train Loss: 0.0968 Acc: 0.9654
# val Loss: 0.0881 Acc: 0.9647
#
# Epoch 203/499
# ----------
# train Loss: 0.0940 Acc: 0.9652
# val Loss: 0.0756 Acc: 0.9734
#
# Epoch 204/499
# ----------
# train Loss: 0.0958 Acc: 0.9677
# val Loss: 0.0890 Acc: 0.9693
#
# Epoch 205/499
# ----------
# train Loss: 0.0933 Acc: 0.9649
# val Loss: 0.0896 Acc: 0.9685
#
# Epoch 206/499
# ----------
# train Loss: 0.0977 Acc: 0.9649
# val Loss: 0.0825 Acc: 0.9701
#
# Epoch 207/499
# ----------
# train Loss: 0.0922 Acc: 0.9663
# val Loss: 0.0719 Acc: 0.9772
#
# Epoch 208/499
# ----------
# train Loss: 0.0941 Acc: 0.9671
# val Loss: 0.0747 Acc: 0.9730
#
# Epoch 209/499
# ----------
# train Loss: 0.0938 Acc: 0.9664
# val Loss: 0.0717 Acc: 0.9759
#
# Epoch 210/499
# ----------
# train Loss: 0.0939 Acc: 0.9676
# val Loss: 0.0721 Acc: 0.9776
#
# Epoch 211/499
# ----------
# train Loss: 0.0934 Acc: 0.9648
# val Loss: 0.0775 Acc: 0.9755
#
# Epoch 212/499
# ----------
# train Loss: 0.0977 Acc: 0.9651
# val Loss: 0.0969 Acc: 0.9655
#
# Epoch 213/499
# ----------
# train Loss: 0.0932 Acc: 0.9672
# val Loss: 0.0731 Acc: 0.9763
#
# Epoch 214/499
# ----------
# train Loss: 0.0941 Acc: 0.9667
# val Loss: 0.0732 Acc: 0.9772
#
# Epoch 215/499
# ----------
# train Loss: 0.0963 Acc: 0.9650
# val Loss: 0.0757 Acc: 0.9768
#
# Epoch 216/499
# ----------
# train Loss: 0.0966 Acc: 0.9649
# val Loss: 0.0721 Acc: 0.9768
#
# Epoch 217/499
# ----------
# train Loss: 0.0960 Acc: 0.9669
# val Loss: 0.0732 Acc: 0.9780
#
# Epoch 218/499
# ----------
# train Loss: 0.0943 Acc: 0.9659
# val Loss: 0.0768 Acc: 0.9755
#
# Epoch 219/499
# ----------
# train Loss: 0.0884 Acc: 0.9702
# val Loss: 0.0873 Acc: 0.9660
#
# Epoch 220/499
# ----------
# train Loss: 0.0971 Acc: 0.9646
# val Loss: 0.0728 Acc: 0.9772
#
# Epoch 221/499
# ----------
# train Loss: 0.0900 Acc: 0.9695
# val Loss: 0.0749 Acc: 0.9763
#
# Epoch 222/499
# ----------
# train Loss: 0.0914 Acc: 0.9665
# val Loss: 0.0775 Acc: 0.9722
#
# Epoch 223/499
# ----------
# train Loss: 0.0954 Acc: 0.9632
# val Loss: 0.0887 Acc: 0.9664
#
# Epoch 224/499
# ----------
# train Loss: 0.0949 Acc: 0.9675
# val Loss: 0.0763 Acc: 0.9734
#
# Epoch 225/499
# ----------
# train Loss: 0.0940 Acc: 0.9648
# val Loss: 0.0759 Acc: 0.9734
#
# Epoch 226/499
# ----------
# train Loss: 0.0923 Acc: 0.9665
# val Loss: 0.0762 Acc: 0.9734
#
# Epoch 227/499
# ----------
# train Loss: 0.0928 Acc: 0.9673
# val Loss: 0.0761 Acc: 0.9772
#
# Epoch 228/499
# ----------
# train Loss: 0.0917 Acc: 0.9690
# val Loss: 0.0775 Acc: 0.9763
#
# Epoch 229/499
# ----------
# train Loss: 0.0911 Acc: 0.9669
# val Loss: 0.0812 Acc: 0.9705
#
# Epoch 230/499
# ----------
# train Loss: 0.0965 Acc: 0.9662
# val Loss: 0.0713 Acc: 0.9780
#
# Epoch 231/499
# ----------
# train Loss: 0.0898 Acc: 0.9680
# val Loss: 0.0827 Acc: 0.9738
#
# Epoch 232/499
# ----------
# train Loss: 0.0969 Acc: 0.9649
# val Loss: 0.0779 Acc: 0.9709
#
# Epoch 233/499
# ----------
# train Loss: 0.0932 Acc: 0.9683
# val Loss: 0.0722 Acc: 0.9763
#
# Epoch 234/499
# ----------
# train Loss: 0.0897 Acc: 0.9671
# val Loss: 0.0740 Acc: 0.9747
#
# Epoch 235/499
# ----------
# train Loss: 0.0913 Acc: 0.9674
# val Loss: 0.0713 Acc: 0.9768
#
# Epoch 236/499
# ----------
# train Loss: 0.0979 Acc: 0.9671
# val Loss: 0.0721 Acc: 0.9763
#
# Epoch 237/499
# ----------
# train Loss: 0.0908 Acc: 0.9675
# val Loss: 0.0708 Acc: 0.9768
#
# Epoch 238/499
# ----------
# train Loss: 0.0916 Acc: 0.9686
# val Loss: 0.0727 Acc: 0.9755
#
# Epoch 239/499
# ----------
# train Loss: 0.0950 Acc: 0.9638
# val Loss: 0.0725 Acc: 0.9763
#
# Epoch 240/499
# ----------
# train Loss: 0.0898 Acc: 0.9679
# val Loss: 0.1000 Acc: 0.9635
#
# Epoch 241/499
# ----------
# train Loss: 0.0892 Acc: 0.9682
# val Loss: 0.0733 Acc: 0.9780
#
# Epoch 242/499
# ----------
# train Loss: 0.0928 Acc: 0.9691
# val Loss: 0.0870 Acc: 0.9664
#
# Epoch 243/499
# ----------
# train Loss: 0.0895 Acc: 0.9668
# val Loss: 0.0708 Acc: 0.9780
#
# Epoch 244/499
# ----------
# train Loss: 0.0963 Acc: 0.9647
# val Loss: 0.0710 Acc: 0.9772
#
# Epoch 245/499
# ----------
# train Loss: 0.0932 Acc: 0.9666
# val Loss: 0.0748 Acc: 0.9738
#
# Epoch 246/499
# ----------
# train Loss: 0.0927 Acc: 0.9670
# val Loss: 0.0774 Acc: 0.9751
#
# Epoch 247/499
# ----------
# train Loss: 0.0942 Acc: 0.9668
# val Loss: 0.0832 Acc: 0.9722
#
# Epoch 248/499
# ----------
# train Loss: 0.0936 Acc: 0.9663
# val Loss: 0.0710 Acc: 0.9780
#
# Epoch 249/499
# ----------
# train Loss: 0.0949 Acc: 0.9657
# val Loss: 0.0729 Acc: 0.9776
#
# Epoch 250/499
# ----------
# train Loss: 0.0937 Acc: 0.9669
# val Loss: 0.0757 Acc: 0.9768
#
# Epoch 251/499
# ----------
# train Loss: 0.0910 Acc: 0.9678
# val Loss: 0.0716 Acc: 0.9763
#
# Epoch 252/499
# ----------
# train Loss: 0.0931 Acc: 0.9667
# val Loss: 0.0712 Acc: 0.9772
#
# Epoch 253/499
# ----------
# train Loss: 0.0931 Acc: 0.9666
# val Loss: 0.0714 Acc: 0.9772
#
# Epoch 254/499
# ----------
# train Loss: 0.0945 Acc: 0.9663
# val Loss: 0.0755 Acc: 0.9743
#
# Epoch 255/499
# ----------
# train Loss: 0.0919 Acc: 0.9667
# val Loss: 0.0718 Acc: 0.9780
#
# Epoch 256/499
# ----------
# train Loss: 0.0917 Acc: 0.9664
# val Loss: 0.0709 Acc: 0.9772
#
# Epoch 257/499
# ----------
# train Loss: 0.0917 Acc: 0.9667
# val Loss: 0.0712 Acc: 0.9776
#
# Epoch 258/499
# ----------
# train Loss: 0.0919 Acc: 0.9674
# val Loss: 0.0778 Acc: 0.9718
#
# Epoch 259/499
# ----------
# train Loss: 0.0933 Acc: 0.9669
# val Loss: 0.0734 Acc: 0.9768
#
# Epoch 260/499
# ----------
# train Loss: 0.0905 Acc: 0.9665
# val Loss: 0.0878 Acc: 0.9697
#
# Epoch 261/499
# ----------
# train Loss: 0.0917 Acc: 0.9672
# val Loss: 0.0720 Acc: 0.9780
#
# Epoch 262/499
# ----------
# train Loss: 0.0901 Acc: 0.9671
# val Loss: 0.0737 Acc: 0.9730
#
# Epoch 263/499
# ----------
# train Loss: 0.0928 Acc: 0.9663
# val Loss: 0.0707 Acc: 0.9768
#
# Epoch 264/499
# ----------
# train Loss: 0.0911 Acc: 0.9675
# val Loss: 0.0763 Acc: 0.9709
#
# Epoch 265/499
# ----------
# train Loss: 0.0889 Acc: 0.9676
# val Loss: 0.1038 Acc: 0.9601
#
# Epoch 266/499
# ----------
# train Loss: 0.0918 Acc: 0.9650
# val Loss: 0.0707 Acc: 0.9776
#
# Epoch 267/499
# ----------
# train Loss: 0.0941 Acc: 0.9670
# val Loss: 0.0771 Acc: 0.9718
#
# Epoch 268/499
# ----------
# train Loss: 0.0932 Acc: 0.9671
# val Loss: 0.0787 Acc: 0.9718
#
# Epoch 269/499
# ----------
# train Loss: 0.0920 Acc: 0.9664
# val Loss: 0.0718 Acc: 0.9780
#
# Epoch 270/499
# ----------
# train Loss: 0.0902 Acc: 0.9669
# val Loss: 0.0932 Acc: 0.9643
#
# Epoch 271/499
# ----------
# train Loss: 0.0936 Acc: 0.9659
# val Loss: 0.0703 Acc: 0.9780
#
# Epoch 272/499
# ----------
# train Loss: 0.0908 Acc: 0.9656
# val Loss: 0.0727 Acc: 0.9759
#
# Epoch 273/499
# ----------
# train Loss: 0.0923 Acc: 0.9650
# val Loss: 0.0708 Acc: 0.9780
#
# Epoch 274/499
# ----------
# train Loss: 0.0897 Acc: 0.9679
# val Loss: 0.0704 Acc: 0.9784
#
# Epoch 275/499
# ----------
# train Loss: 0.0910 Acc: 0.9702
# val Loss: 0.0731 Acc: 0.9780
#
# Epoch 276/499
# ----------
# train Loss: 0.0911 Acc: 0.9678
# val Loss: 0.0713 Acc: 0.9788
#
# Epoch 277/499
# ----------
# train Loss: 0.0906 Acc: 0.9673
# val Loss: 0.0713 Acc: 0.9776
#
# Epoch 278/499
# ----------
# train Loss: 0.0910 Acc: 0.9667
# val Loss: 0.0737 Acc: 0.9751
#
# Epoch 279/499
# ----------
# train Loss: 0.0943 Acc: 0.9664
# val Loss: 0.0777 Acc: 0.9709
#
# Epoch 280/499
# ----------
# train Loss: 0.0972 Acc: 0.9669
# val Loss: 0.0850 Acc: 0.9718
#
# Epoch 281/499
# ----------
# train Loss: 0.0917 Acc: 0.9664
# val Loss: 0.0702 Acc: 0.9784
#
# Epoch 282/499
# ----------
# train Loss: 0.0896 Acc: 0.9672
# val Loss: 0.0816 Acc: 0.9743
#
# Epoch 283/499
# ----------
# train Loss: 0.0874 Acc: 0.9688
# val Loss: 0.0745 Acc: 0.9734
#
# Epoch 284/499
# ----------
# train Loss: 0.0898 Acc: 0.9675
# val Loss: 0.0710 Acc: 0.9792
#
# Epoch 285/499
# ----------
# train Loss: 0.0904 Acc: 0.9680
# val Loss: 0.0698 Acc: 0.9792
#
# Epoch 286/499
# ----------
# train Loss: 0.0937 Acc: 0.9664
# val Loss: 0.0715 Acc: 0.9801
#
# Epoch 287/499
# ----------
# train Loss: 0.0874 Acc: 0.9670
# val Loss: 0.0726 Acc: 0.9755
#
# Epoch 288/499
# ----------
# train Loss: 0.0874 Acc: 0.9677
# val Loss: 0.0702 Acc: 0.9784
#
# Epoch 289/499
# ----------
# train Loss: 0.0893 Acc: 0.9700
# val Loss: 0.0724 Acc: 0.9747
#
# Epoch 290/499
# ----------
# train Loss: 0.0895 Acc: 0.9693
# val Loss: 0.0786 Acc: 0.9705
#
# Epoch 291/499
# ----------
# train Loss: 0.0902 Acc: 0.9685
# val Loss: 0.0709 Acc: 0.9772
#
# Epoch 292/499
# ----------
# train Loss: 0.0908 Acc: 0.9672
# val Loss: 0.0756 Acc: 0.9734
#
# Epoch 293/499
# ----------
# train Loss: 0.0923 Acc: 0.9675
# val Loss: 0.0698 Acc: 0.9780
#
# Epoch 294/499
# ----------
# train Loss: 0.0912 Acc: 0.9665
# val Loss: 0.0699 Acc: 0.9772
#
# Epoch 295/499
# ----------
# train Loss: 0.0861 Acc: 0.9691
# val Loss: 0.0696 Acc: 0.9776
#
# Epoch 296/499
# ----------
# train Loss: 0.0894 Acc: 0.9690
# val Loss: 0.0704 Acc: 0.9784
#
# Epoch 297/499
# ----------
# train Loss: 0.0895 Acc: 0.9669
# val Loss: 0.0700 Acc: 0.9776
#
# Epoch 298/499
# ----------
# train Loss: 0.0912 Acc: 0.9675
# val Loss: 0.0689 Acc: 0.9772
#
# Epoch 299/499
# ----------
# train Loss: 0.0907 Acc: 0.9665
# val Loss: 0.0771 Acc: 0.9718
#
# Epoch 300/499
# ----------
# train Loss: 0.0901 Acc: 0.9681
# val Loss: 0.0720 Acc: 0.9784
#
# Epoch 301/499
# ----------
# train Loss: 0.0909 Acc: 0.9661
# val Loss: 0.0744 Acc: 0.9743
#
# Epoch 302/499
# ----------
# train Loss: 0.0941 Acc: 0.9647
# val Loss: 0.0778 Acc: 0.9726
#
# Epoch 303/499
# ----------
# train Loss: 0.0924 Acc: 0.9654
# val Loss: 0.0711 Acc: 0.9784
#
# Epoch 304/499
# ----------
# train Loss: 0.0921 Acc: 0.9665
# val Loss: 0.0777 Acc: 0.9722
#
# Epoch 305/499
# ----------
# train Loss: 0.0919 Acc: 0.9689
# val Loss: 0.0699 Acc: 0.9780
#
# Epoch 306/499
# ----------
# train Loss: 0.0874 Acc: 0.9694
# val Loss: 0.0721 Acc: 0.9738
#
# Epoch 307/499
# ----------
# train Loss: 0.0915 Acc: 0.9662
# val Loss: 0.0712 Acc: 0.9788
#
# Epoch 308/499
# ----------
# train Loss: 0.0932 Acc: 0.9650
# val Loss: 0.0713 Acc: 0.9747
#
# Epoch 309/499
# ----------
# train Loss: 0.0868 Acc: 0.9678
# val Loss: 0.0722 Acc: 0.9751
#
# Epoch 310/499
# ----------
# train Loss: 0.0894 Acc: 0.9668
# val Loss: 0.0702 Acc: 0.9788
#
# Epoch 311/499
# ----------
# train Loss: 0.0873 Acc: 0.9683
# val Loss: 0.0691 Acc: 0.9784
#
# Epoch 312/499
# ----------
# train Loss: 0.0936 Acc: 0.9656
# val Loss: 0.0688 Acc: 0.9780
#
# Epoch 313/499
# ----------
# train Loss: 0.0913 Acc: 0.9663
# val Loss: 0.0719 Acc: 0.9743
#
# Epoch 314/499
# ----------
# train Loss: 0.0907 Acc: 0.9665
# val Loss: 0.0702 Acc: 0.9797
#
# Epoch 315/499
# ----------
# train Loss: 0.0892 Acc: 0.9677
# val Loss: 0.0703 Acc: 0.9784
#
# Epoch 316/499
# ----------
# train Loss: 0.0893 Acc: 0.9676
# val Loss: 0.0713 Acc: 0.9755
#
# Epoch 317/499
# ----------
# train Loss: 0.0882 Acc: 0.9680
# val Loss: 0.0693 Acc: 0.9768
#
# Epoch 318/499
# ----------
# train Loss: 0.0901 Acc: 0.9680
# val Loss: 0.0700 Acc: 0.9776
#
# Epoch 319/499
# ----------
# train Loss: 0.0920 Acc: 0.9684
# val Loss: 0.0692 Acc: 0.9772
#
# Epoch 320/499
# ----------
# train Loss: 0.0906 Acc: 0.9665
# val Loss: 0.0708 Acc: 0.9792
#
# Epoch 321/499
# ----------
# train Loss: 0.0927 Acc: 0.9681
# val Loss: 0.0722 Acc: 0.9751
#
# Epoch 322/499
# ----------
# train Loss: 0.0918 Acc: 0.9661
# val Loss: 0.0759 Acc: 0.9726
#
# Epoch 323/499
# ----------
# train Loss: 0.0915 Acc: 0.9674
# val Loss: 0.0696 Acc: 0.9768
#
# Epoch 324/499
# ----------
# train Loss: 0.0920 Acc: 0.9676
# val Loss: 0.0702 Acc: 0.9776
#
# Epoch 325/499
# ----------
# train Loss: 0.0882 Acc: 0.9672
# val Loss: 0.0776 Acc: 0.9751
#
# Epoch 326/499
# ----------
# train Loss: 0.0820 Acc: 0.9716
# val Loss: 0.0696 Acc: 0.9776
#
# Epoch 327/499
# ----------
# train Loss: 0.0905 Acc: 0.9666
# val Loss: 0.0732 Acc: 0.9776
#
# Epoch 328/499
# ----------
# train Loss: 0.0912 Acc: 0.9669
# val Loss: 0.0693 Acc: 0.9780
#
# Epoch 329/499
# ----------
# train Loss: 0.0890 Acc: 0.9667
# val Loss: 0.0696 Acc: 0.9788
#
# Epoch 330/499
# ----------
# train Loss: 0.0857 Acc: 0.9708
# val Loss: 0.0700 Acc: 0.9788
#
# Epoch 331/499
# ----------
# train Loss: 0.0903 Acc: 0.9677
# val Loss: 0.0698 Acc: 0.9776
#
# Epoch 332/499
# ----------
# train Loss: 0.0904 Acc: 0.9683
# val Loss: 0.0700 Acc: 0.9768
#
# Epoch 333/499
# ----------
# train Loss: 0.0906 Acc: 0.9665
# val Loss: 0.0721 Acc: 0.9755
#
# Epoch 334/499
# ----------
# train Loss: 0.0926 Acc: 0.9641
# val Loss: 0.0692 Acc: 0.9776
#
# Epoch 335/499
# ----------
# train Loss: 0.0878 Acc: 0.9679
# val Loss: 0.0696 Acc: 0.9788
#
# Epoch 336/499
# ----------
# train Loss: 0.0908 Acc: 0.9684
# val Loss: 0.0712 Acc: 0.9780
#
# Epoch 337/499
# ----------
# train Loss: 0.0913 Acc: 0.9674
# val Loss: 0.0737 Acc: 0.9743
#
# Epoch 338/499
# ----------
# train Loss: 0.0917 Acc: 0.9683
# val Loss: 0.0707 Acc: 0.9768
#
# Epoch 339/499
# ----------
# train Loss: 0.0929 Acc: 0.9675
# val Loss: 0.0696 Acc: 0.9776
#
# Epoch 340/499
# ----------
# train Loss: 0.0882 Acc: 0.9676
# val Loss: 0.0688 Acc: 0.9780
#
# Epoch 341/499
# ----------
# train Loss: 0.0913 Acc: 0.9670
# val Loss: 0.0778 Acc: 0.9722
#
# Epoch 342/499
# ----------
# train Loss: 0.0886 Acc: 0.9668
# val Loss: 0.0698 Acc: 0.9776
#
# Epoch 343/499
# ----------
# train Loss: 0.0871 Acc: 0.9675
# val Loss: 0.0728 Acc: 0.9743
#
# Epoch 344/499
# ----------
# train Loss: 0.0872 Acc: 0.9682
# val Loss: 0.0729 Acc: 0.9743
#
# Epoch 345/499
# ----------
# train Loss: 0.0875 Acc: 0.9675
# val Loss: 0.0694 Acc: 0.9772
#
# Epoch 346/499
# ----------
# train Loss: 0.0899 Acc: 0.9675
# val Loss: 0.0738 Acc: 0.9726
#
# Epoch 347/499
# ----------
# train Loss: 0.0867 Acc: 0.9682
# val Loss: 0.0707 Acc: 0.9788
#
# Epoch 348/499
# ----------
# train Loss: 0.0918 Acc: 0.9672
# val Loss: 0.0704 Acc: 0.9768
#
# Epoch 349/499
# ----------
# train Loss: 0.0903 Acc: 0.9678
# val Loss: 0.0749 Acc: 0.9759
#
# Epoch 350/499
# ----------
# train Loss: 0.0947 Acc: 0.9645
# val Loss: 0.0690 Acc: 0.9776
#
# Epoch 351/499
# ----------
# train Loss: 0.0877 Acc: 0.9678
# val Loss: 0.0701 Acc: 0.9763
#
# Epoch 352/499
# ----------
# train Loss: 0.0896 Acc: 0.9677
# val Loss: 0.0705 Acc: 0.9784
#
# Epoch 353/499
# ----------
# train Loss: 0.0843 Acc: 0.9695
# val Loss: 0.0724 Acc: 0.9743
#
# Epoch 354/499
# ----------
# train Loss: 0.0881 Acc: 0.9691
# val Loss: 0.0709 Acc: 0.9788
#
# Epoch 355/499
# ----------
# train Loss: 0.0919 Acc: 0.9673
# val Loss: 0.0751 Acc: 0.9755
#
# Epoch 356/499
# ----------
# train Loss: 0.0924 Acc: 0.9666
# val Loss: 0.0699 Acc: 0.9792
#
# Epoch 357/499
# ----------
# train Loss: 0.0862 Acc: 0.9692
# val Loss: 0.0723 Acc: 0.9747
#
# Epoch 358/499
# ----------
# train Loss: 0.0907 Acc: 0.9669
# val Loss: 0.0713 Acc: 0.9788
#
# Epoch 359/499
# ----------
# train Loss: 0.0883 Acc: 0.9695
# val Loss: 0.0690 Acc: 0.9784
#
# Epoch 360/499
# ----------
# train Loss: 0.0881 Acc: 0.9686
# val Loss: 0.0769 Acc: 0.9722
#
# Epoch 361/499
# ----------
# train Loss: 0.0888 Acc: 0.9681
# val Loss: 0.0691 Acc: 0.9780
#
# Epoch 362/499
# ----------
# train Loss: 0.0919 Acc: 0.9686
# val Loss: 0.0705 Acc: 0.9768
#
# Epoch 363/499
# ----------
# train Loss: 0.0855 Acc: 0.9695
# val Loss: 0.0686 Acc: 0.9780
#
# Epoch 364/499
# ----------
# train Loss: 0.0911 Acc: 0.9663
# val Loss: 0.0727 Acc: 0.9755
#
# Epoch 365/499
# ----------
# train Loss: 0.0916 Acc: 0.9664
# val Loss: 0.0702 Acc: 0.9788
#
# Epoch 366/499
# ----------
# train Loss: 0.0862 Acc: 0.9693
# val Loss: 0.0864 Acc: 0.9655
#
# Epoch 367/499
# ----------
# train Loss: 0.0851 Acc: 0.9711
# val Loss: 0.0711 Acc: 0.9759
#
# Epoch 368/499
# ----------
# train Loss: 0.0888 Acc: 0.9670
# val Loss: 0.0703 Acc: 0.9784
#
# Epoch 369/499
# ----------
# train Loss: 0.0882 Acc: 0.9684
# val Loss: 0.0698 Acc: 0.9780
#
# Epoch 370/499
# ----------
# train Loss: 0.0879 Acc: 0.9679
# val Loss: 0.0708 Acc: 0.9772
#
# Epoch 371/499
# ----------
# train Loss: 0.0900 Acc: 0.9675
# val Loss: 0.0793 Acc: 0.9751
#
# Epoch 372/499
# ----------
# train Loss: 0.0900 Acc: 0.9669
# val Loss: 0.0719 Acc: 0.9784
#
# Epoch 373/499
# ----------
# train Loss: 0.0910 Acc: 0.9659
# val Loss: 0.0745 Acc: 0.9730
#
# Epoch 374/499
# ----------
# train Loss: 0.0874 Acc: 0.9673
# val Loss: 0.0833 Acc: 0.9680
#
# Epoch 375/499
# ----------
# train Loss: 0.0867 Acc: 0.9679
# val Loss: 0.0767 Acc: 0.9718
#
# Epoch 376/499
# ----------
# train Loss: 0.0868 Acc: 0.9679
# val Loss: 0.0686 Acc: 0.9776
#
# Epoch 377/499
# ----------
# train Loss: 0.0904 Acc: 0.9672
# val Loss: 0.0693 Acc: 0.9776
#
# Epoch 378/499
# ----------
# train Loss: 0.0908 Acc: 0.9665
# val Loss: 0.0706 Acc: 0.9759
#
# Epoch 379/499
# ----------
# train Loss: 0.0879 Acc: 0.9689
# val Loss: 0.0678 Acc: 0.9784
#
# Epoch 380/499
# ----------
# train Loss: 0.0876 Acc: 0.9676
# val Loss: 0.0702 Acc: 0.9763
#
# Epoch 381/499
# ----------
# train Loss: 0.0883 Acc: 0.9679
# val Loss: 0.0684 Acc: 0.9784
#
# Epoch 382/499
# ----------
# train Loss: 0.0847 Acc: 0.9686
# val Loss: 0.0703 Acc: 0.9763
#
# Epoch 383/499
# ----------
# train Loss: 0.0860 Acc: 0.9681
# val Loss: 0.0701 Acc: 0.9751
#
# Epoch 384/499
# ----------
# train Loss: 0.0908 Acc: 0.9658
# val Loss: 0.0691 Acc: 0.9780
#
# Epoch 385/499
# ----------
# train Loss: 0.0909 Acc: 0.9673
# val Loss: 0.0759 Acc: 0.9743
#
# Epoch 386/499
# ----------
# train Loss: 0.0920 Acc: 0.9666
# val Loss: 0.0692 Acc: 0.9772
#
# Epoch 387/499
# ----------
# train Loss: 0.0861 Acc: 0.9692
# val Loss: 0.0699 Acc: 0.9763
#
# Epoch 388/499
# ----------
# train Loss: 0.0902 Acc: 0.9681
# val Loss: 0.0693 Acc: 0.9768
#
# Epoch 389/499
# ----------
# train Loss: 0.0880 Acc: 0.9696
# val Loss: 0.0682 Acc: 0.9780
#
# Epoch 390/499
# ----------
# train Loss: 0.0903 Acc: 0.9678
# val Loss: 0.0677 Acc: 0.9784
#
# Epoch 391/499
# ----------
# train Loss: 0.0872 Acc: 0.9680
# val Loss: 0.0699 Acc: 0.9768
#
# Epoch 392/499
# ----------
# train Loss: 0.0897 Acc: 0.9652
# val Loss: 0.0978 Acc: 0.9618
#
# Epoch 393/499
# ----------
# train Loss: 0.0850 Acc: 0.9698
# val Loss: 0.0675 Acc: 0.9784
#
# Epoch 394/499
# ----------
# train Loss: 0.0875 Acc: 0.9695
# val Loss: 0.0714 Acc: 0.9788
#
# Epoch 395/499
# ----------
# train Loss: 0.0882 Acc: 0.9670
# val Loss: 0.0683 Acc: 0.9780
#
# Epoch 396/499
# ----------
# train Loss: 0.0880 Acc: 0.9685
# val Loss: 0.0671 Acc: 0.9784
#
# Epoch 397/499
# ----------
# train Loss: 0.0882 Acc: 0.9691
# val Loss: 0.0672 Acc: 0.9788
#
# Epoch 398/499
# ----------
# train Loss: 0.0911 Acc: 0.9676
# val Loss: 0.0684 Acc: 0.9784
#
# Epoch 399/499
# ----------
# train Loss: 0.0909 Acc: 0.9670
# val Loss: 0.0719 Acc: 0.9751
#
# Epoch 400/499
# ----------
# train Loss: 0.0875 Acc: 0.9700
# val Loss: 0.0686 Acc: 0.9788
#
# Epoch 401/499
# ----------
# train Loss: 0.0886 Acc: 0.9670
# val Loss: 0.0739 Acc: 0.9776
#
# Epoch 402/499
# ----------
# train Loss: 0.0897 Acc: 0.9671
# val Loss: 0.0692 Acc: 0.9784
#
# Epoch 403/499
# ----------
# train Loss: 0.0847 Acc: 0.9698
# val Loss: 0.0685 Acc: 0.9776
#
# Epoch 404/499
# ----------
# train Loss: 0.0869 Acc: 0.9697
# val Loss: 0.0701 Acc: 0.9788
#
# Epoch 405/499
# ----------
# train Loss: 0.0900 Acc: 0.9666
# val Loss: 0.0683 Acc: 0.9780
#
# Epoch 406/499
# ----------
# train Loss: 0.0910 Acc: 0.9665
# val Loss: 0.0680 Acc: 0.9780
#
# Epoch 407/499
# ----------
# train Loss: 0.0872 Acc: 0.9684
# val Loss: 0.0683 Acc: 0.9772
#
# Epoch 408/499
# ----------
# train Loss: 0.0901 Acc: 0.9675
# val Loss: 0.0676 Acc: 0.9784
#
# Epoch 409/499
# ----------
# train Loss: 0.0922 Acc: 0.9674
# val Loss: 0.0685 Acc: 0.9776
#
# Epoch 410/499
# ----------
# train Loss: 0.0863 Acc: 0.9692
# val Loss: 0.0692 Acc: 0.9772
#
# Epoch 411/499
# ----------
# train Loss: 0.0864 Acc: 0.9672
# val Loss: 0.0725 Acc: 0.9747
#
# Epoch 412/499
# ----------
# train Loss: 0.0911 Acc: 0.9672
# val Loss: 0.0709 Acc: 0.9797
#
# Epoch 413/499
# ----------
# train Loss: 0.0873 Acc: 0.9672
# val Loss: 0.0696 Acc: 0.9776
#
# Epoch 414/499
# ----------
# train Loss: 0.0891 Acc: 0.9680
# val Loss: 0.0684 Acc: 0.9788
#
# Epoch 415/499
# ----------
# train Loss: 0.0865 Acc: 0.9683
# val Loss: 0.0742 Acc: 0.9768
#
# Epoch 416/499
# ----------
# train Loss: 0.0872 Acc: 0.9675
# val Loss: 0.0699 Acc: 0.9772
#
# Epoch 417/499
# ----------
# train Loss: 0.0866 Acc: 0.9688
# val Loss: 0.0754 Acc: 0.9714
#
# Epoch 418/499
# ----------
# train Loss: 0.0916 Acc: 0.9671
# val Loss: 0.0690 Acc: 0.9784
#
# Epoch 419/499
# ----------
# train Loss: 0.0860 Acc: 0.9688
# val Loss: 0.0780 Acc: 0.9701
#
# Epoch 420/499
# ----------
# train Loss: 0.0858 Acc: 0.9679
# val Loss: 0.0686 Acc: 0.9780
#
# Epoch 421/499
# ----------
# train Loss: 0.0867 Acc: 0.9684
# val Loss: 0.0695 Acc: 0.9763
#
# Epoch 422/499
# ----------
# train Loss: 0.0866 Acc: 0.9679
# val Loss: 0.0681 Acc: 0.9788
#
# Epoch 423/499
# ----------
# train Loss: 0.0884 Acc: 0.9685
# val Loss: 0.0694 Acc: 0.9772
#
# Epoch 424/499
# ----------
# train Loss: 0.0874 Acc: 0.9676
# val Loss: 0.0677 Acc: 0.9780
#
# Epoch 425/499
# ----------
# train Loss: 0.0857 Acc: 0.9696
# val Loss: 0.0731 Acc: 0.9743
#
# Epoch 426/499
# ----------
# train Loss: 0.0890 Acc: 0.9668
# val Loss: 0.0691 Acc: 0.9788
#
# Epoch 427/499
# ----------
# train Loss: 0.0879 Acc: 0.9693
# val Loss: 0.0680 Acc: 0.9784
#
# Epoch 428/499
# ----------
# train Loss: 0.0867 Acc: 0.9703
# val Loss: 0.0691 Acc: 0.9788
#
# Epoch 429/499
# ----------
# train Loss: 0.0857 Acc: 0.9697
# val Loss: 0.0710 Acc: 0.9784
#
# Epoch 430/499
# ----------
# train Loss: 0.0890 Acc: 0.9661
# val Loss: 0.0713 Acc: 0.9747
#
# Epoch 431/499
# ----------
# train Loss: 0.0867 Acc: 0.9696
# val Loss: 0.0710 Acc: 0.9792
#
# Epoch 432/499
# ----------
# train Loss: 0.0847 Acc: 0.9704
# val Loss: 0.0802 Acc: 0.9718
#
# Epoch 433/499
# ----------
# train Loss: 0.0882 Acc: 0.9669
# val Loss: 0.0770 Acc: 0.9751
#
# Epoch 434/499
# ----------
# train Loss: 0.0904 Acc: 0.9670
# val Loss: 0.0707 Acc: 0.9797
#
# Epoch 435/499
# ----------
# train Loss: 0.0865 Acc: 0.9707
# val Loss: 0.0844 Acc: 0.9685
#
# Epoch 436/499
# ----------
# train Loss: 0.0862 Acc: 0.9668
# val Loss: 0.0694 Acc: 0.9797
#
# Epoch 437/499
# ----------
# train Loss: 0.0882 Acc: 0.9668
# val Loss: 0.0701 Acc: 0.9776
#
# Epoch 438/499
# ----------
# train Loss: 0.0863 Acc: 0.9695
# val Loss: 0.0681 Acc: 0.9780
#
# Epoch 439/499
# ----------
# train Loss: 0.0877 Acc: 0.9665
# val Loss: 0.0678 Acc: 0.9784
#
# Epoch 440/499
# ----------
# train Loss: 0.0886 Acc: 0.9661
# val Loss: 0.0680 Acc: 0.9780
#
# Epoch 441/499
# ----------
# train Loss: 0.0867 Acc: 0.9683
# val Loss: 0.0823 Acc: 0.9722
#
# Epoch 442/499
# ----------
# train Loss: 0.0868 Acc: 0.9681
# val Loss: 0.0677 Acc: 0.9788
#
# Epoch 443/499
# ----------
# train Loss: 0.0863 Acc: 0.9705
# val Loss: 0.0676 Acc: 0.9784
#
# Epoch 444/499
# ----------
# train Loss: 0.0885 Acc: 0.9680
# val Loss: 0.0692 Acc: 0.9788
#
# Epoch 445/499
# ----------
# train Loss: 0.0839 Acc: 0.9693
# val Loss: 0.0683 Acc: 0.9772
#
# Epoch 446/499
# ----------
# train Loss: 0.0867 Acc: 0.9691
# val Loss: 0.0673 Acc: 0.9784
#
# Epoch 447/499
# ----------
# train Loss: 0.0874 Acc: 0.9673
# val Loss: 0.0714 Acc: 0.9776
#
# Epoch 448/499
# ----------
# train Loss: 0.0871 Acc: 0.9688
# val Loss: 0.0709 Acc: 0.9784
#
# Epoch 449/499
# ----------
# train Loss: 0.0859 Acc: 0.9695
# val Loss: 0.0689 Acc: 0.9784
#
# Epoch 450/499
# ----------
# train Loss: 0.0876 Acc: 0.9686
# val Loss: 0.0680 Acc: 0.9788
#
# Epoch 451/499
# ----------
# train Loss: 0.0886 Acc: 0.9674
# val Loss: 0.0718 Acc: 0.9776
#
# Epoch 452/499
# ----------
# train Loss: 0.0872 Acc: 0.9680
# val Loss: 0.0674 Acc: 0.9776
#
# Epoch 453/499
# ----------
# train Loss: 0.0858 Acc: 0.9702
# val Loss: 0.0668 Acc: 0.9792
#
# Epoch 454/499
# ----------
# train Loss: 0.0869 Acc: 0.9699
# val Loss: 0.0732 Acc: 0.9734
#
# Epoch 455/499
# ----------
# train Loss: 0.0876 Acc: 0.9696
# val Loss: 0.0679 Acc: 0.9776
#
# Epoch 456/499
# ----------
# train Loss: 0.0853 Acc: 0.9694
# val Loss: 0.0704 Acc: 0.9788
#
# Epoch 457/499
# ----------
# train Loss: 0.0894 Acc: 0.9676
# val Loss: 0.0683 Acc: 0.9772
#
# Epoch 458/499
# ----------
# train Loss: 0.0855 Acc: 0.9682
# val Loss: 0.0685 Acc: 0.9776
#
# Epoch 459/499
# ----------
# train Loss: 0.0859 Acc: 0.9683
# val Loss: 0.0680 Acc: 0.9784
#
# Epoch 460/499
# ----------
# train Loss: 0.0862 Acc: 0.9688
# val Loss: 0.0688 Acc: 0.9784
#
# Epoch 461/499
# ----------
# train Loss: 0.0868 Acc: 0.9681
# val Loss: 0.0703 Acc: 0.9792
#
# Epoch 462/499
# ----------
# train Loss: 0.0896 Acc: 0.9685
# val Loss: 0.0717 Acc: 0.9751
#
# Epoch 463/499
# ----------
# train Loss: 0.0842 Acc: 0.9692
# val Loss: 0.0686 Acc: 0.9772
#
# Epoch 464/499
# ----------
# train Loss: 0.0849 Acc: 0.9676
# val Loss: 0.0688 Acc: 0.9776
#
# Epoch 465/499
# ----------
# train Loss: 0.0896 Acc: 0.9688
# val Loss: 0.0670 Acc: 0.9784
#
# Epoch 466/499
# ----------
# train Loss: 0.0845 Acc: 0.9696
# val Loss: 0.0674 Acc: 0.9780
#
# Epoch 467/499
# ----------
# train Loss: 0.0842 Acc: 0.9685
# val Loss: 0.0673 Acc: 0.9792
#
# Epoch 468/499
# ----------
# train Loss: 0.0850 Acc: 0.9686
# val Loss: 0.0719 Acc: 0.9772
#
# Epoch 469/499
# ----------
# train Loss: 0.0835 Acc: 0.9705
# val Loss: 0.0772 Acc: 0.9705
#
# Epoch 470/499
# ----------
# train Loss: 0.0875 Acc: 0.9684
# val Loss: 0.0694 Acc: 0.9772
#
# Epoch 471/499
# ----------
# train Loss: 0.0847 Acc: 0.9677
# val Loss: 0.0693 Acc: 0.9763
#
# Epoch 472/499
# ----------
# train Loss: 0.0836 Acc: 0.9691
# val Loss: 0.0740 Acc: 0.9768
#
# Epoch 473/499
# ----------
# train Loss: 0.0874 Acc: 0.9670
# val Loss: 0.0673 Acc: 0.9792
#
# Epoch 474/499
# ----------
# train Loss: 0.0874 Acc: 0.9691
# val Loss: 0.0698 Acc: 0.9784
#
# Epoch 475/499
# ----------
# train Loss: 0.0856 Acc: 0.9680
# val Loss: 0.0771 Acc: 0.9751
#
# Epoch 476/499
# ----------
# train Loss: 0.0828 Acc: 0.9710
# val Loss: 0.0687 Acc: 0.9780
#
# Epoch 477/499
# ----------
# train Loss: 0.0836 Acc: 0.9679
# val Loss: 0.0715 Acc: 0.9776
#
# Epoch 478/499
# ----------
# train Loss: 0.0919 Acc: 0.9680
# val Loss: 0.0668 Acc: 0.9788
#
# Epoch 479/499
# ----------
# train Loss: 0.0862 Acc: 0.9699
# val Loss: 0.0687 Acc: 0.9780
#
# Epoch 480/499
# ----------
# train Loss: 0.0859 Acc: 0.9691
# val Loss: 0.0706 Acc: 0.9784
#
# Epoch 481/499
# ----------
# train Loss: 0.0818 Acc: 0.9708
# val Loss: 0.0687 Acc: 0.9776
#
# Epoch 482/499
# ----------
# train Loss: 0.0872 Acc: 0.9676
# val Loss: 0.0705 Acc: 0.9755
#
# Epoch 483/499
# ----------
# train Loss: 0.0875 Acc: 0.9669
# val Loss: 0.0688 Acc: 0.9772
#
# Epoch 484/499
# ----------
# train Loss: 0.0873 Acc: 0.9672
# val Loss: 0.0671 Acc: 0.9784
#
# Epoch 485/499
# ----------
# train Loss: 0.0837 Acc: 0.9688
# val Loss: 0.0674 Acc: 0.9801
#
# Epoch 486/499
# ----------
# train Loss: 0.0860 Acc: 0.9699
# val Loss: 0.0684 Acc: 0.9776
#
# Epoch 487/499
# ----------
# train Loss: 0.0863 Acc: 0.9674
# val Loss: 0.0683 Acc: 0.9788
#
# Epoch 488/499
# ----------
# train Loss: 0.0883 Acc: 0.9665
# val Loss: 0.0823 Acc: 0.9709
#
# Epoch 489/499
# ----------
# train Loss: 0.0843 Acc: 0.9706
# val Loss: 0.0679 Acc: 0.9776
#
# Epoch 490/499
# ----------
# train Loss: 0.0857 Acc: 0.9694
# val Loss: 0.0707 Acc: 0.9784
#
# Epoch 491/499
# ----------
# train Loss: 0.0845 Acc: 0.9690
# val Loss: 0.0683 Acc: 0.9772
#
# Epoch 492/499
# ----------
# train Loss: 0.0835 Acc: 0.9698
# val Loss: 0.0987 Acc: 0.9610
#
# Epoch 493/499
# ----------
# train Loss: 0.0871 Acc: 0.9697
# val Loss: 0.0703 Acc: 0.9755
#
# Epoch 494/499
# ----------
# train Loss: 0.0854 Acc: 0.9693
# val Loss: 0.0701 Acc: 0.9776
#
# Epoch 495/499
# ----------
# train Loss: 0.0821 Acc: 0.9702
# val Loss: 0.0675 Acc: 0.9792
#
# Epoch 496/499
# ----------
# train Loss: 0.0858 Acc: 0.9697
# val Loss: 0.0672 Acc: 0.9792
#
# Epoch 497/499
# ----------
# train Loss: 0.0831 Acc: 0.9702
# val Loss: 0.0684 Acc: 0.9788
#
# Epoch 498/499
# ----------
# train Loss: 0.0864 Acc: 0.9698
# val Loss: 0.0734 Acc: 0.9763
#
# Epoch 499/499
# ----------
# train Loss: 0.0836 Acc: 0.9707
# val Loss: 0.0723 Acc: 0.9763
#
#
# ##############################
# ------ Summary ------
# model -> squeezenet
# epochs -> 500
# lr -> 0.0001
# batch size -> 16
#
# Training complete in 128m 2s
# Best val Acc: 0.980075
# ##############################
#
# ==== END ====

# %%
from sklearn.metrics import confusion_matrix

nb_classes = 3

# Initialize the prediction and label lists(tensors)
predlist=torch.zeros(0,dtype=torch.long, device='cpu')
lbllist=torch.zeros(0,dtype=torch.long, device='cpu')

with torch.no_grad():
    for i, (inputs, classes) in enumerate(dataloaders['val']):
        inputs = inputs.to(device) #labels atuais
        classes = classes.to(device) #classes
        outputs = model_ft(inputs) #valores preditos = Passa o label atual e retorna o que o modelo predice
        _, preds = torch.max(outputs, 1) #pega o maior valor das predições

        # Append batch prediction results
        predlist=torch.cat([predlist,preds.view(-1).cpu()])
        lbllist=torch.cat([lbllist,classes.view(-1).cpu()])

# Confusion matrix
conf_mat=confusion_matrix(lbllist.numpy(), predlist.numpy())
print(conf_mat)
print()
# Out:
# [[791   0   0]
#  [  1 772  26]
#  [  4  17 798]]

# %%
import itertools 
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

cm = confusion_matrix(lbllist.numpy(), predlist.numpy())
np.set_printoptions(precision=2)

plt.figure()

# %%
plot_confusion_matrix(cm, classes=['norm', 'covid', 'pnemo'], title='Confusion matrix')
# Out:
# Confusion matrix, without normalization

# %%
from sklearn import metrics

# %%
#analise dos resultados do modelo
print('Sensitivity or recall total')
print (metrics.recall_score(lbllist.numpy(), predlist.numpy(), average='micro'))

print()
print('Sensitivity or recall per classes')
print (metrics.recall_score(lbllist.numpy(), predlist.numpy(), average=None))

print()
print('Precision')
print (metrics.precision_score(lbllist.numpy(), predlist.numpy(), average=None))

print()
print('F1 Score')
print (metrics.f1_score(lbllist.numpy(), predlist.numpy(), average=None))
# Out:
# Sensitivity or recall total
# 0.9800747198007472
#
# Sensitivity or recall per classes
# [1.   0.97 0.97]
#
# Precision
# [0.99 0.98 0.97]
#
# F1 Score
# [1.   0.97 0.97]

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    #mean = np.array([0.485, 0.456, 0.405])
    #std = np.array([0.229, 0.224, 0.225])
    #inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    #plt.pause(1)  # pause a bit so that plots are updated

# %%
def visualize_model(model, num_images=30):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    for i, (inputs, classes) in enumerate(dataloaders['test']):
        #inputs, labels = data

        #inputs, labels = Variable(inputs), Variable(labels)
        inputs = inputs.to(device) #labels atuais
        
        outputs = model(inputs)
        _, preds = torch.max(outputs.data, 1)

        for j in range(inputs.size()[0]):
            images_so_far += 1
            ax = plt.figure(figsize=(20,20))
            ax = plt.subplot(15, 2, images_so_far)
            ax.axis('off')
            ax.set_title('{}'.format(class_names[predlist[j]]))
            imshow(inputs.cpu().data[j])

            if images_so_far == num_images:
                model.train(mode=was_training)
                return
    model.train(mode=was_training)

#print(dir(model))
visualize_model(model_ft)
# Out:
# /home/jimi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
savePath = "test_model.pth"
torch.save(model_ft.state_dict(), savePath)

# %%
import io, os
import requests
from PIL import Image
import torch
from torchvision import models, transforms
from torch.autograd import Variable
from torch.nn import functional as F
from torchvision import datasets
import numpy as np
import cv2
import pdb

# %%
finalconv_name = 'features'
model_ft.eval()
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (6): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (9): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Conv2d(512, 3, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )

# %%
model_ft.load_state_dict(torch.load("test_model.pth",map_location='cpu'))

# %%
normalize = transforms.Normalize(
   mean=[0.485, 0.456, 0.406],
   std=[0.229, 0.224, 0.225]
)
preprocess = transforms.Compose([
   transforms.Resize((224,224)),
   transforms.ToTensor(),
   normalize
])

# %%
features_blobs = []
def hook_feature(module, input, output):
    features_blobs.append(output.data.cpu().numpy())

model_ft._modules.get(finalconv_name).register_forward_hook(hook_feature)

# %%
params_to_update = model_ft.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name, param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name, param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)

# get the softmax weight
params = params_to_update
weight_softmax = np.squeeze(params[-2].cpu().data.numpy())

def returnCAM(feature_conv, weight_softmax, class_idx):
    # generate the class activation maps upsample to 256x256
    size_upsample = (256, 256)
    bz, nc, h, w = feature_conv.shape
    output_cam = []
    for idx in class_idx:
        cam = weight_softmax[idx].dot(feature_conv.reshape((nc, h*w)))
        cam = cam.reshape(h, w)
        cam = cam - np.min(cam)
        cam_img = cam / np.max(cam)
        cam_img = np.uint8(255 * cam_img)
        output_cam.append(cv2.resize(cam_img, size_upsample))
    return output_cam
# Out:
# Params to learn:
# 	 classifier.1.weight
# 	 classifier.1.bias

# %%
img_pil = Image.open("/home/jimi/dissertacao/covid19/datasets/80-20/test/covid/000001-1.png").convert('RGB') # you can change image at here

img_tensor = preprocess(img_pil).cuda()
img_variable = Variable(img_tensor.unsqueeze(0))
logit = model_ft(img_variable)

h_x = F.softmax(logit, dim=1).data.squeeze().cuda()
probs, idx = h_x.sort(0, True)
probs = probs.cpu().numpy()
idx = idx.cpu().numpy()

# %%
org_img = np.array(img_pil)

# %%
CAMs = returnCAM(features_blobs[0], weight_softmax, [idx[0]])

# render the CAM and output
org_img = np.array(img_pil,dtype=np.uint8)
org_img = org_img[:, :, ::-1].copy()
height, width, _ = org_img.shape
heatmap = cv2.applyColorMap(cv2.resize(CAMs[0],(width, height)), cv2.COLORMAP_JET)
result = heatmap * 0.3 + org_img * 0.5
cv2.imwrite('result.jpg', result) # save result
# Out:
# True

# %%
# check result by opencv 
norm_result = cv2.normalize(result, None, 0, 255, cv2.NORM_MINMAX,dtype=cv2.CV_8UC1)
concat_image = np.hstack((org_img,norm_result))
concat_image = cv2.resize(concat_image, dsize=(0, 0), fx=0.5, fy=0.5)
cv2.imshow('result',concat_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-266-b7e53fcbb8e1> in <module>
#       3 concat_image = np.hstack((org_img,norm_result))
#       4 concat_image = cv2.resize(concat_image, dsize=(0, 0), fx=0.5, fy=0.5)
# ----> 5 cv2.imshow('result',concat_image)
#       6 cv2.waitKey(0)
#       7 cv2.destroyAllWindows()
#
# error: OpenCV(3.4.2) /tmp/build/80754af9/opencv-suite_1535558553474/work/modules/highgui/src/window.cpp:632: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Carbon support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
def return_CAM(feature_conv, weight, class_idx):
    # generate the class -activation maps upsample to 256x256
    size_upsample = (224, 224)
    bz, nc, h, w = feature_conv.shape
    output_cam = []
    for idx in class_idx:
        beforeDot =  feature_conv.reshape((nc, h*w))
        cam = np.matmul(weight[idx], beforeDot)
        cam = cam.reshape(h, w)
        cam = cam - np.min(cam)
        cam_img = cam / np.max(cam)
        cam_img = np.uint8(255 * cam_img)
        output_cam.append(cv2.resize(cam_img, size_upsample))
    return output_cam

# %%
normalize = transforms.Normalize(
   mean=[0.485, 0.456, 0.406],
   std=[0.229, 0.224, 0.225]
)
preprocess = transforms.Compose([
   transforms.Resize((224,224)),
   transforms.ToTensor(),
   normalize
])

# %%
#for fname in test_dir+'covid':

fname = '/home/jimi/dissertacao/covid19/datasets/80-20/test/covid/000001.png'    
img_pil = Image.open(fname).convert('RGB')
img_tensor = preprocess(img_pil)
img_variable = Variable(img_tensor.unsqueeze(0)).cuda()
logit = model_ft(img_variable).cuda()

h_x = F.softmax(logit, dim=1).data.squeeze().cpu()

probs, idx = h_x.sort(0, True)
probs = probs.detach().numpy().argmax() 
idx = idx.numpy()

predlist.append(idx[0]) # parei aqui
predicted =  train_loader.dataset.classes[idx[0]]

print("Target: " + fname + " | Predicted: " +  predicted) 

features_blobs = mod(img_variable)
features_blobs1 = features_blobs.cpu().detach().numpy()
CAMs = return_CAM(features_blobs1, weight, [idx[0]])

readImg = '/home/jimi/dissertacao/covid19/datasets/80-20/test/covid/000001.png'
img = cv2.imread(readImg)
height, width, _ = img.shape
heatmap = cv2.applyColorMap(cv2.resize(CAMs[0],(width, height)), cv2.COLORMAP_JET)
result = heatmap * 0.5 + img * 0.5

cv2.imwrite("image_1", result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-210-96e79cbf8b8d> in <module>
#      13 idx = idx.numpy()
#      14
# ---> 15 predlist.append(idx[0]) # parei aqui
#      16 predicted =  train_loader.dataset.classes[idx[0]]
#      17
#
# AttributeError: 'Tensor' object has no attribute 'append'

# %%
from fastai.vision import *
from fastai.basics import *

model_ft.fit_one_cicle(2, max_lr=slice(2e-5, 1e-4))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-7fa4400be7f2> in <module>
#       2 from fastai.basics import *
#       3
# ----> 4 model_ft.fit_one_cicle(2, max_lr=slice(2e-5, 1e-4))
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     592                 return modules[name]
#     593         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 594             type(self).__name__, name))
#     595
#     596     def __setattr__(self, name, value):
#
# AttributeError: 'SqueezeNet' object has no attribute 'fit_one_cicle'

# %%
def images_to_probs(model_ft, images):
    '''
    Generates predictions and corresponding probabilities from a trained
    network and a list of images
    '''
     outputs = model_ft(images)
    # convert output probabilities to predicted class
    _, preds_tensor = torch.max(output, 1)
    preds = np.squeeze(preds_tensor.numpy())
    return preds, [F.softmax(el, dim=0)[i].item() for i, el in zip(preds, output)]

# %%
# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(12, 48))
for idx in np.arange(4):
    ax = fig.add_subplot(1, 4, idx+1, xticks=[], yticks=[])
    plt.imshow(predlist[idx])
    ax.set_title("{0}, {1:.1f}%\n(label: {2})".format(
        classes[predlist[idx]],
        classes[lbllist[idx]]),
        color="red")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-4a4eb66309c6> in <module>
#       3 for idx in np.arange(4):
#       4     ax = fig.add_subplot(1, 4, idx+1, xticks=[], yticks=[])
# ----> 5     plt.imshow(predlist[idx])
#       6     ax.set_title("{0}, {1:.1f}%\n(label: {2})".format(
#       7         classes[predlist[idx]],
#
# ~/.local/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# ~/.local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/.local/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5613                               resample=resample, **kwargs)
#    5614
# -> 5615         im.set_data(X)
#    5616         im.set_alpha(alpha)
#    5617         if im.get_clip_path() is None:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/image.py in set_data(self, A)
#     697                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     698             raise TypeError("Invalid shape {} for image data"
# --> 699                             .format(self._A.shape))
#     700
#     701         if self._A.ndim == 3:
#
# TypeError: Invalid shape () for image data

# %%
#roc curve
fpr, tpr, tresholds = metrics.roc_curve(lbllist.numpy(), predlist.numpy())
plt.plot(fpr, tpr)
plt.xlim[0.0, 1.0]
plt.ylim[0.0, 1.0]
plt.title('Roc Curve')
plt.xlabel('False posite rate')
plt.ylabel('True posite rate')
plt.grid(true)

# %%
# test-the-model
model_ft.eval()  # it-disables-dropout
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in dataloaders['val']:
        images = inputs.to(device)
        labels = labels.to(device)
        outputs = model_ft(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item() 
          
    print('Test Accuracy of the model: {} %'.format(100 * correct / total))

# Save 
torch.save(model_ft.state_dict(), 'model.ckpt')

# %% [markdown]
# ![Small confusion matrix](cf.png)

# %%
# Per-class accuracy
class_accuracy=100*conf_mat.diagonal()/conf_mat.sum(1)
print(class_accuracy)
# Out:
# [100.          96.74593242  97.19169719]

# %% [markdown]
# ![Small confusion matrix](cf2.png)

# %%
#quem são? listar!
#model_ft, hist

print(model_ft)
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (6): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (9): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Conv2d(512, 3, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )

# %%
print(hist)
# Out:
# [tensor(0.9274, device='cuda:0', dtype=torch.float64), tensor(0.9465, device='cuda:0', dtype=torch.float64), tensor(0.9415, device='cuda:0', dtype=torch.float64), tensor(0.9502, device='cuda:0', dtype=torch.float64), tensor(0.9552, device='cuda:0', dtype=torch.float64), tensor(0.9577, device='cuda:0', dtype=torch.float64), tensor(0.9560, device='cuda:0', dtype=torch.float64), tensor(0.9502, device='cuda:0', dtype=torch.float64), tensor(0.9593, device='cuda:0', dtype=torch.float64), tensor(0.9593, device='cuda:0', dtype=torch.float64), tensor(0.9614, device='cuda:0', dtype=torch.float64), tensor(0.9622, device='cuda:0', dtype=torch.float64), tensor(0.9622, device='cuda:0', dtype=torch.float64), tensor(0.9639, device='cuda:0', dtype=torch.float64), tensor(0.9647, device='cuda:0', dtype=torch.float64), tensor(0.9589, device='cuda:0', dtype=torch.float64), tensor(0.9643, device='cuda:0', dtype=torch.float64), tensor(0.9668, device='cuda:0', dtype=torch.float64), tensor(0.9655, device='cuda:0', dtype=torch.float64), tensor(0.9610, device='cuda:0', dtype=torch.float64), tensor(0.9655, device='cuda:0', dtype=torch.float64), tensor(0.9639, device='cuda:0', dtype=torch.float64), tensor(0.9651, device='cuda:0', dtype=torch.float64), tensor(0.9601, device='cuda:0', dtype=torch.float64), tensor(0.9668, device='cuda:0', dtype=torch.float64), tensor(0.9552, device='cuda:0', dtype=torch.float64), tensor(0.9680, device='cuda:0', dtype=torch.float64), tensor(0.9622, device='cuda:0', dtype=torch.float64), tensor(0.9531, device='cuda:0', dtype=torch.float64), tensor(0.9564, device='cuda:0', dtype=torch.float64), tensor(0.9664, device='cuda:0', dtype=torch.float64), tensor(0.9664, device='cuda:0', dtype=torch.float64), tensor(0.9631, device='cuda:0', dtype=torch.float64), tensor(0.9693, device='cuda:0', dtype=torch.float64), tensor(0.9643, device='cuda:0', dtype=torch.float64), tensor(0.9639, device='cuda:0', dtype=torch.float64), tensor(0.9639, device='cuda:0', dtype=torch.float64), tensor(0.9705, device='cuda:0', dtype=torch.float64), tensor(0.9672, device='cuda:0', dtype=torch.float64), tensor(0.9680, device='cuda:0', dtype=torch.float64), tensor(0.9664, device='cuda:0', dtype=torch.float64), tensor(0.9697, device='cuda:0', dtype=torch.float64), tensor(0.9660, device='cuda:0', dtype=torch.float64), tensor(0.9655, device='cuda:0', dtype=torch.float64), tensor(0.9672, device='cuda:0', dtype=torch.float64), tensor(0.9701, device='cuda:0', dtype=torch.float64), tensor(0.9639, device='cuda:0', dtype=torch.float64), tensor(0.9655, device='cuda:0', dtype=torch.float64), tensor(0.9581, device='cuda:0', dtype=torch.float64), tensor(0.9709, device='cuda:0', dtype=torch.float64), tensor(0.9680, device='cuda:0', dtype=torch.float64), tensor(0.9722, device='cuda:0', dtype=torch.float64), tensor(0.9689, device='cuda:0', dtype=torch.float64), tensor(0.9680, device='cuda:0', dtype=torch.float64), tensor(0.9668, device='cuda:0', dtype=torch.float64), tensor(0.9639, device='cuda:0', dtype=torch.float64), tensor(0.9676, device='cuda:0', dtype=torch.float64), tensor(0.9676, device='cuda:0', dtype=torch.float64), tensor(0.9685, device='cuda:0', dtype=torch.float64), tensor(0.9726, device='cuda:0', dtype=torch.float64), tensor(0.9639, device='cuda:0', dtype=torch.float64), tensor(0.9701, device='cuda:0', dtype=torch.float64), tensor(0.9635, device='cuda:0', dtype=torch.float64), tensor(0.9726, device='cuda:0', dtype=torch.float64), tensor(0.9680, device='cuda:0', dtype=torch.float64), tensor(0.9730, device='cuda:0', dtype=torch.float64), tensor(0.9714, device='cuda:0', dtype=torch.float64), tensor(0.9726, device='cuda:0', dtype=torch.float64), tensor(0.9668, device='cuda:0', dtype=torch.float64), tensor(0.9697, device='cuda:0', dtype=torch.float64), tensor(0.9730, device='cuda:0', dtype=torch.float64), tensor(0.9697, device='cuda:0', dtype=torch.float64), tensor(0.9726, device='cuda:0', dtype=torch.float64), tensor(0.9693, device='cuda:0', dtype=torch.float64), ten ...

# %%
type(model_ft)
# Out:
# torchvision.models.squeezenet.SqueezeNet

# %%
type(hist)
# Out:
# list

# %%
shape(model_ft)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-925f7973aa12> in <module>
# ----> 1 shape(model_ft)
#
# NameError: name 'shape' is not defined

# %%
shape(hist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c28351bd9020> in <module>
# ----> 1 shape(hist)
#
# NameError: name 'shape' is not defined

# %%
model_ft.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-3153c2148797> in <module>
# ----> 1 model_ft.shape
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     592                 return modules[name]
#     593         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 594             type(self).__name__, name))
#     595
#     596     def __setattr__(self, name, value):
#
# AttributeError: 'SqueezeNet' object has no attribute 'shape'

# %%
model_ft.hist
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-1a891aafbe74> in <module>
# ----> 1 model_ft.hist
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     592                 return modules[name]
#     593         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 594             type(self).__name__, name))
#     595
#     596     def __setattr__(self, name, value):
#
# AttributeError: 'SqueezeNet' object has no attribute 'hist'
