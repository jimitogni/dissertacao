# %% [markdown]
# <a href="https://colab.research.google.com/github/jimitogni/dissertacao/blob/master/transfer_inceptionV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import os
from numpy.random import seed
import tensorflow as tf
import torch
import pandas as pd
import numpy as np
import os, shutil
from fastai.vision import *
from fastai.widgets import ClassConfusion
import random
import matplotlib.image as mpimg 
from PIL import Image

tf.random.set_seed(100)

# %% [markdown]
# Metodo para buscar diretórios

# %%
def search_dir(type="normal", num=6):
  #funcao que ajuda scanear um diretorio
  counter = 0

  for file in os.listdir('dataset/test/covid/'):
    if counter == num:
      break

    if file.endswith(".jpeg"):
      print(file)

    counter += 1

# %% [markdown]
# Função que auxilia a plotar as imagens utilizando a biblioteca mpimg

# %%
def plot_images(type="normal", num=6):
  #auxilia ao plotar imagens
  counter = 0

  fig = plt.figure(figsize=(10,8))
  print("antes do for")
  print("list_dir = {}".format(os.listdir(train_dir)))
  print("train_dir + file = {}".format(os.listdir(train_dir + file)))

  for file in os.listdir(train_dir):
    if file.endswith(".jpeg"):
      print("passou no if 1")
      if counter == num:
        print("parrou no if 2 - nao achou nada")
        break

      img = mpimg.imread(train_dir + file)
      plt.subplot(231+counter)
      plt.title(file.split('.')[0])
      imgplot = plt.imshow(img)

      counter += 1
      print("chegou até o final do for")

# %% [markdown]
# Metodo para plotar os gráficos das curvas de aprendizado

# %%
def display_training_curves(training, validation, title, subplot):
  if subplot%10==1: #set up subplot in first call
    plt.subplots(figsize=(10,10))
    plt.tight_layout()
  ax = plt.subplot(subplot)
  ax.set_facecolor('F8F8F8')
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model' + title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['train', 'valid.'])

# %% [markdown]
# Usando a API do kaggle para baixar uma base de dados com imagens de Raios-X que contem **imagens de pulmões normais e com pneumonia**

# %%
os.environ['KAGLE_USERNAME']= "jimitogni"
os.environ['KAGLE_KEY']= "6ba3f466a063e70addd26514bb2cf41d"

# %%
# %%shell
# pip install kaggle
# export KAGGLE_USERNAME=jimitogni
# export KAGGLE_KEY=6ba3f466a063e70addd26514bb2cf41d
#
# kaggle datasets download paultimothymooney/chest-xray-pneumonia
# unzip -q chest-xray-pneumonia.zip
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.21.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.4.5.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.38.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Downloading chest-xray-pneumonia.zip to /content
# 100% 2.29G/2.29G [00:30<00:00, 12.0MB/s]
# 100% 2.29G/2.29G [00:30<00:00, 80.8MB/s]

# %% [markdown]
# Agora pegamos a base de dados que contem apenas Raios-X com imagens de pessoas contaminadas com COVID-19

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 1575 (delta 28), reused 41 (delta 18), pack-reused 1511
# Receiving objects: 100% (1575/1575), 216.44 MiB | 36.99 MiB/s, done.
# Resolving deltas: 100% (752/752), done.
# Checking out files: 100% (341/341), done.

# %% [markdown]
# Agrupando as duas bases de dados

# %%
# Load Kaggle Pneumonia Dataset
def get_dataset(path, label):
  return [[path+x, label] for x in os.listdir(path) if not x.startswith('.')]

root = 'chest_xray/chest_xray/train/'
normal_xray = get_dataset(root+'NORMAL/', 'normal')
pneumonia_xray = get_dataset(root+'PNEUMONIA/', 'pneumonia')
print(len(normal_xray), normal_xray[0:5])
print(len(pneumonia_xray), pneumonia_xray[0:5])

# Load Covid-19 Dataset
metadata_path='covid-chestxray-dataset/metadata.csv'
srcpath = 'covid-chestxray-dataset/images/'
df=pd.read_csv(metadata_path)
covid_patients=df['finding']=='COVID-19'
PA=df['view']=='PA'
PA_covid=df[covid_patients & PA]
covid_xray = [[srcpath + files, 'covid'] for files in PA_covid['filename']]
print(len(covid_xray), covid_xray[0:5])

random.shuffle(normal_xray)
random.shuffle(pneumonia_xray)
random.shuffle(covid_xray)

# gerando dados balanceados e randomizados
min_size = min(len(normal_xray), len(pneumonia_xray), len(covid_xray))-1
dataset = normal_xray[0:min_size] + covid_xray[0:min_size] + pneumonia_xray[0:min_size]
random.shuffle(dataset)

print(len(dataset), dataset[0:5])

# carregando os dados para um df pandas
df = pd.DataFrame(dataset, columns=['X', 'y']).sample(frac=1)
print(df)

X = df['X']
y = df['y']

classes= y.unique()
print(classes)

# Split em train, valid, e test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

print()
print()
print("Total de imagens {}, Dados para: treino={}, Validação={} e Teste={} ".format(len(df), len(X_train), len(X_val), len(X_test)))

# !rm -rf dataset/ #remove a pasta se ela ja existir

#cria uma nova pasta com as duas bases de dados agrupadas
for dtype, dinputs, doutputs in [['train', X_train, y_train], ['val', X_val, y_val], ['test', X_test, y_test]]:
  for _X, _y in zip(dinputs, doutputs):
    path = 'dataset/'+dtype+'/'+_y
    os.makedirs(path, exist_ok=True)
    # print(_X, path)
    shutil.copy(_X, path)

# !tar -czf dataset.tar.gz dataset/ #guarda toda a base obtida em um arquivo zip
# Out:
# 1341 [['chest_xray/chest_xray/train/NORMAL/IM-0355-0001.jpeg', 'normal'], ['chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0809-0001.jpeg', 'normal'], ['chest_xray/chest_xray/train/NORMAL/IM-0312-0001.jpeg', 'normal'], ['chest_xray/chest_xray/train/NORMAL/IM-0593-0001.jpeg', 'normal'], ['chest_xray/chest_xray/train/NORMAL/IM-0490-0001.jpeg', 'normal']]
# 3875 [['chest_xray/chest_xray/train/PNEUMONIA/person151_virus_301.jpeg', 'pneumonia'], ['chest_xray/chest_xray/train/PNEUMONIA/person489_virus_994.jpeg', 'pneumonia'], ['chest_xray/chest_xray/train/PNEUMONIA/person441_bacteria_1915.jpeg', 'pneumonia'], ['chest_xray/chest_xray/train/PNEUMONIA/person440_bacteria_1897.jpeg', 'pneumonia'], ['chest_xray/chest_xray/train/PNEUMONIA/person1339_bacteria_3399.jpeg', 'pneumonia']]
# 133 [['covid-chestxray-dataset/images/auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg', 'covid'], ['covid-chestxray-dataset/images/auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg', 'covid'], ['covid-chestxray-dataset/images/auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg', 'covid'], ['covid-chestxray-dataset/images/auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg', 'covid'], ['covid-chestxray-dataset/images/nejmc2001573_f1a.jpeg', 'covid']]
# 396 [['chest_xray/chest_xray/train/PNEUMONIA/person1756_bacteria_4598.jpeg', 'pneumonia'], ['covid-chestxray-dataset/images/radiol.2020200274.fig3d.png', 'covid'], ['covid-chestxray-dataset/images/80446565-E090-4187-A031-9D3CEAA586C8.jpeg', 'covid'], ['chest_xray/chest_xray/train/PNEUMONIA/person630_bacteria_2512.jpeg', 'pneumonia'], ['covid-chestxray-dataset/images/ryct.2020200034.fig5-day4.jpeg', 'covid']]
#                                                      X          y
# 303  chest_xray/chest_xray/train/PNEUMONIA/person73...  pneumonia
# 239  covid-chestxray-dataset/images/58cb9263f16e943...      covid
# 111  chest_xray/chest_xray/train/NORMAL/IM-0624-000...     normal
# 67   chest_xray/chest_xray/train/PNEUMONIA/person27...  pneumonia
# 338  chest_xray/chest_xray/train/NORMAL/IM-0526-000...     normal
# ..                                                 ...        ...
# 8    chest_xray/chest_xray/train/NORMAL/IM-0608-000...     normal
# 349  chest_xray/chest_xray/train/NORMAL/IM-0399-000...     normal
# 278  chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-...     normal
# 56   chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-...     normal
# 392  chest_xray/chest_xray/train/PNEUMONIA/person14...  pneumonia
#
# [396 rows x 2 columns]
# ['pneumonia' 'covid' 'normal']
#
#
# Total de imagens 396, Dados para: treino=252, Validação=64 e Teste=80

# %%
#explore data
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#amostras de imagens com rotulos
def stage(data):
  print("distribuição da divisão das bases: treino - validação - teste, respectivamente:", len(data.train_ds),len(data.valid_ds),len(data.test_ds.x))
  print("classes", data.classes)
  data.show_batch(20)
  return None

tfms = get_transforms(do_flip=True, flip_vert=False, max_rotate=15.0, max_lighting=0.1, max_zoom=1.05)#, max_warp=0.

data = ImageDataBunch.from_folder('dataset', train="train", valid='val',test='test', ds_tfms=get_transforms(tfms), bs=9, size=512, num_workers=4).normalize()
stage(data)
# Out:
# distribuição da divisão das bases: treino - validação - teste, respectivamente: 252 64 80
# classes ['covid', 'normal', 'pneumonia']

# %%
#diretorios
train_dir = "dataset/train/"
val_dir = "dataset/val/"
test_dir = "dataset/test/"

# %%
search_dir(type="pneumonia", num=10)
search_dir(type="normal", num=10)
search_dir(type="covid", num=10)
# Out:
# ryct.2020200034.fig5-day7.jpeg
# 16669_1_1.jpeg
# 53EC07C9-5CC6-4BE4-9B6F-D7B0D72AAA7E.jpeg
# ryct.2020200034.fig5-day7.jpeg
# 16669_1_1.jpeg
# 53EC07C9-5CC6-4BE4-9B6F-D7B0D72AAA7E.jpeg
# ryct.2020200034.fig5-day7.jpeg
# 16669_1_1.jpeg
# 53EC07C9-5CC6-4BE4-9B6F-D7B0D72AAA7E.jpeg

# %% [markdown]
# Plotando apelas imagens com covid

# %%
#plot_images(type="pneumonia", num=6)
#auxilia ao plotar imagens
counter = 0
num = 6
#print(type(train_dir))

fig = plt.figure(figsize=(14,12))
#print("antes do for")
#print("list_dir train_dir = {}".format(os.listdir(train_dir)))
#print("train_dir + file = {}".format(os.listdir(train_dir + file)))

for file in os.listdir('dataset/train/covid/'):
  #print('dataset/train/covid/' + file)
  if file.endswith(".jpeg"):
    #print("passou no if 1")
    if counter == num:
      #print("parrou no if 2 - nao achou nada")
      break

    img = mpimg.imread('dataset/train/covid/' + file)
    plt.subplot(231+counter)
    plt.title(file.split('.')[0])
    imgplot = plt.imshow(img)

    counter += 1
    #print("chegou até o final do for")

# %% [markdown]
# Plotando imagens normais

# %%
#plot_images(type="pneumonia", num=6)
#auxilia ao plotar imagens
counter = 0
num = 6
#print(type(train_dir))

fig = plt.figure(figsize=(10,8))
#print("antes do for")
#print("list_dir train_dir = {}".format(os.listdir(train_dir)))
#print("train_dir + file = {}".format(os.listdir(train_dir + file)))

for file in os.listdir('dataset/train/normal/'):
  #print('dataset/train/covid/' + file)
  if file.endswith(".jpeg"):
    #print("passou no if 1")
    if counter == num:
      #print("parrou no if 2 - nao achou nada")
      break

    img = mpimg.imread('dataset/train/normal/' + file)
    plt.subplot(231+counter)
    plt.title(file.split('.')[0])
    imgplot = plt.imshow(img)

    counter += 1
    #print("chegou até o final do for")

# %% [markdown]
# **MODELO**
# pre trerinado usando a rede inceptionV3

# %%
import numpy as np

from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input, decode_predictions

from tensorflow.python.keras.preprocessing import image

# %%
pre_model = InceptionV3(weights="imagenet") #carrega o modelo com os pesos da imagenet

# %% [markdown]
# ------

# %% [markdown]
# Testando a classificalção com um imagem qualquer para ver o que a rede retorna antes de ser treinada com os nossos dados

# %%
img = image.load_img("/content/dataset/train/covid/covid-19-pneumonia-58-day-7.jpg", target_size=(299, 299))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

y = pre_model.predict(x)

for index, res in enumerate(decode_predictions(y)[0]):
  print('{}. {}: {:.3f}%'.format(index + 1, res[1], 100* res[2]))
# Out:
# 1. plastic_bag: 3.106%
# 2. quill: 2.632%
# 3. groom: 2.417%
# 4. black_and_gold_garden_spider: 1.885%
# 5. mosquito_net: 1.841%

# %%
#img = mpimg.imread("example_2.jpg")
#imgplot = plt.imshow(img)

# %% [markdown]
# preparação dos dados

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
batch_size = 163

#criando gerador para dados de treinamento
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1) #cria um gerador de imagem no abstract

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir, #diretorio com os dados de treino
    target_size=(150,150), #tamanho da imagem que queremos
    batch_size=batch_size, #quantos arquivos para ler de cada vez
    class_mode="categorical"
)
# Out:
# Found 252 images belonging to 3 classes.

# %%
#gerando dados para validação

val_datagen = ImageDataGenerator(rescale=1./255)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(150,150),
    batch_size=batch_size,
    class_mode="categorical",
)
# Out:
# Found 64 images belonging to 3 classes.

# %%
#gerando dados para teste

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(150,150),
    batch_size=1,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 80 images belonging to 3 classes.

# %% [markdown]
# #MODELO PARA TREINO EXCLUINDO A PRIMEIRA CAMADA

# %%
import keras

# %%
base_model = InceptionV3(weights='imagenet', include_top=False)

x = base_model.output
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dense(1024, activation='relu')(x)
x = keras.layers.BatchNormalization()(x)
predictions = keras.layers.Dense(3, activation='softmax')(x)

for layer in base_model.layers:
  layer.trainable = False #congela os layers para nao treinar

final_model = keras.models.Model(inputs=base_model.inputs, outputs=predictions) #modelo final

# %%
final_model.compile(loss="categorical_crossentropy", # log loss
                    optimizer="adam",
                    metrics=["accuracy"])

# %%
final_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_659 (Conv2D)             (None, None, None, 3 864         input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_663 (BatchN (None, None, None, 3 96          conv2d_659[0][0]
# __________________________________________________________________________________________________
# activation_659 (Activation)     (None, None, None, 3 0           batch_normalization_663[0][0]
# __________________________________________________________________________________________________
# conv2d_660 (Conv2D)             (None, None, None, 3 9216        activation_659[0][0]
# __________________________________________________________________________________________________
# batch_normalization_664 (BatchN (None, None, None, 3 96          conv2d_660[0][0]
# __________________________________________________________________________________________________
# activation_660 (Activation)     (None, None, None, 3 0           batch_normalization_664[0][0]
# __________________________________________________________________________________________________
# conv2d_661 (Conv2D)             (None, None, None, 6 18432       activation_660[0][0]
# __________________________________________________________________________________________________
# batch_normalization_665 (BatchN (None, None, None, 6 192         conv2d_661[0][0]
# __________________________________________________________________________________________________
# activation_661 (Activation)     (None, None, None, 6 0           batch_normalization_665[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, None, None, 6 0           activation_661[0][0]
# __________________________________________________________________________________________________
# conv2d_662 (Conv2D)             (None, None, None, 8 5120        max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_666 (BatchN (None, None, None, 8 240         conv2d_662[0][0]
# __________________________________________________________________________________________________
# activation_662 (Activation)     (None, None, None, 8 0           batch_normalization_666[0][0]
# __________________________________________________________________________________________________
# conv2d_663 (Conv2D)             (None, None, None, 1 138240      activation_662[0][0]
# __________________________________________________________________________________________________
# batch_normalization_667 (BatchN (None, None, None, 1 576         conv2d_663[0][0]
# __________________________________________________________________________________________________
# activation_663 (Activation)     (None, None, None, 1 0           batch_normalization_667[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, None, None, 1 0           activation_663[0][0]
# __________________________________________________________________________________________________
# conv2d_667 (Conv2D)             (None, None, None, 6 12288       max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_671 (BatchN (None, None, None, 6 192         conv2d_667[0][0]
# __________________________________________________________________________________________________
# activation_667 (Activation)     (None, None, None, 6 0           batch_normalization_671[0][0]
# __________________________________________________________________________________________________
# conv2d_665 (Conv2D)             (None, None, None, 4 9216        max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_668 (Conv2D)             (None, None, None, 9 55296       activation_667[0][0]
# __________________________________________________________________________________________________
# batch_normalization_669 (BatchN (None, None, None, 4 144         conv2d_665[0][0]
# __________________________________________________________________________________________________
# batch_normalization_672 (BatchN (None, None, None, 9 288         conv2d_668[0][0]
# __________________________________________________________________________________________________
# activation_665 (Activation)     (None, None, None, 4 0           batch_normalization_669[0][0]
# __________________________________________________________________________________________________
# activation_668 (Activation)     (None, None, None, 9 0           batch_normalization_672[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_64 (AveragePo (None, None, None, 1 0           max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_664 (Conv2D)             (None, None, None, 6 12288       max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_666 (Conv2D)             (None, None, None, 6 76800       activation_665[0][0]
# __________________________________________________________________________________________________
# conv2d_669 (Conv2D)             (None, None, None, 9 82944       activation_668[0][0]
# __________________________________________________________________________________________________
# conv2d_670 (Conv2D)             (None, None, None, 3 6144        average_pooling2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_668 (BatchN (None, None, None, 6 192         conv2d_664[0][0]
# __________________________________________________________________________________________________
# batch_normalization_670 (BatchN (None, None, None, 6 192         conv2d_666[0][0]
# __________________________________________________________________________________________________
# batch_normalization_673 (BatchN (None, None, None, 9 288         conv2d_669[0][0]
# __________________________________________________________________________________________________
# batch_normalization_674 (BatchN (None, None, None, 3 96          conv2d_670[0][0]
# __________________________________________________________________________________________________
# activation_664 (Activation)     (None, None, None, 6 0           batch_normalization_668[0][0]
# __________________________________________________________________________________________________
# activation_666 (Activation)     (None, None, None, 6 0           batch_normalization_670[0][0]
# __________________________________________________________________________________________________
# activation_669 (Activation)     (None, None, None, 9 0           batch_normalization_673[0][0]
# __________________________________________________________________________________________________
# activation_670 (Activation)     (None, None, None, 3 0           batch_normalization_674[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, None, None, 2 0           activation_664[0][0]
#                                                                  activation_666[0][0]
#                                                                  activation_669[0][0]
#                                                                  activation_670[0][0]
# __________________________________________________________________________________________________
# conv2d_674 (Conv2D)             (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_678 (BatchN (None, None, None, 6 192         conv2d_674[0][0]
# __________________________________________________________________________________________________
# activation_674 (Activation)     (None, None, None, 6 0           batch_normalization_678[0][0]
# __________________________________________________________________________________________________
# conv2d_672 (Conv2D)             (None, None, None, 4 12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_675 (Conv2D)             (None, None, None, 9 55296       activation_674[0][0]
# __________________________________________________________________________________________________
# batch_normalization_676 (BatchN (None, None, None, 4 144         conv2d_672[0][0]
# __________________________________________________________________________________________________
# batch_normalization_679 (BatchN (None, None, None, 9 288         conv2d_675[0][0]
# __________________________________________________________________________________________________
# activation_672 (Activation)     (None, None, None, 4 0           batch_normalization_676[0][0]
# __________________________________________________________________________________________________
# activation_675 (Activation)     (None, None, None, 9 0           batch_normalization_679[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_65 (AveragePo (None, None, None, 2 0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_671 (Conv2D)             (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_673 (Conv2D)             (None, None, None, 6 76800       activation_672[0][0]
# __________________________________________________________________________________________________
# conv2d_676 (Conv2D)             (None, None, None, 9 82944       activation_675[0][0]
# __________________________________________________________________________________________________
# conv2d_677 (Conv2D)             (None, None, None, 6 16384       average_pooling2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_675 (BatchN (None, None, None, 6 192         conv2d_671[0][0]
# __________________________________________________________________________________________________
# batch_normalization_677 (BatchN (None, None, None, 6 192         conv2d_673[0][0]
# __________________________________________________________________________________________________
# batch_normalization_680 (BatchN (None, None, None, 9 288         conv2d_676[0][0]
# __________________________________________________________________________________________________
# batch_normalization_681 (BatchN (None, None, None, 6 192         conv2d_677[0][0]
# __________________________________________________________________________________________________
# activation_671 (Activation)     (None, None, None, 6 0           batch_normalization_675[0][0]
# __________________________________________________________________________________________________
# activation_673 (Activation)     (None, None, None, 6 0           batch_normalization_677[0][0]
# __________________________________________________________________________________________________
# activation_676 (Activation)     (None, None, None, 9 0           batch_normalization_680[0][0]
# __________________________________________________________________________________________________
# activation_677 (Activation)     (None, None, None, 6 0           batch_normalization_681[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, None, None, 2 0           activation_671[0][0]
#                                                                  activation_673[0][0]
#                                                                  activation_676[0][0]
#                                                                  activation_677[0][0]
# __________________________________________________________________________________________________
# conv2d_681 (Conv2D)             (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_685 (BatchN (None, None, None, 6 192         conv2d_681[0][0]
# __________________________________________________________________________________________________
# activation_681 (Activation)     (None, None, None, 6 0           batch_normalization_685[0][0]
# __________________________________________________________________________________________________
# conv2d_679 (Conv2D)             (None, None, None, 4 13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_682 (Conv2D)             (None, None, None, 9 55296       activation_681[0][0]
# __________________________________________________________________________________________________
# batch_normalization_683 (BatchN (None, None, None, 4 144         conv2d_679[0][0]
# __________________________________________________________________________________________________
# batch_normalization_686 (BatchN (None, None, None, 9 288         conv2d_682[0][0]
# __________________________________________________________________________________________________
# activation_679 (Activation)     (None, None, None, 4 0           batch_normalization_683[0][0]
# __________________________________________________________________________________________________
# activation_682 (Activation)     (None, None, None, 9 0           batch_normalization_686[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_66 (AveragePo (None, None, None, 2 0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_678 (Conv2D)             (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_680 (Conv2D)             (None, None, None, 6 76800       activation_679[0][0]
# __________________________________________________________________________________________________
# conv2d_683 (Conv2D)             (None, None, None, 9 82944       activation_682[0][0]
# __________________________________________________________________________________________________
# conv2d_684 (Conv2D)             (None, None, None, 6 18432       average_pooling2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_682 (BatchN (None, None, None, 6 192         conv2d_678[0][0]
# __________________________________________________________________________________________________
# batch_normalization_684 (BatchN (None, None, None, 6 192         conv2d_680[0][0]
# __________________________________________________________________________________________________
# batch_normalization_687 (BatchN (None, None, None, 9 288         conv2d_683[0][0]
# __________________________________________________________________________________________________
# batch_normalization_688 (BatchN (None, None, None, 6 192         conv2d_684[0][0]
# __________________________________________________________________________________________________
# activation_678 (Activation)     (None, None, None, 6 0           batch_normalization_682[0][0]
# __________________________________________________________________________________________________
# activation_680 (Activation)     (None, None, None, 6 0           batch_normalization_684[0][0]
# __________________________________________________________________________________________________
# activation_683 (Activation)     (None, None, None, 9 0           batch_normalization_687[0][0]
# __________________________________________________________________________________________________
# activation_684 (Activation)     (None, None, None, 6 0           batch_normalization_688[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, None, None, 2 0           activation_678[0][0]
#                                                                  activation_680[0][0]
#                                                                  activation_683[0][0]
#                                                                  activation_684[0][0]
# __________________________________________________________________________________________________
# conv2d_686 (Conv2D)             (None, None, None, 6 18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_690 (BatchN (None, None, None, 6 192         conv2d_686[0][0]
# __________________________________________________________________________________________________
# activation_686 (Activation)     (None, None, None, 6 0           batch_normalization_690[0][0]
# __________________________________________________________________________________________________
# conv2d_687 (Conv2D)             (None, None, None, 9 55296       activation_686[0][0]
# __________________________________________________________________________________________________
# batch_normalization_691 (BatchN (None, None, None, 9 288         conv2d_687[0][0]
# __________________________________________________________________________________________________
# activation_687 (Activation)     (None, None, None, 9 0           batch_normalization_691[0][0]
# __________________________________________________________________________________________________
# conv2d_685 (Conv2D)             (None, None, None, 3 995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_688 (Conv2D)             (None, None, None, 9 82944       activation_687[0][0]
# __________________________________________________________________________________________________
# batch_normalization_689 (BatchN (None, None, None, 3 1152        conv2d_685[0][0]
# __________________________________________________________________________________________________
# batch_normalization_692 (BatchN (None, None, None, 9 288         conv2d_688[0][0]
# __________________________________________________________________________________________________
# activation_685 (Activation)     (None, None, None, 3 0           batch_normalization_689[0][0]
# __________________________________________________________________________________________________
# activation_688 (Activation)     (None, None, None, 9 0           batch_normalization_692[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, None, None, 2 0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, None, None, 7 0           activation_685[0][0]
#                                                                  activation_688[0][0]
#                                                                  max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_693 (Conv2D)             (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_697 (BatchN (None, None, None, 1 384         conv2d_693[0][0]
# __________________________________________________________________________________________________
# activation_693 (Activation)     (None, None, None, 1 0           batch_normalization_697[0][0]
# __________________________________________________________________________________________________
# conv2d_694 (Conv2D)             (None, None, None, 1 114688      activation_693[0][0]
# __________________________________________________________________________________________________
# batch_normalization_698 (BatchN (None, None, None, 1 384         conv2d_694[0][0]
# __________________________________________________________________________________________________
# activation_694 (Activation)     (None, None, None, 1 0           batch_normalization_698[0][0]
# __________________________________________________________________________________________________
# conv2d_690 (Conv2D)             (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_695 (Conv2D)             (None, None, None, 1 114688      activation_694[0][0]
# __________________________________________________________________________________________________
# batch_normalization_694 (BatchN (None, None, None, 1 384         conv2d_690[0][0]
# __________________________________________________________________________________________________
# batch_normalization_699 (BatchN (None, None, None, 1 384         conv2d_695[0][0]
# __________________________________________________________________________________________________
# activation_690 (Activation)     (None, None, None, 1 0           batch_normalization_694[0][0]
# __________________________________________________________________________________________________
# activation_695 (Activation)     (None, None, None, 1 0           batch_normalization_699[0][0]
# __________________________________________________________________________________________________
# conv2d_691 (Conv2D)             (None, None, None, 1 114688      activation_690[0][0]
# __________________________________________________________________________________________________
# conv2d_696 (Conv2D)             (None, None, None, 1 114688      activation_695[0][0]
# __________________________________________________________________________________________________
# batch_normalization_695 (BatchN (None, None, None, 1 384         conv2d_691[0][0]
# __________________________________________________________________________________________________
# batch_normalization_700 (BatchN (None, None, None, 1 384         conv2d_696[0][0]
# __________________________________________________________________________________________________
# activation_691 (Activation)     (None, None, None, 1 0           batch_normalization_695[0][0]
# __________________________________________________________________________________________________
# activation_696 (Activation)     (None, None, None, 1 0           batch_normalization_700[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_67 (AveragePo (None, None, None, 7 0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_689 (Conv2D)             (None, None, None, 1 147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_692 (Conv2D)             (None, None, None, 1 172032      activation_691[0][0]
# __________________________________________________________________________________________________
# conv2d_697 (Conv2D)             (None, None, None, 1 172032      activation_696[0][0]
# __________________________________________________________________________________________________
# conv2d_698 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_693 (BatchN (None, None, None, 1 576         conv2d_689[0][0]
# __________________________________________________________________________________________________
# batch_normalization_696 (BatchN (None, None, None, 1 576         conv2d_692[0][0]
# __________________________________________________________________________________________________
# batch_normalization_701 (BatchN (None, None, None, 1 576         conv2d_697[0][0]
# __________________________________________________________________________________________________
# batch_normalization_702 (BatchN (None, None, None, 1 576         conv2d_698[0][0]
# __________________________________________________________________________________________________
# activation_689 (Activation)     (None, None, None, 1 0           batch_normalization_693[0][0]
# __________________________________________________________________________________________________
# activation_692 (Activation)     (None, None, None, 1 0           batch_normalization_696[0][0]
# __________________________________________________________________________________________________
# activation_697 (Activation)     (None, None, None, 1 0           batch_normalization_701[0][0]
# __________________________________________________________________________________________________
# activation_698 (Activation)     (None, None, None, 1 0           batch_normalization_702[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, None, None, 7 0           activation_689[0][0]
#                                                                  activation_692[0][0]
#                                                                  activation_697[0][0]
#                                                                  activation_698[0][0]
# __________________________________________________________________________________________________
# conv2d_703 (Conv2D)             (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_707 (BatchN (None, None, None, 1 480         conv2d_703[0][0]
# __________________________________________________________________________________________________
# activation_703 (Activation)     (None, None, None, 1 0           batch_normalization_707[0][0]
# __________________________________________________________________________________________________
# conv2d_704 (Conv2D)             (None, None, None, 1 179200      activation_703[0][0]
# __________________________________________________________________________________________________
# batch_normalization_708 (BatchN (None, None, None, 1 480         conv2d_704[0][0]
# __________________________________________________________________________________________________
# activation_704 (Activation)     (None, None, None, 1 0           batch_normalization_708[0][0]
# __________________________________________________________________________________________________
# conv2d_700 (Conv2D)             (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_705 (Conv2D)             (None, None, None, 1 179200      activation_704[0][0]
# __________________________________________________________________________________________________
# batch_normalization_704 (BatchN (None, None, None, 1 480         conv2d_700[0][0]
# __________________________________________________________________________________________________
# batch_normalization_709 (BatchN (None, None, None, 1 480         conv2d_705[0][0]
# __________________________________________________________________________________________________
# activation_700 (Activation)     (None, None, None, 1 0           batch_normalization_704[0][0]
# __________________________________________________________________________________________________
# activation_705 (Activation)     (None, None, None, 1 0           batch_normalization_709[0][0]
# __________________________________________________________________________________________________
# conv2d_701 (Conv2D)             (None, None, None, 1 179200      activation_700[0][0]
# __________________________________________________________________________________________________
# conv2d_706 (Conv2D)             (None, None, None, 1 179200      activation_705[0][0]
# __________________________________________________________________________________________________
# batch_normalization_705 (BatchN (None, None, None, 1 480         conv2d_701[0][0]
# __________________________________________________________________________________________________
# batch_normalization_710 (BatchN (None, None, None, 1 480         conv2d_706[0][0]
# __________________________________________________________________________________________________
# activation_701 (Activation)     (None, None, None, 1 0           batch_normalization_705[0][0]
# __________________________________________________________________________________________________
# activation_706 (Activation)     (None, None, None, 1 0           batch_normalization_710[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_68 (AveragePo (None, None, None, 7 0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_699 (Conv2D)             (None, None, None, 1 147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_702 (Conv2D)             (None, None, None, 1 215040      activation_701[0][0]
# __________________________________________________________________________________________________
# conv2d_707 (Conv2D)             (None, None, None, 1 215040      activation_706[0][0]
# __________________________________________________________________________________________________
# conv2d_708 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_703 (BatchN (None, None, None, 1 576         conv2d_699[0][0]
# __________________________________________________________________________________________________
# batch_normalization_706 (BatchN (None, None, None, 1 576         conv2d_702[0][0]
# __________________________________________________________________________________________________
# batch_normalization_711 (BatchN (None, None, None, 1 576         conv2d_707[0][0]
# __________________________________________________________________________________________________
# batch_normalization_712 (BatchN (None, None, None, 1 576         conv2d_708[0][0]
# __________________________________________________________________________________________________
# activation_699 (Activation)     (None, None, None, 1 0           batch_normalization_703[0][0]
# __________________________________________________________________________________________________
# activation_702 (Activation)     (None, None, None, 1 0           batch_normalization_706[0][0]
# __________________________________________________________________________________________________
# activation_707 (Activation)     (None, None, None, 1 0           batch_normalization_711[0][0]
# __________________________________________________________________________________________________
# activation_708 (Activation)     (None, None, None, 1 0           batch_normalization_712[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, None, None, 7 0           activation_699[0][0]
#                                                                  activation_702[0][0]
#                                                                  activation_707[0][0]
#                                                                  activation_708[0][0]
# __________________________________________________________________________________________________
# conv2d_713 (Conv2D)             (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_717 (BatchN (None, None, None, 1 480         conv2d_713[0][0]
# __________________________________________________________________________________________________
# activation_713 (Activation)     (None, None, None, 1 0           batch_normalization_717[0][0]
# __________________________________________________________________________________________________
# conv2d_714 (Conv2D)             (None, None, None, 1 179200      activation_713[0][0]
# __________________________________________________________________________________________________
# batch_normalization_718 (BatchN (None, None, None, 1 480         conv2d_714[0][0]
# __________________________________________________________________________________________________
# activation_714 (Activation)     (None, None, None, 1 0           batch_normalization_718[0][0]
# __________________________________________________________________________________________________
# conv2d_710 (Conv2D)             (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_715 (Conv2D)             (None, None, None, 1 179200      activation_714[0][0]
# __________________________________________________________________________________________________
# batch_normalization_714 (BatchN (None, None, None, 1 480         conv2d_710[0][0]
# __________________________________________________________________________________________________
# batch_normalization_719 (BatchN (None, None, None, 1 480         conv2d_715[0][0]
# __________________________________________________________________________________________________
# activation_710 (Activation)     (None, None, None, 1 0           batch_normalization_714[0][0]
# __________________________________________________________________________________________________
# activation_715 (Activation)     (None, None, None, 1 0           batch_normalization_719[0][0]
# __________________________________________________________________________________________________
# conv2d_711 (Conv2D)             (None, None, None, 1 179200      activation_710[0][0]
# __________________________________________________________________________________________________
# conv2d_716 (Conv2D)             (None, None, None, 1 179200      activation_715[0][0]
# __________________________________________________________________________________________________
# batch_normalization_715 (BatchN (None, None, None, 1 480         conv2d_711[0][0]
# __________________________________________________________________________________________________
# batch_normalization_720 (BatchN (None, None, None, 1 480         conv2d_716[0][0]
# __________________________________________________________________________________________________
# activation_711 (Activation)     (None, None, None, 1 0           batch_normalization_715[0][0]
# __________________________________________________________________________________________________
# activation_716 (Activation)     (None, None, None, 1 0           batch_normalization_720[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_69 (AveragePo (None, None, None, 7 0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_709 (Conv2D)             (None, None, None, 1 147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_712 (Conv2D)             (None, None, None, 1 215040      activation_711[0][0]
# __________________________________________________________________________________________________
# conv2d_717 (Conv2D)             (None, None, None, 1 215040      activation_716[0][0]
# __________________________________________________________________________________________________
# conv2d_718 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_713 (BatchN (None, None, None, 1 576         conv2d_709[0][0]
# __________________________________________________________________________________________________
# batch_normalization_716 (BatchN (None, None, None, 1 576         conv2d_712[0][0]
# __________________________________________________________________________________________________
# batch_normalization_721 (BatchN (None, None, None, 1 576         conv2d_717[0][0]
# __________________________________________________________________________________________________
# batch_normalization_722 (BatchN (None, None, None, 1 576         conv2d_718[0][0]
# __________________________________________________________________________________________________
# activation_709 (Activation)     (None, None, None, 1 0           batch_normalization_713[0][0]
# __________________________________________________________________________________________________
# activation_712 (Activation)     (None, None, None, 1 0           batch_normalization_716[0][0]
# __________________________________________________________________________________________________
# activation_717 (Activation)     (None, None, None, 1 0           batch_normalization_721[0][0]
# __________________________________________________________________________________________________
# activation_718 (Activation)     (None, None, None, 1 0           batch_normalization_722[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, None, None, 7 0           activation_709[0][0]
#                                                                  activation_712[0][0]
#                                                                  activation_717[0][0]
#                                                                  activation_718[0][0]
# __________________________________________________________________________________________________
# conv2d_723 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_727 (BatchN (None, None, None, 1 576         conv2d_723[0][0]
# __________________________________________________________________________________________________
# activation_723 (Activation)     (None, None, None, 1 0           batch_normalization_727[0][0]
# __________________________________________________________________________________________________
# conv2d_724 (Conv2D)             (None, None, None, 1 258048      activation_723[0][0]
# __________________________________________________________________________________________________
# batch_normalization_728 (BatchN (None, None, None, 1 576         conv2d_724[0][0]
# __________________________________________________________________________________________________
# activation_724 (Activation)     (None, None, None, 1 0           batch_normalization_728[0][0]
# __________________________________________________________________________________________________
# conv2d_720 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_725 (Conv2D)             (None, None, None, 1 258048      activation_724[0][0]
# __________________________________________________________________________________________________
# batch_normalization_724 (BatchN (None, None, None, 1 576         conv2d_720[0][0]
# __________________________________________________________________________________________________
# batch_normalization_729 (BatchN (None, None, None, 1 576         conv2d_725[0][0]
# __________________________________________________________________________________________________
# activation_720 (Activation)     (None, None, None, 1 0           batch_normalization_724[0][0]
# __________________________________________________________________________________________________
# activation_725 (Activation)     (None, None, None, 1 0           batch_normalization_729[0][0]
# __________________________________________________________________________________________________
# conv2d_721 (Conv2D)             (None, None, None, 1 258048      activation_720[0][0]
# __________________________________________________________________________________________________
# conv2d_726 (Conv2D)             (None, None, None, 1 258048      activation_725[0][0]
# __________________________________________________________________________________________________
# batch_normalization_725 (BatchN (None, None, None, 1 576         conv2d_721[0][0]
# __________________________________________________________________________________________________
# batch_normalization_730 (BatchN (None, None, None, 1 576         conv2d_726[0][0]
# __________________________________________________________________________________________________
# activation_721 (Activation)     (None, None, None, 1 0           batch_normalization_725[0][0]
# __________________________________________________________________________________________________
# activation_726 (Activation)     (None, None, None, 1 0           batch_normalization_730[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_70 (AveragePo (None, None, None, 7 0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_719 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_722 (Conv2D)             (None, None, None, 1 258048      activation_721[0][0]
# __________________________________________________________________________________________________
# conv2d_727 (Conv2D)             (None, None, None, 1 258048      activation_726[0][0]
# __________________________________________________________________________________________________
# conv2d_728 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_723 (BatchN (None, None, None, 1 576         conv2d_719[0][0]
# __________________________________________________________________________________________________
# batch_normalization_726 (BatchN (None, None, None, 1 576         conv2d_722[0][0]
# __________________________________________________________________________________________________
# batch_normalization_731 (BatchN (None, None, None, 1 576         conv2d_727[0][0]
# __________________________________________________________________________________________________
# batch_normalization_732 (BatchN (None, None, None, 1 576         conv2d_728[0][0]
# __________________________________________________________________________________________________
# activation_719 (Activation)     (None, None, None, 1 0           batch_normalization_723[0][0]
# __________________________________________________________________________________________________
# activation_722 (Activation)     (None, None, None, 1 0           batch_normalization_726[0][0]
# __________________________________________________________________________________________________
# activation_727 (Activation)     (None, None, None, 1 0           batch_normalization_731[0][0]
# __________________________________________________________________________________________________
# activation_728 (Activation)     (None, None, None, 1 0           batch_normalization_732[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, None, None, 7 0           activation_719[0][0]
#                                                                  activation_722[0][0]
#                                                                  activation_727[0][0]
#                                                                  activation_728[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv2d_734 (Conv2D)             (None, None, None, 1 331776      activation_733[0][0]
# __________________________________________________________________________________________________
# batch_normalization_734 (BatchN (None, None, None, 3 960         conv2d_730[0][0]
# __________________________________________________________________________________________________
# batch_normalization_738 (BatchN (None, None, None, 1 576         conv2d_734[0][0]
# __________________________________________________________________________________________________
# activation_730 (Activation)     (None, None, None, 3 0           batch_normalization_734[0][0]
# __________________________________________________________________________________________________
# activation_734 (Activation)     (None, None, None, 1 0           batch_normalization_738[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, None, None, 7 0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, None, None, 1 0           activation_730[0][0]
#                                                                  activation_734[0][0]
#                                                                  max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_739 (Conv2D)             (None, None, None, 4 573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_743 (BatchN (None, None, None, 4 1344        conv2d_739[0][0]
# __________________________________________________________________________________________________
# activation_739 (Activation)     (None, None, None, 4 0           batch_normalization_743[0][0]
# __________________________________________________________________________________________________
# conv2d_736 (Conv2D)             (None, None, None, 3 491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_740 (Conv2D)             (None, None, None, 3 1548288     activation_739[0][0]
# __________________________________________________________________________________________________
# batch_normalization_740 (BatchN (None, None, None, 3 1152        conv2d_736[0][0]
# __________________________________________________________________________________________________
# batch_normalization_744 (BatchN (None, None, None, 3 1152        conv2d_740[0][0]
# __________________________________________________________________________________________________
# activation_736 (Activation)     (None, None, None, 3 0           batch_normalization_740[0][0]
# __________________________________________________________________________________________________
# activation_740 (Activation)     (None, None, None, 3 0           batch_normalization_744[0][0]
# __________________________________________________________________________________________________
# conv2d_737 (Conv2D)             (None, None, None, 3 442368      activation_736[0][0]
# __________________________________________________________________________________________________
# conv2d_738 (Conv2D)             (None, None, None, 3 442368      activation_736[0][0]
# __________________________________________________________________________________________________
# conv2d_741 (Conv2D)             (None, None, None, 3 442368      activation_740[0][0]
# __________________________________________________________________________________________________
# conv2d_742 (Conv2D)             (None, None, None, 3 442368      activation_740[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_71 (AveragePo (None, None, None, 1 0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_735 (Conv2D)             (None, None, None, 3 409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_741 (BatchN (None, None, None, 3 1152        conv2d_737[0][0]
# __________________________________________________________________________________________________
# batch_normalization_742 (BatchN (None, None, None, 3 1152        conv2d_738[0][0]
# __________________________________________________________________________________________________
# batch_normalization_745 (BatchN (None, None, None, 3 1152        conv2d_741[0][0]
# __________________________________________________________________________________________________
# batch_normalization_746 (BatchN (None, None, None, 3 1152        conv2d_742[0][0]
# __________________________________________________________________________________________________
# conv2d_743 (Conv2D)             (None, None, None, 1 245760      average_pooling2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_739 (BatchN (None, None, None, 3 960         conv2d_735[0][0]
# __________________________________________________________________________________________________
# activation_737 (Activation)     (None, None, None, 3 0           batch_normalization_741[0][0]
# __________________________________________________________________________________________________
# activation_738 (Activation)     (None, None, None, 3 0           batch_normalization_742[0][0]
# __________________________________________________________________________________________________
# activation_741 (Activation)     (None, None, None, 3 0           batch_normalization_745[0][0]
# __________________________________________________________________________________________________
# activation_742 (Activation)     (None, None, None, 3 0           batch_normalization_746[0][0]
# __________________________________________________________________________________________________
# batch_normalization_747 (BatchN (None, None, None, 1 576         conv2d_743[0][0]
# __________________________________________________________________________________________________
# activation_735 (Activation)     (None, None, None, 3 0           batch_normalization_739[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, None, None, 7 0           activation_737[0][0]
#                                                                  activation_738[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, None, None, 7 0           activation_741[0][0]
#                                                                  activation_742[0][0]
# __________________________________________________________________________________________________
# activation_743 (Activation)     (None, None, None, 1 0           batch_normalization_747[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, None, None, 2 0           activation_735[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_15[0][0]
#                                                                  activation_743[0][0]
# __________________________________________________________________________________________________
# conv2d_748 (Conv2D)             (None, None, None, 4 917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_752 (BatchN (None, None, None, 4 1344        conv2d_748[0][0]
# __________________________________________________________________________________________________
# activation_748 (Activation)     (None, None, None, 4 0           batch_normalization_752[0][0]
# __________________________________________________________________________________________________
# conv2d_745 (Conv2D)             (None, None, None, 3 786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_749 (Conv2D)             (None, None, None, 3 1548288     activation_748[0][0]
# __________________________________________________________________________________________________
# batch_normalization_749 (BatchN (None, None, None, 3 1152        conv2d_745[0][0]
# __________________________________________________________________________________________________
# batch_normalization_753 (BatchN (None, None, None, 3 1152        conv2d_749[0][0]
# __________________________________________________________________________________________________
# activation_745 (Activation)     (None, None, None, 3 0           batch_normalization_749[0][0]
# __________________________________________________________________________________________________
# activation_749 (Activation)     (None, None, None, 3 0           batch_normalization_753[0][0]
# __________________________________________________________________________________________________
# conv2d_746 (Conv2D)             (None, None, None, 3 442368      activation_745[0][0]
# __________________________________________________________________________________________________
# conv2d_747 (Conv2D)             (None, None, None, 3 442368      activation_745[0][0]
# __________________________________________________________________________________________________
# conv2d_750 (Conv2D)             (None, None, None, 3 442368      activation_749[0][0]
# __________________________________________________________________________________________________
# conv2d_751 (Conv2D)             (None, None, None, 3 442368      activation_749[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_72 (AveragePo (None, None, None, 2 0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_744 (Conv2D)             (None, None, None, 3 655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_750 (BatchN (None, None, None, 3 1152        conv2d_746[0][0]
# __________________________________________________________________________________________________
# batch_normalization_751 (BatchN (None, None, None, 3 1152        conv2d_747[0][0]
# __________________________________________________________________________________________________
# batch_normalization_754 (BatchN (None, None, None, 3 1152        conv2d_750[0][0]
# __________________________________________________________________________________________________
# batch_normalization_755 (BatchN (None, None, None, 3 1152        conv2d_751[0][0]
# __________________________________________________________________________________________________
# conv2d_752 (Conv2D)             (None, None, None, 1 393216      average_pooling2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_748 (BatchN (None, None, None, 3 960         conv2d_744[0][0]
# __________________________________________________________________________________________________
# activation_746 (Activation)     (None, None, None, 3 0           batch_normalization_750[0][0]
# __________________________________________________________________________________________________
# activation_747 (Activation)     (None, None, None, 3 0           batch_normalization_751[0][0]
# __________________________________________________________________________________________________
# activation_750 (Activation)     (None, None, None, 3 0           batch_normalization_754[0][0]
# __________________________________________________________________________________________________
# activation_751 (Activation)     (None, None, None, 3 0           batch_normalization_755[0][0]
# __________________________________________________________________________________________________
# batch_normalization_756 (BatchN (None, None, None, 1 576         conv2d_752[0][0]
# __________________________________________________________________________________________________
# activation_744 (Activation)     (None, None, None, 3 0           batch_normalization_748[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, None, None, 7 0           activation_746[0][0]
#                                                                  activation_747[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, None, None, 7 0           activation_750[0][0]
#                                                                  activation_751[0][0]
# __________________________________________________________________________________________________
# activation_752 (Activation)     (None, None, None, 1 0           batch_normalization_756[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, None, None, 2 0           activation_744[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_16[0][0]
#                                                                  activation_752[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 2048)         0           mixed10[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1024)         2098176     global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_757 (BatchN (None, 1024)         4096        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 3)            3075        batch_normalization_757[0][0]
# ==================================================================================================
# Total params: 23,908,131
# Trainable params: 2,103,299
# Non-trainable params: 21,804,832
# __________________________________________________________________________________________________

# %%
fit_history = final_model.fit_generator(
    train_generator, #generator dados treino
    steps_per_epoch=len(train_generator),
    epochs=40, #talvez 40 seja melhor
    validation_data=val_generator, #dados gerados para validação
    validation_steps=len(val_generator)
)

#history = model.fit(train_generator, epochs=25, validation_data = validation_generator, verbose = 1)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 13s 6s/step - loss: 1.9181 - accuracy: 0.3730 - val_loss: 9.3698 - val_accuracy: 0.2969
# Epoch 2/50
# 2/2 [==============================] - 4s 2s/step - loss: 1.0176 - accuracy: 0.6627 - val_loss: 1.6533 - val_accuracy: 0.5469
# Epoch 3/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.7231 - accuracy: 0.7778 - val_loss: 1.5072 - val_accuracy: 0.6094
# Epoch 4/50
# 2/2 [==============================] - 7s 3s/step - loss: 0.7872 - accuracy: 0.7738 - val_loss: 2.3869 - val_accuracy: 0.5781
# Epoch 5/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.5099 - accuracy: 0.8294 - val_loss: 6.3989 - val_accuracy: 0.5156
# Epoch 6/50
# 2/2 [==============================] - 7s 3s/step - loss: 0.5620 - accuracy: 0.8452 - val_loss: 8.4494 - val_accuracy: 0.5000
# Epoch 7/50
# 2/2 [==============================] - 7s 3s/step - loss: 0.3835 - accuracy: 0.8571 - val_loss: 7.7105 - val_accuracy: 0.5000
# Epoch 8/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.4284 - accuracy: 0.8810 - val_loss: 5.2956 - val_accuracy: 0.5469
# Epoch 9/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3590 - accuracy: 0.8373 - val_loss: 3.1783 - val_accuracy: 0.5938
# Epoch 10/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3559 - accuracy: 0.8730 - val_loss: 4.3775 - val_accuracy: 0.4375
# Epoch 11/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.4167 - accuracy: 0.8611 - val_loss: 6.1699 - val_accuracy: 0.3438
# Epoch 12/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.4125 - accuracy: 0.8452 - val_loss: 5.9977 - val_accuracy: 0.3438
# Epoch 13/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3074 - accuracy: 0.8730 - val_loss: 4.3014 - val_accuracy: 0.4062
# Epoch 14/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2635 - accuracy: 0.9048 - val_loss: 3.0055 - val_accuracy: 0.5469
# Epoch 15/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2619 - accuracy: 0.9087 - val_loss: 3.1253 - val_accuracy: 0.5938
# Epoch 16/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3779 - accuracy: 0.8730 - val_loss: 3.7812 - val_accuracy: 0.5625
# Epoch 17/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2632 - accuracy: 0.8889 - val_loss: 4.5551 - val_accuracy: 0.5312
# Epoch 18/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3598 - accuracy: 0.8651 - val_loss: 3.8110 - val_accuracy: 0.5625
# Epoch 19/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2978 - accuracy: 0.8889 - val_loss: 2.3399 - val_accuracy: 0.6250
# Epoch 20/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3143 - accuracy: 0.9087 - val_loss: 1.6442 - val_accuracy: 0.6875
# Epoch 21/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3397 - accuracy: 0.8770 - val_loss: 1.7749 - val_accuracy: 0.6875
# Epoch 22/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2296 - accuracy: 0.9286 - val_loss: 2.2740 - val_accuracy: 0.6406
# Epoch 23/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2182 - accuracy: 0.9206 - val_loss: 2.8806 - val_accuracy: 0.6094
# Epoch 24/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2267 - accuracy: 0.8968 - val_loss: 3.3616 - val_accuracy: 0.6250
# Epoch 25/50
# 2/2 [==============================] - 7s 3s/step - loss: 0.3103 - accuracy: 0.8810 - val_loss: 3.8232 - val_accuracy: 0.6406
# Epoch 26/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2755 - accuracy: 0.9087 - val_loss: 4.3204 - val_accuracy: 0.5938
# Epoch 27/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3196 - accuracy: 0.8770 - val_loss: 4.5135 - val_accuracy: 0.5938
# Epoch 28/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2695 - accuracy: 0.9048 - val_loss: 3.8150 - val_accuracy: 0.6094
# Epoch 29/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2656 - accuracy: 0.8889 - val_loss: 3.0556 - val_accuracy: 0.5625
# Epoch 30/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1889 - accuracy: 0.9365 - val_loss: 2.5970 - val_accuracy: 0.6094
# Epoch 31/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2915 - accuracy: 0.8849 - val_loss: 1.7851 - val_accuracy: 0.6250
# Epoch 32/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2494 - accuracy: 0.9246 - val_loss: 1.7538 - val_accuracy: 0.6875
# Epoch 33/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1749 - accuracy: 0.9325 - val_loss: 1.8534 - val_accuracy: 0.7188
# Epoch 34/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2384 - accuracy: 0.9048 - val_loss: 2.1807 - val_accuracy: 0.6719
# Epoch 35/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2012 - accuracy: 0.9127 - val_loss: 2.6500 - val_accuracy: 0.7188
# Epoch 36/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2609 - accuracy: 0.8889 - val_loss: 3.5745 - val_accuracy: 0.6250
# Epoch 37/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2431 - accuracy: 0.9087 - val_loss: 4.4498 - val_accuracy: 0.5312
# Epoch 38/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2052 - accuracy: 0.9286 - val_loss: 4.6894 - val_accuracy: 0.5156
# Epoch 39/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1802 - accuracy: 0.9405 - val_loss: 4.4968 - val_accuracy: 0.5469
# Epoch 40/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2293 - accuracy: 0.9206 - val_loss: 3.8670 - val_accuracy: 0.5625
# Epoch 41/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2499 - accuracy: 0.9008 - val_loss: 3.5035 - val_accuracy: 0.6250
# Epoch 42/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2308 - accuracy: 0.9008 - val_loss: 3.5914 - val_accuracy: 0.6719
# Epoch 43/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1932 - accuracy: 0.9167 - val_loss: 3.6724 - val_accuracy: 0.6719
# Epoch 44/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1485 - accuracy: 0.9603 - val_loss: 4.0015 - val_accuracy: 0.6562
# Epoch 45/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1584 - accuracy: 0.9325 - val_loss: 4.0074 - val_accuracy: 0.6250
# Epoch 46/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1295 - accuracy: 0.9444 - val_loss: 4.0949 - val_accuracy: 0.6250
# Epoch 47/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1927 - accuracy: 0.9325 - val_loss: 4.3840 - val_accuracy: 0.5938
# Epoch 48/50
# 2/2 [==============================] - 7s 3s/step - loss: 0.2115 - accuracy: 0.9206 - val_loss: 4.7069 - val_accuracy: 0.5781
# Epoch 49/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2273 - accuracy: 0.9127 - val_loss: 4.7464 - val_accuracy: 0.5938
# Epoch 50/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1595 - accuracy: 0.9325 - val_loss: 4.9332 - val_accuracy: 0.6094

# %%
#display_training_curves(fit_history.history['acc'], fit_history.history['val_acc'], 'accuracy', 211)
#display_training_curves(fit_history.history['loss'], fit_history.history['val_loss'], 'loss', 212)

#def display_training_curves(training, validation, title, subplot):

print(fit_history.history)

training = fit_history.history['accuracy']
validation = fit_history.history['val_accuracy']
title = 'Acurácia'
subplot = 211

plt.subplots(figsize=(10,10))
plt.tight_layout()
ax = plt.subplot(subplot)
ax.set_facecolor('#F8F8F8')
ax.plot(training)
ax.plot(validation)
ax.set_title('Acurácia')
ax.set_ylabel(title)
ax.set_xlabel('epoch')
ax.legend(['train', 'valid.'])
# Out:
# {'val_loss': [9.369823455810547, 1.6533164978027344, 1.507234811782837, 2.386929512023926, 6.398871421813965, 8.4494047164917, 7.710509777069092, 5.295631408691406, 3.1783270835876465, 4.377467155456543, 6.1699419021606445, 5.997745513916016, 4.301438331604004, 3.005450963973999, 3.1252732276916504, 3.781198024749756, 4.555121898651123, 3.8110039234161377, 2.3399274349212646, 1.6441526412963867, 1.7748773097991943, 2.2739996910095215, 2.8806402683258057, 3.361593723297119, 3.823209524154663, 4.320440292358398, 4.513484001159668, 3.815011739730835, 3.0555877685546875, 2.5969839096069336, 1.7850971221923828, 1.7538015842437744, 1.853377103805542, 2.1807074546813965, 2.6499710083007812, 3.5745372772216797, 4.44980525970459, 4.689375877380371, 4.496791839599609, 3.8670458793640137, 3.503488063812256, 3.59135365486145, 3.672412395477295, 4.001453399658203, 4.007397174835205, 4.094856262207031, 4.383994102478027, 4.706909656524658, 4.746404647827148, 4.933163642883301], 'val_accuracy': [0.296875, 0.546875, 0.609375, 0.578125, 0.515625, 0.5, 0.5, 0.546875, 0.59375, 0.4375, 0.34375, 0.34375, 0.40625, 0.546875, 0.59375, 0.5625, 0.53125, 0.5625, 0.625, 0.6875, 0.6875, 0.640625, 0.609375, 0.625, 0.640625, 0.59375, 0.59375, 0.609375, 0.5625, 0.609375, 0.625, 0.6875, 0.71875, 0.671875, 0.71875, 0.625, 0.53125, 0.515625, 0.546875, 0.5625, 0.625, 0.671875, 0.671875, 0.65625, 0.625, 0.625, 0.59375, 0.578125, 0.59375, 0.609375], 'loss': [1.8572154768875666, 0.9740332322461265, 0.728081541875052, 0.7785242829057906, 0.5191325842151566, 0.5521261469712333, 0.3948827880242514, 0.419889992191678, 0.3776318887396464, 0.33951123732896077, 0.4441281532247861, 0.4196363885014776, 0.30563583449711873, 0.2616471294609327, 0.25899199964035124, 0.37612076647697934, 0.26899888478810824, 0.3585964266269926, 0.2964753723806805, 0.31099350324698855, 0.33201301015085644, 0.23474997317507154, 0.23104120507126763, 0.23391418768063424, 0.31798667105890455, 0.2705867163955219, 0.30982776506552623, 0.2704412790517958, 0.26189812402876594, 0.1843870354905015, 0.3105656261600199, 0.2477197072335652, 0.18639472499489784, 0.2407257804085338, 0.19992899072785225, 0.25902164195265087, 0.24220667862229878, 0.20987293206983143, 0.17130167427517118, 0.22101782268238446, 0.2609365885219877, 0.23111832999284304, 0.19216451705211685, 0.1535543499603158, 0.1540278639821779, 0.1255953861252656, 0.19322149124410418, 0.21688837782731132, 0.22797176466574745, 0.1679586043788327], 'accuracy': [0.37301588, 0.6626984, 0.7777778, 0.77380955, 0.8293651, 0.8452381, 0.85714287, 0.88095236, 0.8373016, 0.8730159, 0.8611111, 0.8452381, 0.8730159, 0.9047619, 0.90873015, 0.8730159, 0.8888889, 0.86507934, 0.8888889, 0.90873015, 0.8769841, 0.9285714, 0.9206349, 0.8968254, 0.88095236, 0.90873015, 0.8769841, 0.9047619, 0.8888889, 0.93650794, 0.88492066, 0.92460316, 0.9325397, 0.9047619, 0.9126984, 0.8888889, 0.90873015, 0.9285714, 0.9404762, 0.9206349, 0.9007937, 0.9007937, 0.9166667, 0.96031743, 0.9325397, 0.9444444, 0.9325397, 0.9206349, 0.9126984, 0.9325397]}

# %%
result = final_model.evaluate_generator(test_generator, steps=len(test_generator))
print('Loss: ', result[0])
print('Accuracy: ', result[1])
# Out:
# Loss:  11.468350410461426
# Accuracy:  0.612500011920929

# %%
train_generator.class_indices
# Out:
# {'covid': 0, 'normal': 1, 'pneumonia': 2}

# %%
#gerando todos os preditores
filenames = test_generator.filenames
nb_samples = len(filenames)
predict = final_model.predict_generator(test_generator, steps = nb_samples).argmax(axis=-1)

predict
# Out:
# array([0, 0, 1, 0, ..., 1, 0, 2, 1])

# %%
#gerandor de rotulos verdadeiros
test_generator.classes
# Out:
# array([0, 0, 0, 0, ..., 2, 2, 2, 2], dtype=int32)

# %%
#@title Enter Filepath Here:
filename = "/content/dataset/val/covid/16654_1_1.png" #@param {type:"string"}

img = image.load_img(filename, target_size=(150, 150))

x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

y = final_model.predict(x)

predicton="Normal" if y.argmax(axis=-1)==0 else "Pneumonia"
actual="Normal" if "NORMAL" in filename else "Pneumonia" 

img=mpimg.imread(filename)
title_text = ("%s%s%s%s%s"%("True Label: ", actual, "\n", "Prediction: ", predicton))
plt.title(title_text)
imgplot=plt.imshow(img)
