# %% [markdown]
# <a href="https://colab.research.google.com/github/jimitogni/dissertacao/blob/master/transfer_resnet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import os
from numpy.random import seed
import tensorflow as tf
import torch
import pandas as pd
import numpy as np
import os, shutil
from fastai.vision import *
from fastai.widgets import ClassConfusion
import random
import matplotlib.image as mpimg 
from PIL import Image

tf.random.set_seed(100)

# %% [markdown]
# Metodo para buscar diretórios

# %%
def search_dir(type="normal", num=6):
  #funcao que ajuda scanear um diretorio
  counter = 0

  for file in os.listdir('dataset/test/covid/'):
    if counter == num:
      break

    if file.endswith(".jpeg"):
      print(file)

    counter += 1

# %% [markdown]
# Função que auxilia a plotar as imagens utilizando a biblioteca mpimg

# %%
def plot_images(type="normal", num=6):
  #auxilia ao plotar imagens
  counter = 0

  fig = plt.figure(figsize=(10,8))
  print("antes do for")
  print("list_dir = {}".format(os.listdir(train_dir)))
  print("train_dir + file = {}".format(os.listdir(train_dir + file)))

  for file in os.listdir(train_dir):
    if file.endswith(".jpeg"):
      print("passou no if 1")
      if counter == num:
        print("parrou no if 2 - nao achou nada")
        break

      img = mpimg.imread(train_dir + file)
      plt.subplot(231+counter)
      plt.title(file.split('.')[0])
      imgplot = plt.imshow(img)

      counter += 1
      print("chegou até o final do for")

# %% [markdown]
# Metodo para plotar os gráficos das curvas de aprendizado

# %%
def display_training_curves(training, validation, title, subplot):
  if subplot%10==1: #set up subplot in first call
    plt.subplots(figsize=(10,10))
    plt.tight_layout()
  ax = plt.subplot(subplot)
  ax.set_facecolor('F8F8F8')
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model' + title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['train', 'valid.'])

# %% [markdown]
# Usando a API do kaggle para baixar uma base de dados com imagens de Raios-X que contem **imagens de pulmões normais e com pneumonia**

# %%
os.environ['KAGLE_USERNAME']= "jimitogni"
os.environ['KAGLE_KEY']= "6ba3f466a063e70addd26514bb2cf41d"

# %%
# %%shell
# pip install kaggle
# export KAGGLE_USERNAME=jimitogni
# export KAGGLE_KEY=6ba3f466a063e70addd26514bb2cf41d
#
# kaggle datasets download paultimothymooney/chest-xray-pneumonia
# unzip -q chest-xray-pneumonia.zip
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.38.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.21.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.4.5.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.8)
# Downloading chest-xray-pneumonia.zip to /content
#  99% 2.27G/2.29G [00:48<00:00, 30.3MB/s]
# 100% 2.29G/2.29G [00:48<00:00, 51.2MB/s]

# %% [markdown]
# Agora pegamos a base de dados que contem apenas Raios-X com imagens de pessoas contaminadas com COVID-19

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 1575 (delta 28), reused 41 (delta 18), pack-reused 1511
# Receiving objects: 100% (1575/1575), 216.44 MiB | 31.10 MiB/s, done.
# Resolving deltas: 100% (752/752), done.
# Checking out files: 100% (341/341), done.

# %% [markdown]
# Agrupando as duas bases de dados

# %%
# Load Kaggle Pneumonia Dataset
def get_dataset(path, label):
  return [[path+x, label] for x in os.listdir(path) if not x.startswith('.')]

root = 'chest_xray/chest_xray/train/'
normal_xray = get_dataset(root+'NORMAL/', 'normal')
pneumonia_xray = get_dataset(root+'PNEUMONIA/', 'pneumonia')
print(len(normal_xray), normal_xray[0:5])
print(len(pneumonia_xray), pneumonia_xray[0:5])

# Load Covid-19 Dataset
metadata_path='covid-chestxray-dataset/metadata.csv'
srcpath = 'covid-chestxray-dataset/images/'
df=pd.read_csv(metadata_path)
covid_patients=df['finding']=='COVID-19'
PA=df['view']=='PA'
PA_covid=df[covid_patients & PA]
covid_xray = [[srcpath + files, 'covid'] for files in PA_covid['filename']]
print(len(covid_xray), covid_xray[0:5])

random.shuffle(normal_xray)
random.shuffle(pneumonia_xray)
random.shuffle(covid_xray)

# gerando dados balanceados e randomizados
min_size = min(len(normal_xray), len(pneumonia_xray), len(covid_xray))-1
dataset = normal_xray[0:min_size] + covid_xray[0:min_size] + pneumonia_xray[0:min_size]
random.shuffle(dataset)

print(len(dataset), dataset[0:5])

# carregando os dados para um df pandas
df = pd.DataFrame(dataset, columns=['X', 'y']).sample(frac=1)
print(df)

X = df['X']
y = df['y']

classes= y.unique()
print(classes)

# Split em train, valid, e test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

print()
print()
print("Total de imagens {}, Dados para: treino={}, Validação={} e Teste={} ".format(len(df), len(X_train), len(X_val), len(X_test)))

# !rm -rf dataset/ #remove a pasta se ela ja existir

#cria uma nova pasta com as duas bases de dados agrupadas
for dtype, dinputs, doutputs in [['train', X_train, y_train], ['val', X_val, y_val], ['test', X_test, y_test]]:
  for _X, _y in zip(dinputs, doutputs):
    path = 'dataset/'+dtype+'/'+_y
    os.makedirs(path, exist_ok=True)
    # print(_X, path)
    shutil.copy(_X, path)

# !tar -czf dataset.tar.gz dataset/ #guarda toda a base obtida em um arquivo zip
# Out:
# 1341 [['chest_xray/chest_xray/train/NORMAL/IM-0355-0001.jpeg', 'normal'], ['chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-0809-0001.jpeg', 'normal'], ['chest_xray/chest_xray/train/NORMAL/IM-0312-0001.jpeg', 'normal'], ['chest_xray/chest_xray/train/NORMAL/IM-0593-0001.jpeg', 'normal'], ['chest_xray/chest_xray/train/NORMAL/IM-0490-0001.jpeg', 'normal']]
# 3875 [['chest_xray/chest_xray/train/PNEUMONIA/person151_virus_301.jpeg', 'pneumonia'], ['chest_xray/chest_xray/train/PNEUMONIA/person489_virus_994.jpeg', 'pneumonia'], ['chest_xray/chest_xray/train/PNEUMONIA/person441_bacteria_1915.jpeg', 'pneumonia'], ['chest_xray/chest_xray/train/PNEUMONIA/person440_bacteria_1897.jpeg', 'pneumonia'], ['chest_xray/chest_xray/train/PNEUMONIA/person1339_bacteria_3399.jpeg', 'pneumonia']]
# 133 [['covid-chestxray-dataset/images/auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg', 'covid'], ['covid-chestxray-dataset/images/auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg', 'covid'], ['covid-chestxray-dataset/images/auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg', 'covid'], ['covid-chestxray-dataset/images/auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg', 'covid'], ['covid-chestxray-dataset/images/nejmc2001573_f1a.jpeg', 'covid']]
# 396 [['chest_xray/chest_xray/train/NORMAL/IM-0543-0001.jpeg', 'normal'], ['covid-chestxray-dataset/images/auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg', 'covid'], ['chest_xray/chest_xray/train/PNEUMONIA/person565_virus_1105.jpeg', 'pneumonia'], ['chest_xray/chest_xray/train/PNEUMONIA/person1176_virus_1998.jpeg', 'pneumonia'], ['chest_xray/chest_xray/train/PNEUMONIA/person470_bacteria_1999.jpeg', 'pneumonia']]
#                                                      X          y
# 228  chest_xray/chest_xray/train/PNEUMONIA/person13...  pneumonia
# 344  covid-chestxray-dataset/images/1-s2.0-S1684118...      covid
# 348  covid-chestxray-dataset/images/covid-19-pneumo...      covid
# 37   chest_xray/chest_xray/train/NORMAL/NORMAL2-IM-...     normal
# 70   chest_xray/chest_xray/train/PNEUMONIA/person10...  pneumonia
# ..                                                 ...        ...
# 168       covid-chestxray-dataset/images/16660_4_1.jpg      covid
# 389  chest_xray/chest_xray/train/PNEUMONIA/person15...  pneumonia
# 98   chest_xray/chest_xray/train/PNEUMONIA/person17...  pneumonia
# 89   covid-chestxray-dataset/images/covid-19-pneumo...      covid
# 105  covid-chestxray-dataset/images/1.CXRCTThoraxim...      covid
#
# [396 rows x 2 columns]
# ['pneumonia' 'covid' 'normal']
#
#
# Total de imagens 396, Dados para: treino=252, Validação=64 e Teste=80

# %%
#explore data
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#amostras de imagens com rotulos
def stage(data):
  print("distribuição da divisão das bases: treino - validação - teste, respectivamente:", len(data.train_ds),len(data.valid_ds),len(data.test_ds.x))
  print("classes", data.classes)
  data.show_batch(20)
  return None

tfms = get_transforms(do_flip=True, flip_vert=False, max_rotate=15.0, max_lighting=0.1, max_zoom=1.05)#, max_warp=0.

data = ImageDataBunch.from_folder('dataset', train="train", valid='val',test='test', ds_tfms=get_transforms(tfms), bs=9, size=512, num_workers=4).normalize()
stage(data)
# Out:
# distribuição da divisão das bases: treino - validação - teste, respectivamente: 252 64 80
# classes ['covid', 'normal', 'pneumonia']

# %%
#diretorios
train_dir = "dataset/train/"
val_dir = "dataset/val/"
test_dir = "dataset/test/"

# %%
search_dir(type="pneumonia", num=10)
search_dir(type="normal", num=10)
search_dir(type="covid", num=10)
# Out:
# ryct.2020200034.fig5-day7.jpeg
# 2966893D-5DDF-4B68-9E2B-4979D5956C8E.jpeg
# 53EC07C9-5CC6-4BE4-9B6F-D7B0D72AAA7E.jpeg
# ryct.2020200034.fig5-day7.jpeg
# 2966893D-5DDF-4B68-9E2B-4979D5956C8E.jpeg
# 53EC07C9-5CC6-4BE4-9B6F-D7B0D72AAA7E.jpeg
# ryct.2020200034.fig5-day7.jpeg
# 2966893D-5DDF-4B68-9E2B-4979D5956C8E.jpeg
# 53EC07C9-5CC6-4BE4-9B6F-D7B0D72AAA7E.jpeg

# %% [markdown]
# Plotando apelas imagens com covid

# %%
#plot_images(type="pneumonia", num=6)
#auxilia ao plotar imagens
counter = 0
num = 6
#print(type(train_dir))

fig = plt.figure(figsize=(14,12))
#print("antes do for")
#print("list_dir train_dir = {}".format(os.listdir(train_dir)))
#print("train_dir + file = {}".format(os.listdir(train_dir + file)))

for file in os.listdir('dataset/train/covid/'):
  #print('dataset/train/covid/' + file)
  if file.endswith(".jpeg"):
    #print("passou no if 1")
    if counter == num:
      #print("parrou no if 2 - nao achou nada")
      break

    img = mpimg.imread('dataset/train/covid/' + file)
    plt.subplot(231+counter)
    plt.title(file.split('.')[0])
    imgplot = plt.imshow(img)

    counter += 1
    #print("chegou até o final do for")

# %% [markdown]
# Plotando imagens normais

# %%
#plot_images(type="pneumonia", num=6)
#auxilia ao plotar imagens
counter = 0
num = 6
#print(type(train_dir))

fig = plt.figure(figsize=(10,8))
#print("antes do for")
#print("list_dir train_dir = {}".format(os.listdir(train_dir)))
#print("train_dir + file = {}".format(os.listdir(train_dir + file)))

for file in os.listdir('dataset/train/normal/'):
  #print('dataset/train/covid/' + file)
  if file.endswith(".jpeg"):
    #print("passou no if 1")
    if counter == num:
      #print("parrou no if 2 - nao achou nada")
      break

    img = mpimg.imread('dataset/train/normal/' + file)
    plt.subplot(231+counter)
    plt.title(file.split('.')[0])
    imgplot = plt.imshow(img)

    counter += 1
    #print("chegou até o final do for")

# %% [markdown]
# **MODELO**
# pre trerinado usando a rede inceptionV3

# %%
import numpy as np

from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions

from tensorflow.python.keras.preprocessing import image

# %%
pre_model = ResNet50(weights="imagenet") #carrega o modelo com os pesos da imagenet

# %% [markdown]
# ------

# %% [markdown]
# Testando a classificalção com um imagem qualquer para ver o que a rede retorna antes de ser treinada com os nossos dados

# %%
img = image.load_img("/content/dataset/train/covid/16654_4_1.jpg", target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

y = pre_model.predict(x)

for index, res in enumerate(decode_predictions(y)[0]):
  print('{}. {}: {:.3f}%'.format(index + 1, res[1], 100* res[2]))
# Out:
# 1. groom: 23.905%
# 2. mosquito_net: 15.677%
# 3. feather_boa: 13.858%
# 4. fountain: 8.462%
# 5. gown: 5.533%

# %%
#img = mpimg.imread("example_2.jpg")
#imgplot = plt.imshow(img)

# %% [markdown]
# preparação dos dados

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
batch_size = 163

#criando gerador para dados de treinamento
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1) #cria um gerador de imagem no abstract

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir, #diretorio com os dados de treino
    target_size=(150,150), #tamanho da imagem que queremos
    batch_size=batch_size, #quantos arquivos para ler de cada vez
    class_mode="categorical"
)
# Out:
# Found 252 images belonging to 3 classes.

# %%
#gerando dados para validação

val_datagen = ImageDataGenerator(rescale=1./255)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(150,150),
    batch_size=1,
    class_mode="categorical",
)
# Out:
# Found 64 images belonging to 3 classes.

# %%
#gerando dados para teste

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(150,150),
    batch_size=1,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 80 images belonging to 3 classes.

# %% [markdown]
# #MODELO PARA TREINO EXCLUINDO A PRIMEIRA CAMADA

# %%
import keras

# %%
base_model = ResNet50(weights='imagenet', include_top=False)

x = base_model.output
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dense(1024, activation='relu')(x)
x = keras.layers.BatchNormalization()(x)
predictions = keras.layers.Dense(3, activation='softmax')(x)

for layer in base_model.layers:
  layer.trainable = False #congela os layers para nao treinar

final_model = keras.models.Model(inputs=base_model.inputs, outputs=predictions) #modelo final
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
final_model.compile(loss="categorical_crossentropy", # log loss
                    optimizer="sgd", # sgd ou adam - antes era adam - testar outros sgd, (optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
                    metrics=["accuracy"])

# %%
final_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_6[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           activation_246[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_247[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_248[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, None, None, 2 0           add_81[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_249[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_250[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_251[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_249[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, None, None, 2 0           add_82[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_252[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_253[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_254[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_252[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, None, None, 2 0           add_83[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_255[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_256[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_257[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_255[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, None, None, 5 0           add_84[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_258[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_259[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_260[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_258[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, None, None, 5 0           add_85[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_261[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_262[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_263[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_261[0][0]
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, None, None, 5 0           add_86[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_264[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_265[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_266[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_264[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, None, None, 5 0           add_87[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_267[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_268[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_269[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_267[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, None, None, 1 0           add_88[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_270[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_271[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_272[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_270[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, None, None, 1 0           add_89[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_273[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_274[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_275[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_273[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, None, None, 1 0           add_90[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_276[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_277[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_278[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_276[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, None, None, 1 0           add_91[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_279[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_280[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_281[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_279[0][0]
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, None, None, 1 0           add_92[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_282[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_283 (Activation)     (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_283[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_284[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_282[0][0]
# __________________________________________________________________________________________________
# activation_285 (Activation)     (None, None, None, 1 0           add_93[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524800      activation_285[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_286 (Activation)     (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_286[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_287 (Activation)     (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_287[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2099200     activation_285[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_288 (Activation)     (None, None, None, 2 0           add_94[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_288[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_289 (Activation)     (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_289[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_290 (Activation)     (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_290[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  activation_288[0][0]
# __________________________________________________________________________________________________
# activation_291 (Activation)     (None, None, None, 2 0           add_95[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_291[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_292 (Activation)     (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_292[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_293 (Activation)     (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_293[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_96 (Add)                    (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  activation_291[0][0]
# __________________________________________________________________________________________________
# activation_294 (Activation)     (None, None, None, 2 0           add_96[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 2048)         0           activation_294[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1024)         2098176     global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1024)         4096        dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 3)            3075        batch_normalization_4[0][0]
# ==================================================================================================
# Total params: 25,693,059
# Trainable params: 2,103,299
# Non-trainable params: 23,589,760
# __________________________________________________________________________________________________

# %%
fit_history = final_model.fit_generator(
    train_generator, #generator dados treino
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=val_generator, #dados gerados para validação
    validation_steps=len(val_generator),
    verbose = 1
)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 12s 6s/step - loss: 1.2423 - accuracy: 0.4722 - val_loss: 0.8802 - val_accuracy: 0.3594
# Epoch 2/50
# 2/2 [==============================] - 6s 3s/step - loss: 0.8049 - accuracy: 0.6190 - val_loss: 0.8989 - val_accuracy: 0.3594
# Epoch 3/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.5634 - accuracy: 0.7579 - val_loss: 1.0714 - val_accuracy: 0.3594
# Epoch 4/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.5166 - accuracy: 0.8135 - val_loss: 0.9865 - val_accuracy: 0.3594
# Epoch 5/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.4857 - accuracy: 0.7937 - val_loss: 1.0022 - val_accuracy: 0.2969
# Epoch 6/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.4243 - accuracy: 0.8413 - val_loss: 0.9985 - val_accuracy: 0.2969
# Epoch 7/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.3294 - accuracy: 0.8889 - val_loss: 0.9702 - val_accuracy: 0.3125
# Epoch 8/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2991 - accuracy: 0.8849 - val_loss: 0.9467 - val_accuracy: 0.3281
# Epoch 9/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.3358 - accuracy: 0.8849 - val_loss: 1.3264 - val_accuracy: 0.3281
# Epoch 10/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.3458 - accuracy: 0.8849 - val_loss: 1.0615 - val_accuracy: 0.3281
# Epoch 11/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2869 - accuracy: 0.8730 - val_loss: 1.0682 - val_accuracy: 0.3281
# Epoch 12/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.3799 - accuracy: 0.8571 - val_loss: 0.9183 - val_accuracy: 0.3281
# Epoch 13/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2643 - accuracy: 0.9048 - val_loss: 0.8839 - val_accuracy: 0.3281
# Epoch 14/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2866 - accuracy: 0.9167 - val_loss: 1.1011 - val_accuracy: 0.3281
# Epoch 15/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2476 - accuracy: 0.8849 - val_loss: 1.1131 - val_accuracy: 0.3281
# Epoch 16/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2239 - accuracy: 0.9167 - val_loss: 1.1254 - val_accuracy: 0.3281
# Epoch 17/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2559 - accuracy: 0.8968 - val_loss: 1.1341 - val_accuracy: 0.3281
# Epoch 18/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2414 - accuracy: 0.9127 - val_loss: 1.3723 - val_accuracy: 0.3281
# Epoch 19/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2976 - accuracy: 0.9008 - val_loss: 1.3264 - val_accuracy: 0.3281
# Epoch 20/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2495 - accuracy: 0.9127 - val_loss: 1.1913 - val_accuracy: 0.3281
# Epoch 21/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2311 - accuracy: 0.9286 - val_loss: 1.3565 - val_accuracy: 0.3281
# Epoch 22/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2263 - accuracy: 0.9048 - val_loss: 0.8190 - val_accuracy: 0.3281
# Epoch 23/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1852 - accuracy: 0.9325 - val_loss: 1.2438 - val_accuracy: 0.3281
# Epoch 24/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2021 - accuracy: 0.9365 - val_loss: 1.2850 - val_accuracy: 0.3281
# Epoch 25/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2158 - accuracy: 0.9365 - val_loss: 1.2941 - val_accuracy: 0.3281
# Epoch 26/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2049 - accuracy: 0.9167 - val_loss: 1.3144 - val_accuracy: 0.3281
# Epoch 27/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2165 - accuracy: 0.9206 - val_loss: 1.2810 - val_accuracy: 0.3281
# Epoch 28/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.2023 - accuracy: 0.9127 - val_loss: 0.7632 - val_accuracy: 0.3281
# Epoch 29/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1930 - accuracy: 0.9127 - val_loss: 1.3133 - val_accuracy: 0.3281
# Epoch 30/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1743 - accuracy: 0.9246 - val_loss: 1.3000 - val_accuracy: 0.3281
# Epoch 31/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1798 - accuracy: 0.9365 - val_loss: 1.3858 - val_accuracy: 0.3281
# Epoch 32/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1746 - accuracy: 0.9365 - val_loss: 0.7434 - val_accuracy: 0.3281
# Epoch 33/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1435 - accuracy: 0.9365 - val_loss: 1.2895 - val_accuracy: 0.3281
# Epoch 34/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1934 - accuracy: 0.9246 - val_loss: 0.7184 - val_accuracy: 0.3281
# Epoch 35/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1670 - accuracy: 0.9444 - val_loss: 0.7164 - val_accuracy: 0.3281
# Epoch 36/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1882 - accuracy: 0.9286 - val_loss: 0.6955 - val_accuracy: 0.3281
# Epoch 37/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1530 - accuracy: 0.9484 - val_loss: 1.4598 - val_accuracy: 0.3281
# Epoch 38/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1583 - accuracy: 0.9405 - val_loss: 0.6731 - val_accuracy: 0.3281
# Epoch 39/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1686 - accuracy: 0.9563 - val_loss: 0.6937 - val_accuracy: 0.3281
# Epoch 40/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1507 - accuracy: 0.9484 - val_loss: 1.5290 - val_accuracy: 0.3281
# Epoch 41/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1619 - accuracy: 0.9484 - val_loss: 1.2935 - val_accuracy: 0.3281
# Epoch 42/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1263 - accuracy: 0.9603 - val_loss: 0.6851 - val_accuracy: 0.3281
# Epoch 43/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1371 - accuracy: 0.9524 - val_loss: 1.5689 - val_accuracy: 0.3281
# Epoch 44/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1695 - accuracy: 0.9484 - val_loss: 0.6491 - val_accuracy: 0.3281
# Epoch 45/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1703 - accuracy: 0.9405 - val_loss: 1.6169 - val_accuracy: 0.3281
# Epoch 46/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1352 - accuracy: 0.9524 - val_loss: 1.2770 - val_accuracy: 0.3281
# Epoch 47/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1370 - accuracy: 0.9484 - val_loss: 1.2329 - val_accuracy: 0.3281
# Epoch 48/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1369 - accuracy: 0.9524 - val_loss: 1.6890 - val_accuracy: 0.3281
# Epoch 49/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.0856 - accuracy: 0.9722 - val_loss: 1.6916 - val_accuracy: 0.3281
# Epoch 50/50
# 2/2 [==============================] - 8s 4s/step - loss: 0.1279 - accuracy: 0.9603 - val_loss: 1.7198 - val_accuracy: 0.3281

# %%
#display_training_curves(fit_history.history['acc'], fit_history.history['val_acc'], 'accuracy', 211)
#display_training_curves(fit_history.history['loss'], fit_history.history['val_loss'], 'loss', 212)

#def display_training_curves(training, validation, title, subplot):

training = fit_history.history['accuracy']
validation = fit_history.history['val_accuracy']
title = 'Acurácia'
subplot = 211

plt.subplots(figsize=(10,10))
plt.tight_layout()
ax = plt.subplot(subplot)
ax.set_facecolor('#F8F8F8')
ax.plot(training)
ax.plot(validation)
ax.set_title('model' + title)
ax.set_ylabel(title)
ax.set_xlabel('epoch')
ax.legend(['train', 'valid.'])

# %%
result = final_model.evaluate_generator(test_generator, steps=len(test_generator))
print('Loss: ', result[0])
print('Accuracy: ', result[1])
# Out:
# Loss:  1.219095230102539
# Accuracy:  0.32499998807907104

# %%
train_generator.class_indices
# Out:
# {'covid': 0, 'normal': 1, 'pneumonia': 2}

# %%
#gerando todos os preditores
filenames = test_generator.filenames
nb_samples = len(filenames)
predict = final_model.predict_generator(test_generator, steps = nb_samples).argmax(axis=-1)

predict
# Out:
# array([0, 0, 0, 0, ..., 0, 0, 0, 0])

# %%
#gerandor de rotulos verdadeiros
test_generator.classes
# Out:
# array([0, 0, 0, 0, ..., 2, 2, 2, 2], dtype=int32)

# %%
#@title Enter Filepath Here:
filename = "/content/chest_xray/val/PNEUMONIA/person1950_bacteria_4881.jpeg" #@param {type:"string"}

img = image.load_img(filename, target_size=(150, 150))

x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

y = final_model.predict(x)

predicton="Normal" if y.argmax(axis=-1)==0 else "Pneumonia"
actual="Normal" if "NORMAL" in filename else "Pneumonia" 

img=mpimg.imread(filename)
title_text = ("%s%s%s%s%s"%("True Label: ", actual, "\n", "Prediction: ", predicton))
plt.title(title_text)
imgplot=plt.imshow(img)
